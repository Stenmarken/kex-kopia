# %%
import numpy as np
import pandas as pd
import librosa
import os
import glob
import re
import seaborn as sn
import matplotlib.pyplot as plt
import scipy
import time
import collections
import keras
import random
from keras.utils import np_utils
from keras.layers import MaxPooling1D, Conv1D, Conv2D, MaxPooling2D, GlobalAveragePooling2D, LSTM, ELU, Bidirectional, Attention
from keras.layers import Dense, Dropout, Activation, Flatten, CuDNNLSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import tensorflow as tf
import pickle
from keras.utils.vis_utils import plot_model
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import keras_tuner
from keras import backend as K
import shutil
import os
import tensorflow_addons as tfa
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn import metrics

# %% [markdown]
# ### Global variables

# %%
global_model_type = 'cnn'
global_folder_name = 'weyo4'
file_suffix = 'weyo1'
global_batch_size = 32
global_epochs = 30
global_learning_rate = 0.0001
own_file_path = os.getcwd()

# %%
def instrument_code(filename):
    """
    Function that takes in a filename and returns instrument based on naming convention
    """
    # Synth lead borttagen. id = 9
    class_names=['bass', 'brass', 'flute', 'guitar', 
             'keyboard', 'mallet', 'organ', 'reed', 
             'string', 'vocal']
    
    for name in class_names:
        if name in filename:
            return class_names.index(name)
    else:
        return None

# %% [markdown]
# ## Get data

# %%
def get_data_from_file(file):
    with open(file, "rb") as f:
        X_train_full  = pickle.load(f)

    X_train = []
    y_train = []

    for (key, value) in X_train_full:
        X_train.append(value)
        y_train.append(instrument_code(key))

    X_train_numpy = np.array(X_train)
    y_train_numpy = np.array(y_train)
    return (X_train_numpy, y_train_numpy)

# %%
def get_old_test_data(file):
    with open(file, 'rb') as f:
        old_X_test_full = pickle.load(f)

    old_X_test = []
    old_y_test = []

    for(key, value) in old_X_test_full.items():
        #temporal_value = np.mean(value, axis = 1)
        old_X_test.append(value)
        old_y_test.append(instrument_code(key))
        
    old_y_test_numpy = np.asarray(old_y_test)
    old_X_test_numpy = np.asarray(old_X_test)
    return (old_X_test_numpy, old_y_test_numpy)

# %% [markdown]
# ### Calculate metrics

# %%
def calc_metrics(y_true, y_pred):
    print(metrics.classification_report(y_true, y_pred, digits=3))

# %%
def build_cnn_model():    
    input_shape = (126, 13, 1)
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    #model.add(Dense(512, activation='relu'))
    #model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_lstm_model():
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def plot_acc_loss(history, acc_file_path, loss_file_path):
    # Taget från https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    # summarize history for accuracy
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(acc_file_path)
    plt.show()

    # summarize history for loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(loss_file_path)
    plt.show()

# %%
    
def plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path):    
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    result = confusion_matrix(y_test, y_prediction , normalize='pred')

    df_cm = pd.DataFrame(result, index = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]],
                    columns = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]])

    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig(confusion_matrix_file_path)
    plt.show()

# %%
def run_cnn(fold_index):

    old_test_file = 'CustomDataFull/testdata2000.pkl'

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/cnn_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

    model = build_cnn_model()
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)

    print("\n\ny_test : ", y_test)
    print("\n\ny_prediction : ", y_prediction)

    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)

    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores:\n' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata:\n' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %%
def run_lstm(fold_index):
    old_test_file = 'CustomDataFull/testdata2000.pkl'
    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/lstm_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

    model = build_lstm_model()
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    #model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy', 
    #              tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=10, average='macro',
    #              threshold=0.5)])
    
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)
    
    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores: ' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata: ' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %% [markdown]
# ### Run 5-fold cross validation

# %%
def run_cnn_5_fold_cross_validation():
    path = 'results/cnn_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)

    for i in range(0, 5):
        run_cnn(i)
    copy_file = 'results/cnn_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %%
def run_lstm_5_fold_cross_validation():
    path = 'results/lstm_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)

    for i in range(0, 5):
        run_lstm(i)
    copy_file = 'results/lstm_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %%
if (global_model_type == 'cnn'):
    print('Start running cnn')
    run_cnn_5_fold_cross_validation()
else:
    print('Start running lstm')
    run_lstm_5_fold_cross_validation()
# Out:
# Start running lstm
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_37 (LSTM)              (None, 126, 32)           5888
#
#  dropout_70 (Dropout)        (None, 126, 32)           0
#
#  lstm_38 (LSTM)              (None, 126, 32)           8320
#
#  dropout_71 (Dropout)        (None, 126, 32)           0
#
#  lstm_39 (LSTM)              (None, 126, 32)           8320
#
#  dropout_72 (Dropout)        (None, 126, 32)           0
#
#  lstm_40 (LSTM)              (None, 126, 32)           8320
#
#  dropout_73 (Dropout)        (None, 126, 32)           0
#
#  lstm_41 (LSTM)              (None, 126, 32)           8320
#
#  flatten_18 (Flatten)        (None, 4032)              0
#
#  dense_28 (Dense)            (None, 10)                40330
#
# =================================================================
# Total params: 79,498
# Trainable params: 79,498
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2188/2188 - 48s - loss: 1.5657 - accuracy: 0.4228 - val_loss: 1.2147 - val_accuracy: 0.5631 - 48s/epoch - 22ms/step
# Epoch 2/30
# 2188/2188 - 42s - loss: 1.1919 - accuracy: 0.5640 - val_loss: 1.0671 - val_accuracy: 0.6186 - 42s/epoch - 19ms/step
# Epoch 3/30
# 2188/2188 - 42s - loss: 1.0557 - accuracy: 0.6135 - val_loss: 0.9195 - val_accuracy: 0.6656 - 42s/epoch - 19ms/step
# Epoch 4/30
# 2188/2188 - 42s - loss: 0.9764 - accuracy: 0.6423 - val_loss: 0.9074 - val_accuracy: 0.6702 - 42s/epoch - 19ms/step
# Epoch 5/30
# 2188/2188 - 42s - loss: 0.9160 - accuracy: 0.6630 - val_loss: 0.7966 - val_accuracy: 0.7093 - 42s/epoch - 19ms/step
# Epoch 6/30
# 2188/2188 - 43s - loss: 0.8689 - accuracy: 0.6827 - val_loss: 0.7864 - val_accuracy: 0.7157 - 43s/epoch - 20ms/step
# Epoch 7/30
# 2188/2188 - 42s - loss: 0.8242 - accuracy: 0.6982 - val_loss: 0.7190 - val_accuracy: 0.7379 - 42s/epoch - 19ms/step
# Epoch 8/30
# 2188/2188 - 42s - loss: 0.7936 - accuracy: 0.7083 - val_loss: 0.6874 - val_accuracy: 0.7501 - 42s/epoch - 19ms/step
# Epoch 9/30
# 2188/2188 - 42s - loss: 0.7615 - accuracy: 0.7207 - val_loss: 0.6545 - val_accuracy: 0.7609 - 42s/epoch - 19ms/step
# Epoch 10/30
# 2188/2188 - 43s - loss: 0.7448 - accuracy: 0.7265 - val_loss: 0.7385 - val_accuracy: 0.7313 - 43s/epoch - 19ms/step
# Epoch 11/30
# 2188/2188 - 42s - loss: 0.7212 - accuracy: 0.7343 - val_loss: 0.6889 - val_accuracy: 0.7517 - 42s/epoch - 19ms/step
# Epoch 12/30
# 2188/2188 - 42s - loss: 0.6993 - accuracy: 0.7448 - val_loss: 0.6139 - val_accuracy: 0.7797 - 42s/epoch - 19ms/step
# Epoch 13/30
# 2188/2188 - 42s - loss: 0.6854 - accuracy: 0.7495 - val_loss: 0.6212 - val_accuracy: 0.7773 - 42s/epoch - 19ms/step
# Epoch 14/30
# 2188/2188 - 43s - loss: 0.6641 - accuracy: 0.7568 - val_loss: 0.6071 - val_accuracy: 0.7842 - 43s/epoch - 20ms/step
# Epoch 15/30
# 2188/2188 - 43s - loss: 0.6508 - accuracy: 0.7614 - val_loss: 0.5850 - val_accuracy: 0.7846 - 43s/epoch - 20ms/step
# Epoch 16/30
# 2188/2188 - 43s - loss: 0.6434 - accuracy: 0.7636 - val_loss: 0.5215 - val_accuracy: 0.8171 - 43s/epoch - 20ms/step
# Epoch 17/30
# 2188/2188 - 41s - loss: 0.6200 - accuracy: 0.7724 - val_loss: 0.5230 - val_accuracy: 0.8117 - 41s/epoch - 19ms/step
# Epoch 18/30
# 2188/2188 - 42s - loss: 0.6085 - accuracy: 0.7776 - val_loss: 0.6021 - val_accuracy: 0.7832 - 42s/epoch - 19ms/step
# Epoch 19/30
# 2188/2188 - 42s - loss: 0.6005 - accuracy: 0.7797 - val_loss: 0.5562 - val_accuracy: 0.7974 - 42s/epoch - 19ms/step
# Epoch 20/30
# 2188/2188 - 41s - loss: 0.5889 - accuracy: 0.7832 - val_loss: 0.5461 - val_accuracy: 0.8025 - 41s/epoch - 19ms/step
# Epoch 21/30
# 2188/2188 - 41s - loss: 0.5795 - accuracy: 0.7882 - val_loss: 0.5254 - val_accuracy: 0.8097 - 41s/epoch - 19ms/step
# Epoch 22/30
# 2188/2188 - 41s - loss: 0.5632 - accuracy: 0.7938 - val_loss: 0.5030 - val_accuracy: 0.8231 - 41s/epoch - 19ms/step
# Epoch 23/30
# 2188/2188 - 42s - loss: 0.5574 - accuracy: 0.7954 - val_loss: 0.4896 - val_accuracy: 0.8243 - 42s/epoch - 19ms/step
# Epoch 24/30
# 2188/2188 - 43s - loss: 0.5526 - accuracy: 0.7966 - val_loss: 0.4513 - val_accuracy: 0.8361 - 43s/epoch - 19ms/step
# Epoch 25/30
# 2188/2188 - 43s - loss: 0.5371 - accuracy: 0.8023 - val_loss: 0.4836 - val_accuracy: 0.8271 - 43s/epoch - 20ms/step
# Epoch 26/30
# 2188/2188 - 42s - loss: 0.5314 - accuracy: 0.8049 - val_loss: 0.4712 - val_accuracy: 0.8329 - 42s/epoch - 19ms/step
# Epoch 27/30
# 2188/2188 - 42s - loss: 0.5247 - accuracy: 0.8070 - val_loss: 0.5780 - val_accuracy: 0.7989 - 42s/epoch - 19ms/step
# Epoch 28/30
# 2188/2188 - 42s - loss: 0.5153 - accuracy: 0.8108 - val_loss: 0.4532 - val_accuracy: 0.8375 - 42s/epoch - 19ms/step
# Epoch 29/30
# 2188/2188 - 43s - loss: 0.5078 - accuracy: 0.8138 - val_loss: 0.4609 - val_accuracy: 0.8330 - 43s/epoch - 19ms/step
# Epoch 30/30
# 2188/2188 - 42s - loss: 0.5006 - accuracy: 0.8170 - val_loss: 0.4612 - val_accuracy: 0.8369 - 42s/epoch - 19ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.4514 - accuracy: 0.8323
# 274/274 [==============================] - 3s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 1.4764 - accuracy: 0.6462
# 128/128 [==============================] - 1s 8ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_42 (LSTM)              (None, 126, 32)           5888
#
#  dropout_74 (Dropout)        (None, 126, 32)           0
#
#  lstm_43 (LSTM)              (None, 126, 32)           8320
#
#  dropout_75 (Dropout)        (None, 126, 32)           0
#
#  lstm_44 (LSTM)              (None, 126, 32)           8320
#
#  dropout_76 (Dropout)        (None, 126, 32)           0
#
#  lstm_45 (LSTM)              (None, 126, 32)           8320
#
#  dropout_77 (Dropout)        (None, 126, 32)           0
#
#  lstm_46 (LSTM)              (None, 126, 32)           8320
#
#  flatten_19 (Flatten)        (None, 4032)              0
#
#  dense_29 (Dense)            (None, 10)                40330
#
# =================================================================
# Total params: 79,498
# Trainable params: 79,498
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2188/2188 - 48s - loss: 1.5818 - accuracy: 0.4201 - val_loss: 1.3084 - val_accuracy: 0.5218 - 48s/epoch - 22ms/step
# Epoch 2/30
# 2188/2188 - 42s - loss: 1.2174 - accuracy: 0.5550 - val_loss: 1.0937 - val_accuracy: 0.6006 - 42s/epoch - 19ms/step
# Epoch 3/30
# 2188/2188 - 43s - loss: 1.0752 - accuracy: 0.6047 - val_loss: 0.9547 - val_accuracy: 0.6536 - 43s/epoch - 20ms/step
# Epoch 4/30
# 2188/2188 - 43s - loss: 0.9894 - accuracy: 0.6352 - val_loss: 0.9007 - val_accuracy: 0.6718 - 43s/epoch - 20ms/step
# Epoch 5/30
# 2188/2188 - 43s - loss: 0.9299 - accuracy: 0.6595 - val_loss: 0.7943 - val_accuracy: 0.7125 - 43s/epoch - 20ms/step
# Epoch 6/30
# 2188/2188 - 43s - loss: 0.8856 - accuracy: 0.6760 - val_loss: 0.8165 - val_accuracy: 0.7050 - 43s/epoch - 20ms/step
# Epoch 7/30
# 2188/2188 - 43s - loss: 0.8456 - accuracy: 0.6892 - val_loss: 0.7367 - val_accuracy: 0.7279 - 43s/epoch - 20ms/step
# Epoch 8/30
# 2188/2188 - 42s - loss: 0.8069 - accuracy: 0.7028 - val_loss: 0.7207 - val_accuracy: 0.7403 - 42s/epoch - 19ms/step
# Epoch 9/30
# 2188/2188 - 43s - loss: 0.7807 - accuracy: 0.7114 - val_loss: 0.7003 - val_accuracy: 0.7424 - 43s/epoch - 20ms/step
# Epoch 10/30
# 2188/2188 - 42s - loss: 0.7579 - accuracy: 0.7195 - val_loss: 0.6730 - val_accuracy: 0.7514 - 42s/epoch - 19ms/step
# Epoch 11/30
# 2188/2188 - 42s - loss: 0.7288 - accuracy: 0.7311 - val_loss: 0.6180 - val_accuracy: 0.7733 - 42s/epoch - 19ms/step
# Epoch 12/30
# 2188/2188 - 41s - loss: 0.7114 - accuracy: 0.7383 - val_loss: 0.6559 - val_accuracy: 0.7618 - 41s/epoch - 19ms/step
# Epoch 13/30
# 2188/2188 - 42s - loss: 0.6891 - accuracy: 0.7449 - val_loss: 0.5927 - val_accuracy: 0.7885 - 42s/epoch - 19ms/step
# Epoch 14/30
# 2188/2188 - 42s - loss: 0.6744 - accuracy: 0.7531 - val_loss: 0.5795 - val_accuracy: 0.7889 - 42s/epoch - 19ms/step
# Epoch 15/30
# 2188/2188 - 42s - loss: 0.6602 - accuracy: 0.7570 - val_loss: 0.5678 - val_accuracy: 0.7967 - 42s/epoch - 19ms/step
# Epoch 16/30
# 2188/2188 - 42s - loss: 0.6419 - accuracy: 0.7630 - val_loss: 0.6516 - val_accuracy: 0.7701 - 42s/epoch - 19ms/step
# Epoch 17/30
# 2188/2188 - 41s - loss: 0.6262 - accuracy: 0.7702 - val_loss: 0.5402 - val_accuracy: 0.8109 - 41s/epoch - 19ms/step
# Epoch 18/30
# 2188/2188 - 41s - loss: 0.6126 - accuracy: 0.7740 - val_loss: 0.5289 - val_accuracy: 0.8065 - 41s/epoch - 19ms/step
# Epoch 19/30
# 2188/2188 - 42s - loss: 0.6003 - accuracy: 0.7783 - val_loss: 0.5223 - val_accuracy: 0.8187 - 42s/epoch - 19ms/step
# Epoch 20/30
# 2188/2188 - 42s - loss: 0.5942 - accuracy: 0.7793 - val_loss: 0.5916 - val_accuracy: 0.7955 - 42s/epoch - 19ms/step
# Epoch 21/30
# 2188/2188 - 42s - loss: 0.5768 - accuracy: 0.7870 - val_loss: 0.4921 - val_accuracy: 0.8290 - 42s/epoch - 19ms/step
# Epoch 22/30
# 2188/2188 - 43s - loss: 0.5712 - accuracy: 0.7903 - val_loss: 0.5693 - val_accuracy: 0.7904 - 43s/epoch - 20ms/step
# Epoch 23/30
# 2188/2188 - 43s - loss: 0.5620 - accuracy: 0.7928 - val_loss: 0.5308 - val_accuracy: 0.8153 - 43s/epoch - 19ms/step
# Epoch 24/30
# 2188/2188 - 43s - loss: 0.5519 - accuracy: 0.7978 - val_loss: 0.5550 - val_accuracy: 0.8066 - 43s/epoch - 19ms/step
# Epoch 25/30
# 2188/2188 - 44s - loss: 0.5414 - accuracy: 0.8014 - val_loss: 0.4846 - val_accuracy: 0.8293 - 44s/epoch - 20ms/step
# Epoch 26/30
# 2188/2188 - 44s - loss: 0.5323 - accuracy: 0.8038 - val_loss: 0.4733 - val_accuracy: 0.8287 - 44s/epoch - 20ms/step
# Epoch 27/30
# 2188/2188 - 44s - loss: 0.5257 - accuracy: 0.8054 - val_loss: 0.4765 - val_accuracy: 0.8267 - 44s/epoch - 20ms/step
# Epoch 28/30
# 2188/2188 - 44s - loss: 0.5192 - accuracy: 0.8086 - val_loss: 0.4241 - val_accuracy: 0.8502 - 44s/epoch - 20ms/step
# Epoch 29/30
# 2188/2188 - 44s - loss: 0.5091 - accuracy: 0.8129 - val_loss: 0.4417 - val_accuracy: 0.8538 - 44s/epoch - 20ms/step
# Epoch 30/30
# 2188/2188 - 44s - loss: 0.5008 - accuracy: 0.8158 - val_loss: 0.4428 - val_accuracy: 0.8446 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.4520 - accuracy: 0.8370
# 274/274 [==============================] - 3s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 1.3995 - accuracy: 0.6875
# 128/128 [==============================] - 1s 8ms/step
# 274/274 [==============================] - 2s 9ms/step
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_47 (LSTM)              (None, 126, 32)           5888
#
#  dropout_78 (Dropout)        (None, 126, 32)           0
#
#  lstm_48 (LSTM)              (None, 126, 32)           8320
#
#  dropout_79 (Dropout)        (None, 126, 32)           0
#
#  lstm_49 (LSTM)              (None, 126, 32)           8320
#
#  dropout_80 (Dropout)        (None, 126, 32)           0
#
#  lstm_50 (LSTM)              (None, 126, 32)           8320
#
#  dropout_81 (Dropout)        (None, 126, 32)           0
#
#  lstm_51 (LSTM)              (None, 126, 32)           8320
#
#  flatten_20 (Flatten)        (None, 4032)              0
#
#  dense_30 (Dense)            (None, 10)                40330
#
# =================================================================
# Total params: 79,498
# Trainable params: 79,498
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 2188/2188 - 48s - loss: 1.5435 - accuracy: 0.4353 - val_loss: 1.2209 - val_accuracy: 0.5659 - 48s/epoch - 22ms/step
# Epoch 2/30
# 2188/2188 - 42s - loss: 1.1955 - accuracy: 0.5630 - val_loss: 0.9944 - val_accuracy: 0.6351 - 42s/epoch - 19ms/step
# Epoch 3/30
# 2188/2188 - 44s - loss: 1.0569 - accuracy: 0.6121 - val_loss: 0.9988 - val_accuracy: 0.6398 - 44s/epoch - 20ms/step
# Epoch 4/30
# 2188/2188 - 44s - loss: 0.9824 - accuracy: 0.6408 - val_loss: 0.8284 - val_accuracy: 0.6943 - 44s/epoch - 20ms/step
# Epoch 5/30
# 2188/2188 - 42s - loss: 0.9232 - accuracy: 0.6620 - val_loss: 0.8293 - val_accuracy: 0.7003 - 42s/epoch - 19ms/step
# Epoch 6/30
# 2188/2188 - 43s - loss: 0.8730 - accuracy: 0.6803 - val_loss: 0.7315 - val_accuracy: 0.7317 - 43s/epoch - 20ms/step
# Epoch 7/30
# 2188/2188 - 43s - loss: 0.8302 - accuracy: 0.6956 - val_loss: 0.7417 - val_accuracy: 0.7328 - 43s/epoch - 20ms/step
# Epoch 8/30
# 2188/2188 - 42s - loss: 0.7987 - accuracy: 0.7062 - val_loss: 0.7608 - val_accuracy: 0.7278 - 42s/epoch - 19ms/step
# Epoch 9/30
# 2188/2188 - 43s - loss: 0.7720 - accuracy: 0.7179 - val_loss: 0.6528 - val_accuracy: 0.7667 - 43s/epoch - 19ms/step
# Epoch 10/30
# 2188/2188 - 43s - loss: 0.7383 - accuracy: 0.7300 - val_loss: 0.6745 - val_accuracy: 0.7489 - 43s/epoch - 20ms/step
# Epoch 11/30
# 2188/2188 - 43s - loss: 0.7183 - accuracy: 0.7361 - val_loss: 0.6242 - val_accuracy: 0.7767 - 43s/epoch - 20ms/step
# Epoch 12/30
# 2188/2188 - 43s - loss: 0.6911 - accuracy: 0.7471 - val_loss: 0.6190 - val_accuracy: 0.7743 - 43s/epoch - 20ms/step
# Epoch 13/30
# 2188/2188 - 42s - loss: 0.6778 - accuracy: 0.7518 - val_loss: 0.5757 - val_accuracy: 0.7915 - 42s/epoch - 19ms/step
# Epoch 14/30
# 2188/2188 - 43s - loss: 0.6612 - accuracy: 0.7591 - val_loss: 0.5685 - val_accuracy: 0.7927 - 43s/epoch - 20ms/step
# Epoch 15/30
# 2188/2188 - 42s - loss: 0.6420 - accuracy: 0.7648 - val_loss: 0.5301 - val_accuracy: 0.8081 - 42s/epoch - 19ms/step
# Epoch 16/30
# 2188/2188 - 42s - loss: 0.6279 - accuracy: 0.7693 - val_loss: 0.5526 - val_accuracy: 0.8051 - 42s/epoch - 19ms/step
# Epoch 17/30
# 2188/2188 - 43s - loss: 0.6144 - accuracy: 0.7743 - val_loss: 0.5479 - val_accuracy: 0.8040 - 43s/epoch - 20ms/step
# Epoch 18/30
# 2188/2188 - 42s - loss: 0.6024 - accuracy: 0.7789 - val_loss: 0.5063 - val_accuracy: 0.8170 - 42s/epoch - 19ms/step
# Epoch 19/30
# 2188/2188 - 42s - loss: 0.5876 - accuracy: 0.7845 - val_loss: 0.5096 - val_accuracy: 0.8174 - 42s/epoch - 19ms/step
# Epoch 20/30
# 2188/2188 - 42s - loss: 0.5836 - accuracy: 0.7851 - val_loss: 0.4782 - val_accuracy: 0.8278 - 42s/epoch - 19ms/step
# Epoch 21/30
# 2188/2188 - 43s - loss: 0.5708 - accuracy: 0.7905 - val_loss: 0.5212 - val_accuracy: 0.8105 - 43s/epoch - 20ms/step
# Epoch 22/30
# 2188/2188 - 43s - loss: 0.5636 - accuracy: 0.7928 - val_loss: 0.4988 - val_accuracy: 0.8173 - 43s/epoch - 20ms/step
# Epoch 23/30
# 2188/2188 - 43s - loss: 0.5496 - accuracy: 0.8006 - val_loss: 0.4929 - val_accuracy: 0.8225 - 43s/epoch - 20ms/step
# Epoch 24/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 6
#       4 else:
#       5     print('Start running lstm')
# ----> 6     run_lstm_5_fold_cross_validation()
#
# Cell In[136], line 7, in run_lstm_5_fold_cross_validation()
#       4     os.makedirs(path)
#       6 for i in range(0, 5):
# ----> 7     run_lstm(i)
#       8 copy_file = 'results/lstm_results/' + global_folder_name + '/' + 'copied_model.ipynb'
#       9 own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
#
# Cell In[134], line 23, in run_lstm(fold_index)
#      18 #model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy',
#      19 #              tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=10, average='macro',
#      20 #              threshold=0.5)])
#      22 model.summary()
# ---> 23 history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
#      24 model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')
#      26 history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:
