# %%
import numpy as np
import pandas as pd
import librosa
import os
import glob
import re
import seaborn as sn
import matplotlib.pyplot as plt
import scipy
import time
import collections
import keras
import random
from keras.utils import np_utils
from keras.layers import MaxPooling1D, Conv1D, Conv2D, MaxPooling2D, GlobalAveragePooling2D, LSTM, ELU, Bidirectional, Attention
from keras.layers import Dense, Dropout, Activation, Flatten, CuDNNLSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import tensorflow as tf
import pickle
from keras.utils.vis_utils import plot_model
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import keras_tuner
from keras import backend as K
import shutil
import os
import tensorflow_addons as tfa
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn import metrics

# %% [markdown]
# ### Global variables

# %%
global_model_type = 'lstm'
global_folder_name = 'lstm_base_model_new_dr_lr'
file_suffix = 'weyo1'
global_batch_size = 32
global_epochs = 50
global_learning_rate = 0.0001
own_file_path = os.getcwd() 
global_hyperparameter_folder_name = 'lstm_new_lr_12_05'  #lstm_filter_size_dropout1' #'cnn_filter_size_dropout'
optimized_model = False # Om satt till True körs den hyperparameter tune:ade modellen. Annars base_model
# Out:
#   Cell In[24], line 8
#     global_hyperparameter_folder_name = 'lstm_new_lr_12_05' +  #lstm_filter_size_dropout1' #'cnn_filter_size_dropout'
#                                                                ^
# SyntaxError: invalid syntax

# %%
def instrument_code(filename):
    """
    Function that takes in a filename and returns instrument based on naming convention
    """
    # Synth lead borttagen. id = 9
    class_names=['bass', 'brass', 'flute', 'guitar', 
             'keyboard', 'mallet', 'organ', 'reed', 
             'string', 'vocal']
    
    for name in class_names:
        if name in filename:
            return class_names.index(name)
    else:
        return None

# %% [markdown]
# ## Get data

# %%
def get_data_from_file(file):
    with open(file, "rb") as f:
        X_train_full  = pickle.load(f)

    X_train = []
    y_train = []

    for (key, value) in X_train_full:
        X_train.append(value)
        y_train.append(instrument_code(key))

    X_train_numpy = np.array(X_train)
    y_train_numpy = np.array(y_train)
    return (X_train_numpy, y_train_numpy)

# %%
def get_old_test_data(file):
    with open(file, 'rb') as f:
        old_X_test_full = pickle.load(f)

    old_X_test = []
    old_y_test = []

    for(key, value) in old_X_test_full.items():
        #temporal_value = np.mean(value, axis = 1)
        old_X_test.append(value)
        old_y_test.append(instrument_code(key))
        
    old_y_test_numpy = np.asarray(old_y_test)
    old_X_test_numpy = np.asarray(old_X_test)
    return (old_X_test_numpy, old_y_test_numpy)

# %% [markdown]
# ### Calculate metrics

# %%
def calc_metrics(y_true, y_pred):
    print(metrics.classification_report(y_true, y_pred, digits=3))

# %%
def hyperparameter_cnn_model(hp):
    """
    Function that builds a CNN model with optimized hyperparameters including filter size and dropout rate
    """

    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same', input_shape=(126, 13, 1)))
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))

    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_2', values = [32, 64, 128, 256]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def hyperparameter_lstm_model(hp):
    """
    Function that builds a LSTM model with optimized hyperparameters including filter size and dropout rate
    """
    
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_cnn_model():    
    input_shape = (126, 13, 1)
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_cnn_model():
    input_shape = (126, 13, 1)
    dropout_1 = 0.2 
    conv_2_filters_1 = 128
    conv_2_filters_2 = 128

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_2,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(dropout_1))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_lstm_model():
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    lstm_dropout_rate = 0.25
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_lstm_model():
    dropout_lstm = 0.3
    lstm_layer_units_1 = 32
    lstm_layer_units_2 = 128
    model = Sequential()
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def plot_acc_loss(history, acc_file_path, loss_file_path):
    # Taget från https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    # summarize history for accuracy
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(acc_file_path)
    plt.show()

    # summarize history for loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(loss_file_path)
    plt.show()

# %%
    
def plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path):    
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    result = confusion_matrix(y_test, y_prediction , normalize='pred')

    df_cm = pd.DataFrame(result, index = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]],
                    columns = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]])

    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig(confusion_matrix_file_path)
    plt.show()

# %%
def run_cnn(fold_index):

    old_test_file = 'CustomDataFull/testdata2000.pkl'

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/cnn_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

    if optimized_model:
        model = build_optimized_cnn_model()
    else:
        model = build_cnn_model()
        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)

    print("\n\ny_test : ", y_test)
    print("\n\ny_prediction : ", y_prediction)

    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)

    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores:\n' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata:\n' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %%
def run_lstm(fold_index):
    old_test_file = 'CustomDataFull/testdata2000.pkl'
    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/lstm_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)


    if optimized_model:
        model = build_optimized_lstm_model()
    else:
        model = build_lstm_model()

        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    #model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy', 
    #              tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=10, average='macro',
    #              threshold=0.5)])
    
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)
    
    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores: ' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata: ' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %% [markdown]
# ### Hyperparameter tuning

# %%
def tune_cnn():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_cnn_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
        f.write(str(tuner.results_summary()) + '\n')

    tuner.results_summary()

    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'cnn-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %%
def tune_lstm():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_lstm_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
    
    tuner.results_summary()
    
    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'lstm-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %% [markdown]
# ### Run 5-fold cross validation

# %%
def run_cnn_5_fold_cross_validation():
    path = 'results/cnn_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)

    copy_file = 'results/cnn_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_cnn(i)

# %%
def run_lstm_5_fold_cross_validation():
    path = 'results/lstm_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)
    
    copy_file = 'results/lstm_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_lstm(i)

# %%
if (global_model_type == 'cnn'):
    print('Start running cnn')
    run_cnn_5_fold_cross_validation()
elif (global_model_type == 'lstm'):
    print('Start running lstm')
    run_lstm_5_fold_cross_validation()
elif (global_model_type == 'tune_cnn'):
    print('Start tuning cnn')
    tune_cnn()
elif (global_model_type == 'tune_lstm'):
    print('Start tuning lstm')
    tune_lstm()
# Out:
# Start running lstm
# 2023-05-12 13:41:23.831345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:24.353692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:24.353893: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:24.377372: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-12 13:41:24.389287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:24.389515: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:24.389697: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:29.178455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:29.194050: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:29.194258: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-12 13:41:29.202551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4162 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:26:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 126, 32)           5888
#
#  dropout (Dropout)           (None, 126, 32)           0
#
#  lstm_1 (LSTM)               (None, 126, 32)           8320
#
#  dropout_1 (Dropout)         (None, 126, 32)           0
#
#  lstm_2 (LSTM)               (None, 126, 32)           8320
#
#  dropout_2 (Dropout)         (None, 126, 32)           0
#
#  lstm_3 (LSTM)               (None, 126, 128)          82432
#
#  dropout_3 (Dropout)         (None, 126, 128)          0
#
#  lstm_4 (LSTM)               (None, 126, 128)          131584
#
#  flatten (Flatten)           (None, 16128)             0
#
#  dense (Dense)               (None, 512)               8258048
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,499,722
# Trainable params: 8,499,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-12 13:41:41.654904: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-05-12 13:41:48.395055: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f14540e9e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-12 13:41:48.395087: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 SUPER, Compute Capability 7.5
# 2023-05-12 13:41:48.599879: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-12 13:41:50.305931: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2188/2188 - 67s - loss: 1.7206 - accuracy: 0.3632 - val_loss: 1.4159 - val_accuracy: 0.4863 - 67s/epoch - 31ms/step
# Epoch 2/50
# 2188/2188 - 47s - loss: 1.3781 - accuracy: 0.5016 - val_loss: 1.1603 - val_accuracy: 0.5879 - 47s/epoch - 21ms/step
# Epoch 3/50
# 2188/2188 - 48s - loss: 1.2082 - accuracy: 0.5613 - val_loss: 1.0453 - val_accuracy: 0.6265 - 48s/epoch - 22ms/step
# Epoch 4/50
# 2188/2188 - 47s - loss: 1.0868 - accuracy: 0.6050 - val_loss: 0.9187 - val_accuracy: 0.6730 - 47s/epoch - 21ms/step
# Epoch 5/50
# 2188/2188 - 47s - loss: 0.9962 - accuracy: 0.6377 - val_loss: 0.8458 - val_accuracy: 0.7018 - 47s/epoch - 22ms/step
# Epoch 6/50
# 2188/2188 - 46s - loss: 0.9204 - accuracy: 0.6660 - val_loss: 0.8357 - val_accuracy: 0.6974 - 46s/epoch - 21ms/step
# Epoch 7/50
# 2188/2188 - 47s - loss: 0.8542 - accuracy: 0.6870 - val_loss: 0.7100 - val_accuracy: 0.7413 - 47s/epoch - 21ms/step
# Epoch 8/50
# 2188/2188 - 47s - loss: 0.8108 - accuracy: 0.7055 - val_loss: 0.6680 - val_accuracy: 0.7654 - 47s/epoch - 21ms/step
# Epoch 9/50
# 2188/2188 - 47s - loss: 0.7603 - accuracy: 0.7231 - val_loss: 0.6007 - val_accuracy: 0.7866 - 47s/epoch - 21ms/step
# Epoch 10/50
# 2188/2188 - 47s - loss: 0.7146 - accuracy: 0.7379 - val_loss: 0.5772 - val_accuracy: 0.7907 - 47s/epoch - 21ms/step
# Epoch 11/50
# 2188/2188 - 47s - loss: 0.6874 - accuracy: 0.7494 - val_loss: 0.5413 - val_accuracy: 0.8080 - 47s/epoch - 21ms/step
# Epoch 12/50
# 2188/2188 - 48s - loss: 0.6478 - accuracy: 0.7628 - val_loss: 0.5099 - val_accuracy: 0.8157 - 48s/epoch - 22ms/step
# Epoch 13/50
# 2188/2188 - 48s - loss: 0.6220 - accuracy: 0.7712 - val_loss: 0.4752 - val_accuracy: 0.8303 - 48s/epoch - 22ms/step
# Epoch 14/50
# 2188/2188 - 48s - loss: 0.5973 - accuracy: 0.7822 - val_loss: 0.4953 - val_accuracy: 0.8187 - 48s/epoch - 22ms/step
# Epoch 15/50
# 2188/2188 - 47s - loss: 0.5720 - accuracy: 0.7884 - val_loss: 0.4356 - val_accuracy: 0.8429 - 47s/epoch - 22ms/step
# Epoch 16/50
# 2188/2188 - 47s - loss: 0.5473 - accuracy: 0.7985 - val_loss: 0.4351 - val_accuracy: 0.8415 - 47s/epoch - 22ms/step
# Epoch 17/50
# 2188/2188 - 47s - loss: 0.5299 - accuracy: 0.8055 - val_loss: 0.4158 - val_accuracy: 0.8522 - 47s/epoch - 22ms/step
# Epoch 18/50
# 2188/2188 - 47s - loss: 0.5118 - accuracy: 0.8131 - val_loss: 0.3936 - val_accuracy: 0.8579 - 47s/epoch - 22ms/step
# Epoch 19/50
# 2188/2188 - 49s - loss: 0.4916 - accuracy: 0.8181 - val_loss: 0.3681 - val_accuracy: 0.8681 - 49s/epoch - 22ms/step
# Epoch 20/50
# 2188/2188 - 48s - loss: 0.4775 - accuracy: 0.8246 - val_loss: 0.3516 - val_accuracy: 0.8771 - 48s/epoch - 22ms/step
# Epoch 21/50
# 2188/2188 - 47s - loss: 0.4579 - accuracy: 0.8314 - val_loss: 0.3517 - val_accuracy: 0.8758 - 47s/epoch - 21ms/step
# Epoch 22/50
# 2188/2188 - 47s - loss: 0.4507 - accuracy: 0.8336 - val_loss: 0.3383 - val_accuracy: 0.8823 - 47s/epoch - 21ms/step
# Epoch 23/50
# 2188/2188 - 48s - loss: 0.4358 - accuracy: 0.8373 - val_loss: 0.3713 - val_accuracy: 0.8630 - 48s/epoch - 22ms/step
# Epoch 24/50
# 2188/2188 - 48s - loss: 0.4247 - accuracy: 0.8427 - val_loss: 0.3146 - val_accuracy: 0.8854 - 48s/epoch - 22ms/step
# Epoch 25/50
# 2188/2188 - 48s - loss: 0.4130 - accuracy: 0.8491 - val_loss: 0.3415 - val_accuracy: 0.8779 - 48s/epoch - 22ms/step
# Epoch 26/50
# 2188/2188 - 49s - loss: 0.4005 - accuracy: 0.8517 - val_loss: 0.3021 - val_accuracy: 0.8921 - 49s/epoch - 22ms/step
# Epoch 27/50
# 2188/2188 - 48s - loss: 0.3885 - accuracy: 0.8577 - val_loss: 0.2856 - val_accuracy: 0.8975 - 48s/epoch - 22ms/step
# Epoch 28/50
# 2188/2188 - 47s - loss: 0.3765 - accuracy: 0.8613 - val_loss: 0.2883 - val_accuracy: 0.8984 - 47s/epoch - 21ms/step
# Epoch 29/50
# 2188/2188 - 47s - loss: 0.3720 - accuracy: 0.8619 - val_loss: 0.2762 - val_accuracy: 0.9022 - 47s/epoch - 22ms/step
# Epoch 30/50
# 2188/2188 - 48s - loss: 0.3624 - accuracy: 0.8663 - val_loss: 0.2683 - val_accuracy: 0.9063 - 48s/epoch - 22ms/step
# Epoch 31/50
# 2188/2188 - 47s - loss: 0.3564 - accuracy: 0.8692 - val_loss: 0.2679 - val_accuracy: 0.9072 - 47s/epoch - 21ms/step
# Epoch 32/50
# 2188/2188 - 47s - loss: 0.3440 - accuracy: 0.8726 - val_loss: 0.2508 - val_accuracy: 0.9121 - 47s/epoch - 22ms/step
# Epoch 33/50
# 2188/2188 - 47s - loss: 0.3337 - accuracy: 0.8769 - val_loss: 0.2388 - val_accuracy: 0.9154 - 47s/epoch - 21ms/step
# Epoch 34/50
# 2188/2188 - 46s - loss: 0.3273 - accuracy: 0.8791 - val_loss: 0.2784 - val_accuracy: 0.8985 - 46s/epoch - 21ms/step
# Epoch 35/50
# 2188/2188 - 47s - loss: 0.3223 - accuracy: 0.8808 - val_loss: 0.2479 - val_accuracy: 0.9112 - 47s/epoch - 22ms/step
# Epoch 36/50
# 2188/2188 - 46s - loss: 0.3127 - accuracy: 0.8837 - val_loss: 0.2531 - val_accuracy: 0.9105 - 46s/epoch - 21ms/step
# Epoch 37/50
# 2188/2188 - 47s - loss: 0.3078 - accuracy: 0.8858 - val_loss: 0.2346 - val_accuracy: 0.9175 - 47s/epoch - 21ms/step
# Epoch 38/50
# 2188/2188 - 46s - loss: 0.3013 - accuracy: 0.8883 - val_loss: 0.2190 - val_accuracy: 0.9235 - 46s/epoch - 21ms/step
# Epoch 39/50
# 2188/2188 - 47s - loss: 0.3010 - accuracy: 0.8909 - val_loss: 0.2304 - val_accuracy: 0.9199 - 47s/epoch - 21ms/step
# Epoch 40/50
# 2188/2188 - 47s - loss: 0.2933 - accuracy: 0.8910 - val_loss: 0.2260 - val_accuracy: 0.9216 - 47s/epoch - 22ms/step
# Epoch 41/50
# 2188/2188 - 46s - loss: 0.2875 - accuracy: 0.8932 - val_loss: 0.2151 - val_accuracy: 0.9274 - 46s/epoch - 21ms/step
# Epoch 42/50
# 2188/2188 - 46s - loss: 0.2837 - accuracy: 0.8954 - val_loss: 0.2156 - val_accuracy: 0.9257 - 46s/epoch - 21ms/step
# Epoch 43/50
# 2188/2188 - 46s - loss: 0.2777 - accuracy: 0.8978 - val_loss: 0.2053 - val_accuracy: 0.9314 - 46s/epoch - 21ms/step
# Epoch 44/50
# 2188/2188 - 47s - loss: 0.2711 - accuracy: 0.8993 - val_loss: 0.2042 - val_accuracy: 0.9305 - 47s/epoch - 21ms/step
# Epoch 45/50
# 2188/2188 - 48s - loss: 0.2652 - accuracy: 0.9013 - val_loss: 0.2426 - val_accuracy: 0.9174 - 48s/epoch - 22ms/step
# Epoch 46/50
# 2188/2188 - 48s - loss: 0.2622 - accuracy: 0.9036 - val_loss: 0.2027 - val_accuracy: 0.9318 - 48s/epoch - 22ms/step
# Epoch 47/50
# 2188/2188 - 48s - loss: 0.2623 - accuracy: 0.9041 - val_loss: 0.1935 - val_accuracy: 0.9339 - 48s/epoch - 22ms/step
# Epoch 48/50
# 2188/2188 - 46s - loss: 0.2544 - accuracy: 0.9057 - val_loss: 0.1926 - val_accuracy: 0.9366 - 46s/epoch - 21ms/step
# Epoch 49/50
# 2188/2188 - 47s - loss: 0.2529 - accuracy: 0.9058 - val_loss: 0.1873 - val_accuracy: 0.9346 - 47s/epoch - 22ms/step
# Epoch 50/50
# 2188/2188 - 45s - loss: 0.2482 - accuracy: 0.9072 - val_loss: 0.1905 - val_accuracy: 0.9373 - 45s/epoch - 21ms/step
# 274/274 [==============================] - 3s 10ms/step - loss: 0.1912 - accuracy: 0.9354
# 274/274 [==============================] - 4s 10ms/step
# 128/128 [==============================] - 1s 10ms/step - loss: 2.3368 - accuracy: 0.6790
# 128/128 [==============================] - 1s 8ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 126, 32)           5888
#
#  dropout_5 (Dropout)         (None, 126, 32)           0
#
#  lstm_6 (LSTM)               (None, 126, 32)           8320
#
#  dropout_6 (Dropout)         (None, 126, 32)           0
#
#  lstm_7 (LSTM)               (None, 126, 32)           8320
#
#  dropout_7 (Dropout)         (None, 126, 32)           0
#
#  lstm_8 (LSTM)               (None, 126, 128)          82432
#
#  dropout_8 (Dropout)         (None, 126, 128)          0
#
#  lstm_9 (LSTM)               (None, 126, 128)          131584
#
#  flatten_1 (Flatten)         (None, 16128)             0
#
#  dense_2 (Dense)             (None, 512)               8258048
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,499,722
# Trainable params: 8,499,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 54s - loss: 1.7680 - accuracy: 0.3436 - val_loss: 1.4181 - val_accuracy: 0.4894 - 54s/epoch - 25ms/step
# Epoch 2/50
# 2188/2188 - 47s - loss: 1.4096 - accuracy: 0.4883 - val_loss: 1.2128 - val_accuracy: 0.5666 - 47s/epoch - 22ms/step
# Epoch 3/50
# 2188/2188 - 47s - loss: 1.2361 - accuracy: 0.5525 - val_loss: 1.0428 - val_accuracy: 0.6376 - 47s/epoch - 21ms/step
# Epoch 4/50
# 2188/2188 - 48s - loss: 1.1030 - accuracy: 0.6017 - val_loss: 0.9300 - val_accuracy: 0.6614 - 48s/epoch - 22ms/step
# Epoch 5/50
# 2188/2188 - 49s - loss: 1.0095 - accuracy: 0.6362 - val_loss: 0.8364 - val_accuracy: 0.6910 - 49s/epoch - 22ms/step
# Epoch 6/50
# 2188/2188 - 47s - loss: 0.9275 - accuracy: 0.6627 - val_loss: 0.7964 - val_accuracy: 0.7138 - 47s/epoch - 22ms/step
# Epoch 7/50
# 2188/2188 - 48s - loss: 0.8633 - accuracy: 0.6868 - val_loss: 0.6942 - val_accuracy: 0.7525 - 48s/epoch - 22ms/step
# Epoch 8/50
# 2188/2188 - 48s - loss: 0.8052 - accuracy: 0.7055 - val_loss: 0.6801 - val_accuracy: 0.7519 - 48s/epoch - 22ms/step
# Epoch 9/50
# 2188/2188 - 49s - loss: 0.7639 - accuracy: 0.7211 - val_loss: 0.6158 - val_accuracy: 0.7773 - 49s/epoch - 22ms/step
# Epoch 10/50
# 2188/2188 - 47s - loss: 0.7174 - accuracy: 0.7372 - val_loss: 0.5618 - val_accuracy: 0.7927 - 47s/epoch - 22ms/step
# Epoch 11/50
# 2188/2188 - 47s - loss: 0.6812 - accuracy: 0.7511 - val_loss: 0.5219 - val_accuracy: 0.8033 - 47s/epoch - 21ms/step
# Epoch 12/50
# 2188/2188 - 49s - loss: 0.6490 - accuracy: 0.7612 - val_loss: 0.4940 - val_accuracy: 0.8214 - 49s/epoch - 23ms/step
# Epoch 13/50
# 2188/2188 - 48s - loss: 0.6195 - accuracy: 0.7725 - val_loss: 0.4745 - val_accuracy: 0.8282 - 48s/epoch - 22ms/step
# Epoch 14/50
# 2188/2188 - 48s - loss: 0.5936 - accuracy: 0.7816 - val_loss: 0.4567 - val_accuracy: 0.8384 - 48s/epoch - 22ms/step
# Epoch 15/50
# 2188/2188 - 48s - loss: 0.5664 - accuracy: 0.7899 - val_loss: 0.4478 - val_accuracy: 0.8346 - 48s/epoch - 22ms/step
# Epoch 16/50
# 2188/2188 - 48s - loss: 0.5446 - accuracy: 0.7989 - val_loss: 0.4213 - val_accuracy: 0.8395 - 48s/epoch - 22ms/step
# Epoch 17/50
# 2188/2188 - 48s - loss: 0.5242 - accuracy: 0.8060 - val_loss: 0.4009 - val_accuracy: 0.8480 - 48s/epoch - 22ms/step
# Epoch 18/50
# 2188/2188 - 47s - loss: 0.5090 - accuracy: 0.8109 - val_loss: 0.3677 - val_accuracy: 0.8670 - 47s/epoch - 21ms/step
# Epoch 19/50
# 2188/2188 - 47s - loss: 0.4876 - accuracy: 0.8196 - val_loss: 0.4017 - val_accuracy: 0.8546 - 47s/epoch - 21ms/step
# Epoch 20/50
# 2188/2188 - 48s - loss: 0.4657 - accuracy: 0.8289 - val_loss: 0.3474 - val_accuracy: 0.8762 - 48s/epoch - 22ms/step
# Epoch 21/50
# 2188/2188 - 48s - loss: 0.4498 - accuracy: 0.8334 - val_loss: 0.3350 - val_accuracy: 0.8790 - 48s/epoch - 22ms/step
# Epoch 22/50
# 2188/2188 - 48s - loss: 0.4384 - accuracy: 0.8370 - val_loss: 0.3190 - val_accuracy: 0.8838 - 48s/epoch - 22ms/step
# Epoch 23/50
# 2188/2188 - 47s - loss: 0.4216 - accuracy: 0.8437 - val_loss: 0.3056 - val_accuracy: 0.8923 - 47s/epoch - 21ms/step
# Epoch 24/50
# 2188/2188 - 49s - loss: 0.4164 - accuracy: 0.8446 - val_loss: 0.3148 - val_accuracy: 0.8832 - 49s/epoch - 22ms/step
# Epoch 25/50
# 2188/2188 - 48s - loss: 0.4010 - accuracy: 0.8510 - val_loss: 0.2918 - val_accuracy: 0.8982 - 48s/epoch - 22ms/step
# Epoch 26/50
# 2188/2188 - 49s - loss: 0.3889 - accuracy: 0.8542 - val_loss: 0.2851 - val_accuracy: 0.9005 - 49s/epoch - 22ms/step
# Epoch 27/50
# 2188/2188 - 48s - loss: 0.3806 - accuracy: 0.8582 - val_loss: 0.2962 - val_accuracy: 0.8909 - 48s/epoch - 22ms/step
# Epoch 28/50
# 2188/2188 - 48s - loss: 0.3660 - accuracy: 0.8637 - val_loss: 0.2600 - val_accuracy: 0.9082 - 48s/epoch - 22ms/step
# Epoch 29/50
# 2188/2188 - 48s - loss: 0.3609 - accuracy: 0.8652 - val_loss: 0.2727 - val_accuracy: 0.9040 - 48s/epoch - 22ms/step
# Epoch 30/50
# 2188/2188 - 47s - loss: 0.3527 - accuracy: 0.8706 - val_loss: 0.2793 - val_accuracy: 0.9029 - 47s/epoch - 22ms/step
# Epoch 31/50
# 2188/2188 - 49s - loss: 0.3412 - accuracy: 0.8719 - val_loss: 0.2344 - val_accuracy: 0.9185 - 49s/epoch - 22ms/step
# Epoch 32/50
# 2188/2188 - 49s - loss: 0.3383 - accuracy: 0.8727 - val_loss: 0.2351 - val_accuracy: 0.9171 - 49s/epoch - 22ms/step
# Epoch 33/50
# 2188/2188 - 47s - loss: 0.3268 - accuracy: 0.8794 - val_loss: 0.2337 - val_accuracy: 0.9203 - 47s/epoch - 22ms/step
# Epoch 34/50
# 2188/2188 - 49s - loss: 0.3192 - accuracy: 0.8818 - val_loss: 0.2384 - val_accuracy: 0.9165 - 49s/epoch - 22ms/step
# Epoch 35/50
# 2188/2188 - 47s - loss: 0.3124 - accuracy: 0.8837 - val_loss: 0.2399 - val_accuracy: 0.9197 - 47s/epoch - 21ms/step
# Epoch 36/50
# 2188/2188 - 47s - loss: 0.3051 - accuracy: 0.8857 - val_loss: 0.2219 - val_accuracy: 0.9247 - 47s/epoch - 21ms/step
# Epoch 37/50
# 2188/2188 - 47s - loss: 0.2972 - accuracy: 0.8888 - val_loss: 0.2275 - val_accuracy: 0.9201 - 47s/epoch - 22ms/step
# Epoch 38/50
# 2188/2188 - 48s - loss: 0.2951 - accuracy: 0.8915 - val_loss: 0.2462 - val_accuracy: 0.9177 - 48s/epoch - 22ms/step
# Epoch 39/50
# 2188/2188 - 48s - loss: 0.2848 - accuracy: 0.8947 - val_loss: 0.2147 - val_accuracy: 0.9258 - 48s/epoch - 22ms/step
# Epoch 40/50
# 2188/2188 - 48s - loss: 0.2826 - accuracy: 0.8955 - val_loss: 0.2312 - val_accuracy: 0.9222 - 48s/epoch - 22ms/step
# Epoch 41/50
# 2188/2188 - 47s - loss: 0.2768 - accuracy: 0.8972 - val_loss: 0.2154 - val_accuracy: 0.9247 - 47s/epoch - 22ms/step
# Epoch 42/50
# 2188/2188 - 48s - loss: 0.2726 - accuracy: 0.8985 - val_loss: 0.1999 - val_accuracy: 0.9345 - 48s/epoch - 22ms/step
# Epoch 43/50
# 2188/2188 - 48s - loss: 0.2704 - accuracy: 0.8992 - val_loss: 0.2152 - val_accuracy: 0.9263 - 48s/epoch - 22ms/step
# Epoch 44/50
# 2188/2188 - 48s - loss: 0.2627 - accuracy: 0.9029 - val_loss: 0.1941 - val_accuracy: 0.9359 - 48s/epoch - 22ms/step
# Epoch 45/50
# 2188/2188 - 47s - loss: 0.2624 - accuracy: 0.9023 - val_loss: 0.2047 - val_accuracy: 0.9303 - 47s/epoch - 22ms/step
# Epoch 46/50
# 2188/2188 - 48s - loss: 0.2469 - accuracy: 0.9082 - val_loss: 0.2000 - val_accuracy: 0.9303 - 48s/epoch - 22ms/step
# Epoch 47/50
# 2188/2188 - 49s - loss: 0.2523 - accuracy: 0.9060 - val_loss: 0.2097 - val_accuracy: 0.9319 - 49s/epoch - 22ms/step
# Epoch 48/50
# 2188/2188 - 49s - loss: 0.2485 - accuracy: 0.9075 - val_loss: 0.1899 - val_accuracy: 0.9373 - 49s/epoch - 22ms/step
# Epoch 49/50
# 2188/2188 - 49s - loss: 0.2418 - accuracy: 0.9109 - val_loss: 0.2001 - val_accuracy: 0.9336 - 49s/epoch - 22ms/step
# Epoch 50/50
# 2188/2188 - 49s - loss: 0.2382 - accuracy: 0.9119 - val_loss: 0.1834 - val_accuracy: 0.9394 - 49s/epoch - 22ms/step
# 274/274 [==============================] - 3s 9ms/step - loss: 0.1782 - accuracy: 0.9402
# 274/274 [==============================] - 3s 9ms/step
# 128/128 [==============================] - 1s 10ms/step - loss: 2.2959 - accuracy: 0.6841
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 3s 10ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 126, 32)           5888
#
#  dropout_10 (Dropout)        (None, 126, 32)           0
#
#  lstm_11 (LSTM)              (None, 126, 32)           8320
#
#  dropout_11 (Dropout)        (None, 126, 32)           0
#
#  lstm_12 (LSTM)              (None, 126, 32)           8320
#
#  dropout_12 (Dropout)        (None, 126, 32)           0
#
#  lstm_13 (LSTM)              (None, 126, 128)          82432
#
#  dropout_13 (Dropout)        (None, 126, 128)          0
#
#  lstm_14 (LSTM)              (None, 126, 128)          131584
#
#  flatten_2 (Flatten)         (None, 16128)             0
#
#  dense_4 (Dense)             (None, 512)               8258048
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,499,722
# Trainable params: 8,499,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 55s - loss: 1.6721 - accuracy: 0.3865 - val_loss: 1.3189 - val_accuracy: 0.5190 - 55s/epoch - 25ms/step
# Epoch 2/50
# 2188/2188 - 48s - loss: 1.3406 - accuracy: 0.5134 - val_loss: 1.1177 - val_accuracy: 0.5914 - 48s/epoch - 22ms/step
# Epoch 3/50
# 2188/2188 - 48s - loss: 1.1866 - accuracy: 0.5679 - val_loss: 0.9959 - val_accuracy: 0.6525 - 48s/epoch - 22ms/step
# Epoch 4/50
# 2188/2188 - 47s - loss: 1.0793 - accuracy: 0.6106 - val_loss: 0.9011 - val_accuracy: 0.6695 - 47s/epoch - 21ms/step
# Epoch 5/50
# 2188/2188 - 49s - loss: 0.9904 - accuracy: 0.6387 - val_loss: 0.8028 - val_accuracy: 0.7097 - 49s/epoch - 22ms/step
# Epoch 6/50
# 2188/2188 - 49s - loss: 0.9188 - accuracy: 0.6618 - val_loss: 0.7410 - val_accuracy: 0.7266 - 49s/epoch - 22ms/step
# Epoch 7/50
# 2188/2188 - 47s - loss: 0.8497 - accuracy: 0.6870 - val_loss: 0.6948 - val_accuracy: 0.7471 - 47s/epoch - 22ms/step
# Epoch 8/50
# 2188/2188 - 48s - loss: 0.7981 - accuracy: 0.7064 - val_loss: 0.6389 - val_accuracy: 0.7667 - 48s/epoch - 22ms/step
# Epoch 9/50
# 2188/2188 - 50s - loss: 0.7520 - accuracy: 0.7225 - val_loss: 0.6062 - val_accuracy: 0.7746 - 50s/epoch - 23ms/step
# Epoch 10/50
# 2188/2188 - 48s - loss: 0.7103 - accuracy: 0.7386 - val_loss: 0.5493 - val_accuracy: 0.8005 - 48s/epoch - 22ms/step
# Epoch 11/50
# 2188/2188 - 50s - loss: 0.6766 - accuracy: 0.7487 - val_loss: 0.5238 - val_accuracy: 0.8104 - 50s/epoch - 23ms/step
# Epoch 12/50
# 2188/2188 - 48s - loss: 0.6394 - accuracy: 0.7636 - val_loss: 0.5019 - val_accuracy: 0.8160 - 48s/epoch - 22ms/step
# Epoch 13/50
# 2188/2188 - 48s - loss: 0.6154 - accuracy: 0.7726 - val_loss: 0.4956 - val_accuracy: 0.8241 - 48s/epoch - 22ms/step
# Epoch 14/50
# 2188/2188 - 50s - loss: 0.5878 - accuracy: 0.7808 - val_loss: 0.4430 - val_accuracy: 0.8413 - 50s/epoch - 23ms/step
# Epoch 15/50
# 2188/2188 - 49s - loss: 0.5622 - accuracy: 0.7898 - val_loss: 0.4345 - val_accuracy: 0.8443 - 49s/epoch - 22ms/step
# Epoch 16/50
# 2188/2188 - 48s - loss: 0.5436 - accuracy: 0.7985 - val_loss: 0.4079 - val_accuracy: 0.8512 - 48s/epoch - 22ms/step
# Epoch 17/50
# 2188/2188 - 48s - loss: 0.5210 - accuracy: 0.8062 - val_loss: 0.3700 - val_accuracy: 0.8675 - 48s/epoch - 22ms/step
# Epoch 18/50
# 2188/2188 - 49s - loss: 0.5028 - accuracy: 0.8146 - val_loss: 0.3753 - val_accuracy: 0.8670 - 49s/epoch - 23ms/step
# Epoch 19/50
# 2188/2188 - 49s - loss: 0.4869 - accuracy: 0.8182 - val_loss: 0.3592 - val_accuracy: 0.8721 - 49s/epoch - 23ms/step
# Epoch 20/50
# 2188/2188 - 48s - loss: 0.4693 - accuracy: 0.8242 - val_loss: 0.3424 - val_accuracy: 0.8775 - 48s/epoch - 22ms/step
# Epoch 21/50
# 2188/2188 - 47s - loss: 0.4518 - accuracy: 0.8307 - val_loss: 0.3647 - val_accuracy: 0.8680 - 47s/epoch - 21ms/step
# Epoch 22/50
# 2188/2188 - 48s - loss: 0.4393 - accuracy: 0.8367 - val_loss: 0.3232 - val_accuracy: 0.8864 - 48s/epoch - 22ms/step
# Epoch 23/50
# 2188/2188 - 48s - loss: 0.4264 - accuracy: 0.8406 - val_loss: 0.3323 - val_accuracy: 0.8813 - 48s/epoch - 22ms/step
# Epoch 24/50
# 2188/2188 - 49s - loss: 0.4122 - accuracy: 0.8445 - val_loss: 0.3105 - val_accuracy: 0.8898 - 49s/epoch - 22ms/step
# Epoch 25/50
# 2188/2188 - 52s - loss: 0.4060 - accuracy: 0.8492 - val_loss: 0.3019 - val_accuracy: 0.8919 - 52s/epoch - 24ms/step
# Epoch 26/50
# 2188/2188 - 52s - loss: 0.3968 - accuracy: 0.8526 - val_loss: 0.2849 - val_accuracy: 0.9018 - 52s/epoch - 24ms/step
# Epoch 27/50
# 2188/2188 - 52s - loss: 0.3837 - accuracy: 0.8568 - val_loss: 0.2797 - val_accuracy: 0.9017 - 52s/epoch - 24ms/step
# Epoch 28/50
# 2188/2188 - 52s - loss: 0.3759 - accuracy: 0.8583 - val_loss: 0.2684 - val_accuracy: 0.9055 - 52s/epoch - 24ms/step
# Epoch 29/50
# 2188/2188 - 52s - loss: 0.3615 - accuracy: 0.8655 - val_loss: 0.2781 - val_accuracy: 0.9008 - 52s/epoch - 24ms/step
# Epoch 30/50
# 2188/2188 - 52s - loss: 0.3554 - accuracy: 0.8674 - val_loss: 0.2563 - val_accuracy: 0.9142 - 52s/epoch - 24ms/step
# Epoch 31/50
# 2188/2188 - 52s - loss: 0.3436 - accuracy: 0.8692 - val_loss: 0.2789 - val_accuracy: 0.9005 - 52s/epoch - 24ms/step
# Epoch 32/50
# 2188/2188 - 52s - loss: 0.3382 - accuracy: 0.8736 - val_loss: 0.2487 - val_accuracy: 0.9107 - 52s/epoch - 24ms/step
# Epoch 33/50
# 2188/2188 - 52s - loss: 0.3291 - accuracy: 0.8778 - val_loss: 0.2330 - val_accuracy: 0.9191 - 52s/epoch - 24ms/step
# Epoch 34/50
# 2188/2188 - 52s - loss: 0.3214 - accuracy: 0.8786 - val_loss: 0.2387 - val_accuracy: 0.9168 - 52s/epoch - 24ms/step
# Epoch 35/50
# 2188/2188 - 52s - loss: 0.3181 - accuracy: 0.8825 - val_loss: 0.2272 - val_accuracy: 0.9221 - 52s/epoch - 24ms/step
# Epoch 36/50
# 2188/2188 - 52s - loss: 0.3069 - accuracy: 0.8854 - val_loss: 0.2160 - val_accuracy: 0.9286 - 52s/epoch - 24ms/step
# Epoch 37/50
# 2188/2188 - 52s - loss: 0.3044 - accuracy: 0.8851 - val_loss: 0.2536 - val_accuracy: 0.9111 - 52s/epoch - 24ms/step
# Epoch 38/50
# 2188/2188 - 52s - loss: 0.2987 - accuracy: 0.8892 - val_loss: 0.2103 - val_accuracy: 0.9281 - 52s/epoch - 24ms/step
# Epoch 39/50
# 2188/2188 - 52s - loss: 0.2952 - accuracy: 0.8891 - val_loss: 0.2429 - val_accuracy: 0.9168 - 52s/epoch - 24ms/step
# Epoch 40/50
# 2188/2188 - 52s - loss: 0.2873 - accuracy: 0.8930 - val_loss: 0.2088 - val_accuracy: 0.9294 - 52s/epoch - 24ms/step
# Epoch 41/50
# 2188/2188 - 52s - loss: 0.2847 - accuracy: 0.8942 - val_loss: 0.2182 - val_accuracy: 0.9245 - 52s/epoch - 24ms/step
# Epoch 42/50
# 2188/2188 - 52s - loss: 0.2782 - accuracy: 0.8954 - val_loss: 0.2120 - val_accuracy: 0.9277 - 52s/epoch - 24ms/step
# Epoch 43/50
# 2188/2188 - 52s - loss: 0.2763 - accuracy: 0.8972 - val_loss: 0.1997 - val_accuracy: 0.9306 - 52s/epoch - 24ms/step
# Epoch 44/50
# 2188/2188 - 52s - loss: 0.2684 - accuracy: 0.8999 - val_loss: 0.2035 - val_accuracy: 0.9313 - 52s/epoch - 24ms/step
# Epoch 45/50
# 2188/2188 - 52s - loss: 0.2633 - accuracy: 0.9012 - val_loss: 0.1976 - val_accuracy: 0.9317 - 52s/epoch - 24ms/step
# Epoch 46/50
# 2188/2188 - 52s - loss: 0.2574 - accuracy: 0.9034 - val_loss: 0.2119 - val_accuracy: 0.9267 - 52s/epoch - 24ms/step
# Epoch 47/50
# 2188/2188 - 52s - loss: 0.2551 - accuracy: 0.9050 - val_loss: 0.1932 - val_accuracy: 0.9331 - 52s/epoch - 24ms/step
# Epoch 48/50
# 2188/2188 - 52s - loss: 0.2501 - accuracy: 0.9060 - val_loss: 0.1858 - val_accuracy: 0.9355 - 52s/epoch - 24ms/step
# Epoch 49/50
# 2188/2188 - 52s - loss: 0.2513 - accuracy: 0.9069 - val_loss: 0.1853 - val_accuracy: 0.9371 - 52s/epoch - 24ms/step
# Epoch 50/50
# 2188/2188 - 52s - loss: 0.2433 - accuracy: 0.9085 - val_loss: 0.2051 - val_accuracy: 0.9311 - 52s/epoch - 24ms/step
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2009 - accuracy: 0.9295
# 274/274 [==============================] - 4s 10ms/step
# 128/128 [==============================] - 1s 11ms/step - loss: 2.4616 - accuracy: 0.6851
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 3s 10ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 126, 32)           5888
#
#  dropout_15 (Dropout)        (None, 126, 32)           0
#
#  lstm_16 (LSTM)              (None, 126, 32)           8320
#
#  dropout_16 (Dropout)        (None, 126, 32)           0
#
#  lstm_17 (LSTM)              (None, 126, 32)           8320
#
#  dropout_17 (Dropout)        (None, 126, 32)           0
#
#  lstm_18 (LSTM)              (None, 126, 128)          82432
#
#  dropout_18 (Dropout)        (None, 126, 128)          0
#
#  lstm_19 (LSTM)              (None, 126, 128)          131584
#
#  flatten_3 (Flatten)         (None, 16128)             0
#
#  dense_6 (Dense)             (None, 512)               8258048
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,499,722
# Trainable params: 8,499,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 58s - loss: 1.7491 - accuracy: 0.3534 - val_loss: 1.4016 - val_accuracy: 0.5077 - 58s/epoch - 26ms/step
# Epoch 2/50
# 2188/2188 - 52s - loss: 1.3968 - accuracy: 0.4916 - val_loss: 1.1740 - val_accuracy: 0.5731 - 52s/epoch - 24ms/step
# Epoch 3/50
# 2188/2188 - 51s - loss: 1.2181 - accuracy: 0.5591 - val_loss: 1.0571 - val_accuracy: 0.6161 - 51s/epoch - 23ms/step
# Epoch 4/50
# 2188/2188 - 52s - loss: 1.0999 - accuracy: 0.6020 - val_loss: 0.9287 - val_accuracy: 0.6611 - 52s/epoch - 24ms/step
# Epoch 5/50
# 2188/2188 - 52s - loss: 1.0091 - accuracy: 0.6346 - val_loss: 0.8257 - val_accuracy: 0.7085 - 52s/epoch - 24ms/step
# Epoch 6/50
# 2188/2188 - 52s - loss: 0.9347 - accuracy: 0.6609 - val_loss: 0.7805 - val_accuracy: 0.7250 - 52s/epoch - 24ms/step
# Epoch 7/50
# 2188/2188 - 52s - loss: 0.8666 - accuracy: 0.6841 - val_loss: 0.6928 - val_accuracy: 0.7435 - 52s/epoch - 24ms/step
# Epoch 8/50
# 2188/2188 - 52s - loss: 0.8133 - accuracy: 0.7033 - val_loss: 0.6530 - val_accuracy: 0.7648 - 52s/epoch - 24ms/step
# Epoch 9/50
# 2188/2188 - 52s - loss: 0.7696 - accuracy: 0.7194 - val_loss: 0.6171 - val_accuracy: 0.7832 - 52s/epoch - 24ms/step
# Epoch 10/50
# 2188/2188 - 52s - loss: 0.7253 - accuracy: 0.7360 - val_loss: 0.5912 - val_accuracy: 0.7928 - 52s/epoch - 24ms/step
# Epoch 11/50
# 2188/2188 - 52s - loss: 0.6909 - accuracy: 0.7479 - val_loss: 0.5338 - val_accuracy: 0.8098 - 52s/epoch - 24ms/step
# Epoch 12/50
# 2188/2188 - 52s - loss: 0.6557 - accuracy: 0.7591 - val_loss: 0.5018 - val_accuracy: 0.8241 - 52s/epoch - 24ms/step
# Epoch 13/50
# 2188/2188 - 52s - loss: 0.6304 - accuracy: 0.7690 - val_loss: 0.4667 - val_accuracy: 0.8360 - 52s/epoch - 24ms/step
# Epoch 14/50
# 2188/2188 - 52s - loss: 0.6011 - accuracy: 0.7784 - val_loss: 0.4568 - val_accuracy: 0.8397 - 52s/epoch - 24ms/step
# Epoch 15/50
# 2188/2188 - 51s - loss: 0.5803 - accuracy: 0.7865 - val_loss: 0.4429 - val_accuracy: 0.8362 - 51s/epoch - 24ms/step
# Epoch 16/50
# 2188/2188 - 52s - loss: 0.5540 - accuracy: 0.7961 - val_loss: 0.4579 - val_accuracy: 0.8339 - 52s/epoch - 24ms/step
# Epoch 17/50
# 2188/2188 - 52s - loss: 0.5382 - accuracy: 0.8017 - val_loss: 0.4291 - val_accuracy: 0.8442 - 52s/epoch - 24ms/step
# Epoch 18/50
# 2188/2188 - 52s - loss: 0.5199 - accuracy: 0.8076 - val_loss: 0.3861 - val_accuracy: 0.8639 - 52s/epoch - 24ms/step
# Epoch 19/50
# 2188/2188 - 52s - loss: 0.5031 - accuracy: 0.8138 - val_loss: 0.3811 - val_accuracy: 0.8666 - 52s/epoch - 24ms/step
# Epoch 20/50
# 2188/2188 - 52s - loss: 0.4842 - accuracy: 0.8196 - val_loss: 0.3628 - val_accuracy: 0.8719 - 52s/epoch - 24ms/step
# Epoch 21/50
# 2188/2188 - 52s - loss: 0.4706 - accuracy: 0.8253 - val_loss: 0.3519 - val_accuracy: 0.8738 - 52s/epoch - 24ms/step
# Epoch 22/50
# 2188/2188 - 52s - loss: 0.4564 - accuracy: 0.8311 - val_loss: 0.3297 - val_accuracy: 0.8826 - 52s/epoch - 24ms/step
# Epoch 23/50
# 2188/2188 - 52s - loss: 0.4432 - accuracy: 0.8356 - val_loss: 0.3103 - val_accuracy: 0.8902 - 52s/epoch - 24ms/step
# Epoch 24/50
# 2188/2188 - 52s - loss: 0.4323 - accuracy: 0.8402 - val_loss: 0.3015 - val_accuracy: 0.8949 - 52s/epoch - 24ms/step
# Epoch 25/50
# 2188/2188 - 52s - loss: 0.4158 - accuracy: 0.8459 - val_loss: 0.3022 - val_accuracy: 0.8919 - 52s/epoch - 24ms/step
# Epoch 26/50
# 2188/2188 - 52s - loss: 0.4051 - accuracy: 0.8498 - val_loss: 0.3415 - val_accuracy: 0.8750 - 52s/epoch - 24ms/step
# Epoch 27/50
# 2188/2188 - 52s - loss: 0.3953 - accuracy: 0.8522 - val_loss: 0.2809 - val_accuracy: 0.9035 - 52s/epoch - 24ms/step
# Epoch 28/50
# 2188/2188 - 52s - loss: 0.3814 - accuracy: 0.8574 - val_loss: 0.2811 - val_accuracy: 0.9015 - 52s/epoch - 24ms/step
# Epoch 29/50
# 2188/2188 - 52s - loss: 0.3750 - accuracy: 0.8600 - val_loss: 0.2677 - val_accuracy: 0.9075 - 52s/epoch - 24ms/step
# Epoch 30/50
# 2188/2188 - 52s - loss: 0.3656 - accuracy: 0.8648 - val_loss: 0.2609 - val_accuracy: 0.9087 - 52s/epoch - 24ms/step
# Epoch 31/50
# 2188/2188 - 52s - loss: 0.3552 - accuracy: 0.8675 - val_loss: 0.2488 - val_accuracy: 0.9120 - 52s/epoch - 24ms/step
# Epoch 32/50
# 2188/2188 - 52s - loss: 0.3520 - accuracy: 0.8683 - val_loss: 0.2614 - val_accuracy: 0.9069 - 52s/epoch - 24ms/step
# Epoch 33/50
# 2188/2188 - 52s - loss: 0.3435 - accuracy: 0.8726 - val_loss: 0.2691 - val_accuracy: 0.9069 - 52s/epoch - 24ms/step
# Epoch 34/50
# 2188/2188 - 52s - loss: 0.3308 - accuracy: 0.8760 - val_loss: 0.2609 - val_accuracy: 0.9083 - 52s/epoch - 24ms/step
# Epoch 35/50
# 2188/2188 - 51s - loss: 0.3276 - accuracy: 0.8770 - val_loss: 0.2303 - val_accuracy: 0.9193 - 51s/epoch - 24ms/step
# Epoch 36/50
# 2188/2188 - 52s - loss: 0.3185 - accuracy: 0.8812 - val_loss: 0.2267 - val_accuracy: 0.9225 - 52s/epoch - 24ms/step
# Epoch 37/50
# 2188/2188 - 52s - loss: 0.3145 - accuracy: 0.8823 - val_loss: 0.2291 - val_accuracy: 0.9233 - 52s/epoch - 24ms/step
# Epoch 38/50
# 2188/2188 - 52s - loss: 0.3076 - accuracy: 0.8855 - val_loss: 0.2622 - val_accuracy: 0.9105 - 52s/epoch - 24ms/step
# Epoch 39/50
# 2188/2188 - 52s - loss: 0.3058 - accuracy: 0.8870 - val_loss: 0.2404 - val_accuracy: 0.9155 - 52s/epoch - 24ms/step
# Epoch 40/50
# 2188/2188 - 52s - loss: 0.2913 - accuracy: 0.8913 - val_loss: 0.2137 - val_accuracy: 0.9272 - 52s/epoch - 24ms/step
# Epoch 41/50
# 2188/2188 - 52s - loss: 0.2916 - accuracy: 0.8915 - val_loss: 0.2116 - val_accuracy: 0.9283 - 52s/epoch - 24ms/step
# Epoch 42/50
# 2188/2188 - 52s - loss: 0.2812 - accuracy: 0.8939 - val_loss: 0.2073 - val_accuracy: 0.9294 - 52s/epoch - 24ms/step
# Epoch 43/50
# 2188/2188 - 52s - loss: 0.2816 - accuracy: 0.8954 - val_loss: 0.2175 - val_accuracy: 0.9230 - 52s/epoch - 24ms/step
# Epoch 44/50
# 2188/2188 - 52s - loss: 0.2759 - accuracy: 0.8966 - val_loss: 0.1992 - val_accuracy: 0.9320 - 52s/epoch - 24ms/step
# Epoch 45/50
# 2188/2188 - 52s - loss: 0.2734 - accuracy: 0.8983 - val_loss: 0.1963 - val_accuracy: 0.9353 - 52s/epoch - 24ms/step
# Epoch 46/50
# 2188/2188 - 52s - loss: 0.2697 - accuracy: 0.9009 - val_loss: 0.1984 - val_accuracy: 0.9317 - 52s/epoch - 24ms/step
# Epoch 47/50
# 2188/2188 - 52s - loss: 0.2643 - accuracy: 0.9012 - val_loss: 0.1892 - val_accuracy: 0.9330 - 52s/epoch - 24ms/step
# Epoch 48/50
# 2188/2188 - 52s - loss: 0.2559 - accuracy: 0.9042 - val_loss: 0.1956 - val_accuracy: 0.9319 - 52s/epoch - 24ms/step
# Epoch 49/50
# 2188/2188 - 52s - loss: 0.2582 - accuracy: 0.9039 - val_loss: 0.1920 - val_accuracy: 0.9374 - 52s/epoch - 24ms/step
# Epoch 50/50
# 2188/2188 - 51s - loss: 0.2506 - accuracy: 0.9071 - val_loss: 0.1865 - val_accuracy: 0.9353 - 51s/epoch - 24ms/step
# 274/274 [==============================] - 3s 10ms/step - loss: 0.2057 - accuracy: 0.9310
# 274/274 [==============================] - 4s 10ms/step
# 128/128 [==============================] - 1s 10ms/step - loss: 2.1537 - accuracy: 0.6897
# 128/128 [==============================] - 1s 10ms/step
# 274/274 [==============================] - 3s 10ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 126, 32)           5888
#
#  dropout_20 (Dropout)        (None, 126, 32)           0
#
#  lstm_21 (LSTM)              (None, 126, 32)           8320
#
#  dropout_21 (Dropout)        (None, 126, 32)           0
#
#  lstm_22 (LSTM)              (None, 126, 32)           8320
#
#  dropout_22 (Dropout)        (None, 126, 32)           0
#
#  lstm_23 (LSTM)              (None, 126, 128)          82432
#
#  dropout_23 (Dropout)        (None, 126, 128)          0
#
#  lstm_24 (LSTM)              (None, 126, 128)          131584
#
#  flatten_4 (Flatten)         (None, 16128)             0
#
#  dense_8 (Dense)             (None, 512)               8258048
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,499,722
# Trainable params: 8,499,722
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 59s - loss: 1.7468 - accuracy: 0.3574 - val_loss: 1.3391 - val_accuracy: 0.5187 - 59s/epoch - 27ms/step
# Epoch 2/50
# 2188/2188 - 52s - loss: 1.3557 - accuracy: 0.5115 - val_loss: 1.1505 - val_accuracy: 0.5808 - 52s/epoch - 24ms/step
# Epoch 3/50
# 2188/2188 - 52s - loss: 1.1942 - accuracy: 0.5680 - val_loss: 0.9728 - val_accuracy: 0.6499 - 52s/epoch - 24ms/step
# Epoch 4/50
# 2188/2188 - 52s - loss: 1.0773 - accuracy: 0.6094 - val_loss: 0.8656 - val_accuracy: 0.6897 - 52s/epoch - 24ms/step
# Epoch 5/50
# 2188/2188 - 52s - loss: 0.9865 - accuracy: 0.6429 - val_loss: 0.8026 - val_accuracy: 0.7182 - 52s/epoch - 24ms/step
# Epoch 6/50
# 2188/2188 - 48s - loss: 0.9223 - accuracy: 0.6647 - val_loss: 0.7403 - val_accuracy: 0.7359 - 48s/epoch - 22ms/step
# Epoch 7/50
# 2188/2188 - 50s - loss: 0.8575 - accuracy: 0.6879 - val_loss: 0.7485 - val_accuracy: 0.7216 - 50s/epoch - 23ms/step
# Epoch 8/50
# 2188/2188 - 48s - loss: 0.8150 - accuracy: 0.7019 - val_loss: 0.6281 - val_accuracy: 0.7761 - 48s/epoch - 22ms/step
# Epoch 9/50
# 2188/2188 - 47s - loss: 0.7671 - accuracy: 0.7180 - val_loss: 0.5902 - val_accuracy: 0.7830 - 47s/epoch - 22ms/step
# Epoch 10/50
# 2188/2188 - 47s - loss: 0.7248 - accuracy: 0.7326 - val_loss: 0.5648 - val_accuracy: 0.7981 - 47s/epoch - 22ms/step
# Epoch 11/50
# 2188/2188 - 47s - loss: 0.6869 - accuracy: 0.7464 - val_loss: 0.5278 - val_accuracy: 0.8081 - 47s/epoch - 22ms/step
# Epoch 12/50
# 2188/2188 - 48s - loss: 0.6534 - accuracy: 0.7572 - val_loss: 0.5005 - val_accuracy: 0.8205 - 48s/epoch - 22ms/step
# Epoch 13/50
# 2188/2188 - 48s - loss: 0.6268 - accuracy: 0.7678 - val_loss: 0.5001 - val_accuracy: 0.8097 - 48s/epoch - 22ms/step
# Epoch 14/50
# 2188/2188 - 48s - loss: 0.5981 - accuracy: 0.7774 - val_loss: 0.4729 - val_accuracy: 0.8265 - 48s/epoch - 22ms/step
# Epoch 15/50
# 2188/2188 - 48s - loss: 0.5735 - accuracy: 0.7868 - val_loss: 0.4260 - val_accuracy: 0.8431 - 48s/epoch - 22ms/step
# Epoch 16/50
# 2188/2188 - 48s - loss: 0.5522 - accuracy: 0.7943 - val_loss: 0.4120 - val_accuracy: 0.8504 - 48s/epoch - 22ms/step
# Epoch 17/50
# 2188/2188 - 48s - loss: 0.5356 - accuracy: 0.8013 - val_loss: 0.4064 - val_accuracy: 0.8519 - 48s/epoch - 22ms/step
# Epoch 18/50
# 2188/2188 - 48s - loss: 0.5199 - accuracy: 0.8061 - val_loss: 0.3750 - val_accuracy: 0.8670 - 48s/epoch - 22ms/step
# Epoch 19/50
# 2188/2188 - 48s - loss: 0.4991 - accuracy: 0.8150 - val_loss: 0.3817 - val_accuracy: 0.8591 - 48s/epoch - 22ms/step
# Epoch 20/50
# 2188/2188 - 48s - loss: 0.4825 - accuracy: 0.8195 - val_loss: 0.3666 - val_accuracy: 0.8679 - 48s/epoch - 22ms/step
# Epoch 21/50
# 2188/2188 - 48s - loss: 0.4623 - accuracy: 0.8285 - val_loss: 0.3471 - val_accuracy: 0.8727 - 48s/epoch - 22ms/step
# Epoch 22/50
# 2188/2188 - 48s - loss: 0.4515 - accuracy: 0.8312 - val_loss: 0.3174 - val_accuracy: 0.8826 - 48s/epoch - 22ms/step
# Epoch 23/50
# 2188/2188 - 48s - loss: 0.4334 - accuracy: 0.8381 - val_loss: 0.3569 - val_accuracy: 0.8721 - 48s/epoch - 22ms/step
# Epoch 24/50
# 2188/2188 - 48s - loss: 0.4239 - accuracy: 0.8417 - val_loss: 0.3104 - val_accuracy: 0.8890 - 48s/epoch - 22ms/step
# Epoch 25/50
# 2188/2188 - 48s - loss: 0.4133 - accuracy: 0.8453 - val_loss: 0.2930 - val_accuracy: 0.8951 - 48s/epoch - 22ms/step
# Epoch 26/50
# 2188/2188 - 48s - loss: 0.3989 - accuracy: 0.8510 - val_loss: 0.3060 - val_accuracy: 0.8904 - 48s/epoch - 22ms/step
# Epoch 27/50
# 2188/2188 - 48s - loss: 0.3954 - accuracy: 0.8524 - val_loss: 0.3023 - val_accuracy: 0.8906 - 48s/epoch - 22ms/step
# Epoch 28/50
# 2188/2188 - 48s - loss: 0.3803 - accuracy: 0.8575 - val_loss: 0.2705 - val_accuracy: 0.9023 - 48s/epoch - 22ms/step
# Epoch 29/50
# 2188/2188 - 48s - loss: 0.3748 - accuracy: 0.8592 - val_loss: 0.2819 - val_accuracy: 0.9022 - 48s/epoch - 22ms/step
# Epoch 30/50
# 2188/2188 - 47s - loss: 0.3646 - accuracy: 0.8635 - val_loss: 0.2756 - val_accuracy: 0.9014 - 47s/epoch - 22ms/step
# Epoch 31/50
# 2188/2188 - 47s - loss: 0.3570 - accuracy: 0.8664 - val_loss: 0.2592 - val_accuracy: 0.9083 - 47s/epoch - 22ms/step
# Epoch 32/50
# 2188/2188 - 48s - loss: 0.3472 - accuracy: 0.8691 - val_loss: 0.2657 - val_accuracy: 0.9062 - 48s/epoch - 22ms/step
# Epoch 33/50
# 2188/2188 - 48s - loss: 0.3394 - accuracy: 0.8740 - val_loss: 0.2368 - val_accuracy: 0.9154 - 48s/epoch - 22ms/step
# Epoch 34/50
# 2188/2188 - 48s - loss: 0.3309 - accuracy: 0.8754 - val_loss: 0.2461 - val_accuracy: 0.9141 - 48s/epoch - 22ms/step
# Epoch 35/50
# 2188/2188 - 47s - loss: 0.3261 - accuracy: 0.8776 - val_loss: 0.2389 - val_accuracy: 0.9144 - 47s/epoch - 22ms/step
# Epoch 36/50
# 2188/2188 - 48s - loss: 0.3218 - accuracy: 0.8798 - val_loss: 0.2395 - val_accuracy: 0.9161 - 48s/epoch - 22ms/step
# Epoch 37/50
# 2188/2188 - 47s - loss: 0.3153 - accuracy: 0.8818 - val_loss: 0.2495 - val_accuracy: 0.9118 - 47s/epoch - 21ms/step
# Epoch 38/50
# 2188/2188 - 48s - loss: 0.3078 - accuracy: 0.8850 - val_loss: 0.2339 - val_accuracy: 0.9191 - 48s/epoch - 22ms/step
# Epoch 39/50
# 2188/2188 - 48s - loss: 0.3001 - accuracy: 0.8873 - val_loss: 0.2277 - val_accuracy: 0.9195 - 48s/epoch - 22ms/step
# Epoch 40/50
# 2188/2188 - 48s - loss: 0.2972 - accuracy: 0.8887 - val_loss: 0.2380 - val_accuracy: 0.9197 - 48s/epoch - 22ms/step
# Epoch 41/50
# 2188/2188 - 48s - loss: 0.2860 - accuracy: 0.8918 - val_loss: 0.2298 - val_accuracy: 0.9231 - 48s/epoch - 22ms/step
# Epoch 42/50
# 2188/2188 - 47s - loss: 0.2870 - accuracy: 0.8914 - val_loss: 0.2079 - val_accuracy: 0.9285 - 47s/epoch - 22ms/step
# Epoch 43/50
# 2188/2188 - 48s - loss: 0.2804 - accuracy: 0.8947 - val_loss: 0.2263 - val_accuracy: 0.9213 - 48s/epoch - 22ms/step
# Epoch 44/50
# 2188/2188 - 48s - loss: 0.2770 - accuracy: 0.8962 - val_loss: 0.2462 - val_accuracy: 0.9170 - 48s/epoch - 22ms/step
# Epoch 45/50
# 2188/2188 - 48s - loss: 0.2682 - accuracy: 0.8985 - val_loss: 0.2046 - val_accuracy: 0.9314 - 48s/epoch - 22ms/step
# Epoch 46/50
# 2188/2188 - 47s - loss: 0.2680 - accuracy: 0.8999 - val_loss: 0.1945 - val_accuracy: 0.9343 - 47s/epoch - 22ms/step
# Epoch 47/50
# 2188/2188 - 48s - loss: 0.2656 - accuracy: 0.9008 - val_loss: 0.1903 - val_accuracy: 0.9345 - 48s/epoch - 22ms/step
# Epoch 48/50
# 2188/2188 - 48s - loss: 0.2625 - accuracy: 0.9017 - val_loss: 0.2286 - val_accuracy: 0.9227 - 48s/epoch - 22ms/step
# Epoch 49/50
# 2188/2188 - 48s - loss: 0.2558 - accuracy: 0.9037 - val_loss: 0.1935 - val_accuracy: 0.9336 - 48s/epoch - 22ms/step
# Epoch 50/50
# 2188/2188 - 48s - loss: 0.2491 - accuracy: 0.9073 - val_loss: 0.2108 - val_accuracy: 0.9296 - 48s/epoch - 22ms/step
# 274/274 [==============================] - 3s 9ms/step - loss: 0.2291 - accuracy: 0.9246
# 274/274 [==============================] - 4s 9ms/step
# 128/128 [==============================] - 1s 10ms/step - loss: 2.4085 - accuracy: 0.6963
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 9ms/step
