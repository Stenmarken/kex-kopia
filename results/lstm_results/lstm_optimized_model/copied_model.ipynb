# %%
import numpy as np
import pandas as pd
import librosa
import os
import glob
import re
import seaborn as sn
import matplotlib.pyplot as plt
import scipy
import time
import collections
import keras
import random
from keras.utils import np_utils
from keras.layers import MaxPooling1D, Conv1D, Conv2D, MaxPooling2D, GlobalAveragePooling2D, LSTM, ELU, Bidirectional, Attention
from keras.layers import Dense, Dropout, Activation, Flatten, CuDNNLSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import tensorflow as tf
import pickle
from keras.utils.vis_utils import plot_model
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import keras_tuner
from keras import backend as K
import shutil
import os
import tensorflow_addons as tfa
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn import metrics
# Out:
# 2023-05-04 23:49:08.447185: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 23:49:09.068633: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/stenmarken/miniconda3/envs/tensorflow/lib/
# 2023-05-04 23:49:09.068691: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/stenmarken/miniconda3/envs/tensorflow/lib/
# 2023-05-04 23:49:09.068696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Global variables

# %%
global_model_type = 'lstm'
global_folder_name = 'lstm_optimized_model'
file_suffix = 'weyo1'
global_batch_size = 32
global_epochs = 50
global_learning_rate = 0.001
own_file_path = os.getcwd() 
global_hyperparameter_folder_name = '5_2_lstm_filter_size_dropout' #lstm_filter_size_dropout1' #'cnn_filter_size_dropout'
optimized_model = True # Om satt till True körs den hyperparameter tune:ade modellen. Annars base_model

# %%
def instrument_code(filename):
    """
    Function that takes in a filename and returns instrument based on naming convention
    """
    # Synth lead borttagen. id = 9
    class_names=['bass', 'brass', 'flute', 'guitar', 
             'keyboard', 'mallet', 'organ', 'reed', 
             'string', 'vocal']
    
    for name in class_names:
        if name in filename:
            return class_names.index(name)
    else:
        return None

# %% [markdown]
# ## Get data

# %%
def get_data_from_file(file):
    with open(file, "rb") as f:
        X_train_full  = pickle.load(f)

    X_train = []
    y_train = []

    for (key, value) in X_train_full:
        X_train.append(value)
        y_train.append(instrument_code(key))

    X_train_numpy = np.array(X_train)
    y_train_numpy = np.array(y_train)
    return (X_train_numpy, y_train_numpy)

# %%
def get_old_test_data(file):
    with open(file, 'rb') as f:
        old_X_test_full = pickle.load(f)

    old_X_test = []
    old_y_test = []

    for(key, value) in old_X_test_full.items():
        #temporal_value = np.mean(value, axis = 1)
        old_X_test.append(value)
        old_y_test.append(instrument_code(key))
        
    old_y_test_numpy = np.asarray(old_y_test)
    old_X_test_numpy = np.asarray(old_X_test)
    return (old_X_test_numpy, old_y_test_numpy)

# %% [markdown]
# ### Calculate metrics

# %%
def calc_metrics(y_true, y_pred):
    print(metrics.classification_report(y_true, y_pred, digits=3))

# %%
def hyperparameter_cnn_model(hp):
    """
    Function that builds a CNN model with optimized hyperparameters including filter size and dropout rate
    """

    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same', input_shape=(126, 13, 1)))
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))

    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_2', values = [32, 64, 128, 256]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def hyperparameter_lstm_model(hp):
    """
    Function that builds a LSTM model with optimized hyperparameters including filter size and dropout rate
    """
    
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_cnn_model():    
    input_shape = (126, 13, 1)
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_cnn_model():
    input_shape = (126, 13, 1)
    dropout_1 = 0.2 
    conv_2_filters_1 = 128
    conv_2_filters_2 = 128

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_2,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(dropout_1))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_lstm_model():
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(32, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_lstm_model():
    dropout_lstm = 0.3
    lstm_layer_units_1 = 32
    lstm_layer_units_2 = 128
    model = Sequential()
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def plot_acc_loss(history, acc_file_path, loss_file_path):
    # Taget från https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    # summarize history for accuracy
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(acc_file_path)
    plt.show()

    # summarize history for loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(loss_file_path)
    plt.show()

# %%
    
def plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path):    
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    result = confusion_matrix(y_test, y_prediction , normalize='pred')

    df_cm = pd.DataFrame(result, index = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]],
                    columns = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]])

    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig(confusion_matrix_file_path)
    plt.show()

# %%
def run_cnn(fold_index):

    old_test_file = 'CustomDataFull/testdata2000.pkl'

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/cnn_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

    if optimized_model:
        model = build_optimized_cnn_model()
    else:
        model = build_cnn_model()
        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)

    print("\n\ny_test : ", y_test)
    print("\n\ny_prediction : ", y_prediction)

    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)

    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores:\n' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata:\n' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %%
def run_lstm(fold_index):
    old_test_file = 'CustomDataFull/testdata2000.pkl'
    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/lstm_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)


    if optimized_model:
        model = build_optimized_lstm_model()
    else:
        model = build_lstm_model()

        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    #model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy', 
    #              tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=10, average='macro',
    #              threshold=0.5)])
    
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)
    
    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores: ' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata: ' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %% [markdown]
# ### Hyperparameter tuning

# %%
def tune_cnn():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_cnn_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
        f.write(str(tuner.results_summary()) + '\n')

    tuner.results_summary()

    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'cnn-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %%
def tune_lstm():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_lstm_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
    
    tuner.results_summary()
    
    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'lstm-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %% [markdown]
# ### Run 5-fold cross validation

# %%
def run_cnn_5_fold_cross_validation():
    path = 'results/cnn_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)

    copy_file = 'results/cnn_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_cnn(i)

# %%
def run_lstm_5_fold_cross_validation():
    path = 'results/lstm_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)
    
    copy_file = 'results/lstm_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_lstm(i)

# %%
if (global_model_type == 'cnn'):
    print('Start running cnn')
    run_cnn_5_fold_cross_validation()
elif (global_model_type == 'lstm'):
    print('Start running lstm')
    run_lstm_5_fold_cross_validation()
elif (global_model_type == 'tune_cnn'):
    print('Start tuning cnn')
    tune_cnn()
elif (global_model_type == 'tune_lstm'):
    print('Start tuning lstm')
    tune_lstm()
# Out:
# Start running lstm
# 2023-05-04 23:49:37.313393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.317660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.317859: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.318209: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-04 23:49:37.318816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.319055: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.319215: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.708979: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.709187: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.709352: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-04 23:49:37.709487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4399 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:26:00.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 126, 32)           5888
#
#  dropout (Dropout)           (None, 126, 32)           0
#
#  lstm_1 (LSTM)               (None, 126, 32)           8320
#
#  dropout_1 (Dropout)         (None, 126, 32)           0
#
#  lstm_2 (LSTM)               (None, 126, 32)           8320
#
#  dropout_2 (Dropout)         (None, 126, 32)           0
#
#  lstm_3 (LSTM)               (None, 126, 32)           8320
#
#  dropout_3 (Dropout)         (None, 126, 32)           0
#
#  lstm_4 (LSTM)               (None, 126, 32)           8320
#
#  flatten (Flatten)           (None, 4032)              0
#
#  dense (Dense)               (None, 512)               2064896
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,109,194
# Trainable params: 2,109,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-04 23:49:43.170078: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-05-04 23:49:43.830890: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f381405ea50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-04 23:49:43.830917: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 SUPER, Compute Capability 7.5
# 2023-05-04 23:49:43.834438: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-04 23:49:43.926205: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2188/2188 - 49s - loss: 1.5266 - accuracy: 0.4390 - val_loss: 1.1641 - val_accuracy: 0.5618 - 49s/epoch - 22ms/step
# Epoch 2/50
# 2188/2188 - 43s - loss: 1.1657 - accuracy: 0.5689 - val_loss: 0.9366 - val_accuracy: 0.6579 - 43s/epoch - 19ms/step
# Epoch 3/50
# 2188/2188 - 43s - loss: 1.0031 - accuracy: 0.6304 - val_loss: 0.8232 - val_accuracy: 0.6965 - 43s/epoch - 20ms/step
# Epoch 4/50
# 2188/2188 - 43s - loss: 0.9077 - accuracy: 0.6651 - val_loss: 0.7067 - val_accuracy: 0.7393 - 43s/epoch - 20ms/step
# Epoch 5/50
# 2188/2188 - 43s - loss: 0.8316 - accuracy: 0.6950 - val_loss: 0.6276 - val_accuracy: 0.7658 - 43s/epoch - 20ms/step
# Epoch 6/50
# 2188/2188 - 43s - loss: 0.7680 - accuracy: 0.7149 - val_loss: 0.6053 - val_accuracy: 0.7784 - 43s/epoch - 20ms/step
# Epoch 7/50
# 2188/2188 - 43s - loss: 0.7256 - accuracy: 0.7321 - val_loss: 0.5781 - val_accuracy: 0.7823 - 43s/epoch - 19ms/step
# Epoch 8/50
# 2188/2188 - 43s - loss: 0.6798 - accuracy: 0.7476 - val_loss: 0.5251 - val_accuracy: 0.8086 - 43s/epoch - 20ms/step
# Epoch 9/50
# 2188/2188 - 43s - loss: 0.6515 - accuracy: 0.7583 - val_loss: 0.5288 - val_accuracy: 0.8023 - 43s/epoch - 20ms/step
# Epoch 10/50
# 2188/2188 - 43s - loss: 0.6244 - accuracy: 0.7695 - val_loss: 0.4458 - val_accuracy: 0.8352 - 43s/epoch - 20ms/step
# Epoch 11/50
# 2188/2188 - 43s - loss: 0.5970 - accuracy: 0.7798 - val_loss: 0.5627 - val_accuracy: 0.7947 - 43s/epoch - 20ms/step
# Epoch 12/50
# 2188/2188 - 43s - loss: 0.5720 - accuracy: 0.7886 - val_loss: 0.4281 - val_accuracy: 0.8429 - 43s/epoch - 20ms/step
# Epoch 13/50
# 2188/2188 - 43s - loss: 0.5474 - accuracy: 0.7978 - val_loss: 0.3860 - val_accuracy: 0.8579 - 43s/epoch - 20ms/step
# Epoch 14/50
# 2188/2188 - 43s - loss: 0.5304 - accuracy: 0.8026 - val_loss: 0.3695 - val_accuracy: 0.8635 - 43s/epoch - 20ms/step
# Epoch 15/50
# 2188/2188 - 43s - loss: 0.5164 - accuracy: 0.8082 - val_loss: 0.3776 - val_accuracy: 0.8598 - 43s/epoch - 20ms/step
# Epoch 16/50
# 2188/2188 - 43s - loss: 0.5000 - accuracy: 0.8148 - val_loss: 0.3675 - val_accuracy: 0.8649 - 43s/epoch - 20ms/step
# Epoch 17/50
# 2188/2188 - 43s - loss: 0.4852 - accuracy: 0.8191 - val_loss: 0.3578 - val_accuracy: 0.8691 - 43s/epoch - 20ms/step
# Epoch 18/50
# 2188/2188 - 43s - loss: 0.4670 - accuracy: 0.8273 - val_loss: 0.3257 - val_accuracy: 0.8814 - 43s/epoch - 20ms/step
# Epoch 19/50
# 2188/2188 - 43s - loss: 0.4501 - accuracy: 0.8334 - val_loss: 0.3189 - val_accuracy: 0.8822 - 43s/epoch - 20ms/step
# Epoch 20/50
# 2188/2188 - 43s - loss: 0.4415 - accuracy: 0.8366 - val_loss: 0.3150 - val_accuracy: 0.8847 - 43s/epoch - 19ms/step
# Epoch 21/50
# 2188/2188 - 43s - loss: 0.4324 - accuracy: 0.8391 - val_loss: 0.2704 - val_accuracy: 0.9034 - 43s/epoch - 20ms/step
# Epoch 22/50
# 2188/2188 - 43s - loss: 0.4236 - accuracy: 0.8445 - val_loss: 0.2817 - val_accuracy: 0.8969 - 43s/epoch - 20ms/step
# Epoch 23/50
# 2188/2188 - 43s - loss: 0.4099 - accuracy: 0.8475 - val_loss: 0.2891 - val_accuracy: 0.8960 - 43s/epoch - 20ms/step
# Epoch 24/50
# 2188/2188 - 43s - loss: 0.4006 - accuracy: 0.8525 - val_loss: 0.2971 - val_accuracy: 0.8921 - 43s/epoch - 20ms/step
# Epoch 25/50
# 2188/2188 - 43s - loss: 0.3926 - accuracy: 0.8561 - val_loss: 0.2716 - val_accuracy: 0.9017 - 43s/epoch - 20ms/step
# Epoch 26/50
# 2188/2188 - 43s - loss: 0.3824 - accuracy: 0.8577 - val_loss: 0.2736 - val_accuracy: 0.9001 - 43s/epoch - 20ms/step
# Epoch 27/50
# 2188/2188 - 43s - loss: 0.3760 - accuracy: 0.8611 - val_loss: 0.2353 - val_accuracy: 0.9154 - 43s/epoch - 20ms/step
# Epoch 28/50
# 2188/2188 - 43s - loss: 0.3680 - accuracy: 0.8636 - val_loss: 0.2379 - val_accuracy: 0.9122 - 43s/epoch - 20ms/step
# Epoch 29/50
# 2188/2188 - 43s - loss: 0.3623 - accuracy: 0.8646 - val_loss: 0.2448 - val_accuracy: 0.9087 - 43s/epoch - 20ms/step
# Epoch 30/50
# 2188/2188 - 43s - loss: 0.3513 - accuracy: 0.8700 - val_loss: 0.2407 - val_accuracy: 0.9153 - 43s/epoch - 20ms/step
# Epoch 31/50
# 2188/2188 - 43s - loss: 0.3489 - accuracy: 0.8706 - val_loss: 0.2136 - val_accuracy: 0.9237 - 43s/epoch - 20ms/step
# Epoch 32/50
# 2188/2188 - 43s - loss: 0.3371 - accuracy: 0.8753 - val_loss: 0.2081 - val_accuracy: 0.9264 - 43s/epoch - 20ms/step
# Epoch 33/50
# 2188/2188 - 43s - loss: 0.3387 - accuracy: 0.8750 - val_loss: 0.2175 - val_accuracy: 0.9217 - 43s/epoch - 20ms/step
# Epoch 34/50
# 2188/2188 - 43s - loss: 0.3270 - accuracy: 0.8787 - val_loss: 0.2242 - val_accuracy: 0.9225 - 43s/epoch - 20ms/step
# Epoch 35/50
# 2188/2188 - 43s - loss: 0.3244 - accuracy: 0.8807 - val_loss: 0.1972 - val_accuracy: 0.9317 - 43s/epoch - 20ms/step
# Epoch 36/50
# 2188/2188 - 43s - loss: 0.3220 - accuracy: 0.8814 - val_loss: 0.2095 - val_accuracy: 0.9271 - 43s/epoch - 20ms/step
# Epoch 37/50
# 2188/2188 - 42s - loss: 0.3131 - accuracy: 0.8841 - val_loss: 0.1972 - val_accuracy: 0.9271 - 42s/epoch - 19ms/step
# Epoch 38/50
# 2188/2188 - 43s - loss: 0.3120 - accuracy: 0.8848 - val_loss: 0.2006 - val_accuracy: 0.9265 - 43s/epoch - 19ms/step
# Epoch 39/50
# 2188/2188 - 44s - loss: 0.3011 - accuracy: 0.8890 - val_loss: 0.1949 - val_accuracy: 0.9311 - 44s/epoch - 20ms/step
# Epoch 40/50
# 2188/2188 - 44s - loss: 0.2953 - accuracy: 0.8919 - val_loss: 0.1849 - val_accuracy: 0.9342 - 44s/epoch - 20ms/step
# Epoch 41/50
# 2188/2188 - 44s - loss: 0.2933 - accuracy: 0.8939 - val_loss: 0.2243 - val_accuracy: 0.9186 - 44s/epoch - 20ms/step
# Epoch 42/50
# 2188/2188 - 44s - loss: 0.2892 - accuracy: 0.8939 - val_loss: 0.1897 - val_accuracy: 0.9333 - 44s/epoch - 20ms/step
# Epoch 43/50
# 2188/2188 - 44s - loss: 0.2849 - accuracy: 0.8950 - val_loss: 0.1912 - val_accuracy: 0.9318 - 44s/epoch - 20ms/step
# Epoch 44/50
# 2188/2188 - 44s - loss: 0.2831 - accuracy: 0.8945 - val_loss: 0.2045 - val_accuracy: 0.9299 - 44s/epoch - 20ms/step
# Epoch 45/50
# 2188/2188 - 44s - loss: 0.2765 - accuracy: 0.8983 - val_loss: 0.1849 - val_accuracy: 0.9326 - 44s/epoch - 20ms/step
# Epoch 46/50
# 2188/2188 - 44s - loss: 0.2730 - accuracy: 0.8991 - val_loss: 0.1860 - val_accuracy: 0.9331 - 44s/epoch - 20ms/step
# Epoch 47/50
# 2188/2188 - 44s - loss: 0.2746 - accuracy: 0.8982 - val_loss: 0.1930 - val_accuracy: 0.9315 - 44s/epoch - 20ms/step
# Epoch 48/50
# 2188/2188 - 44s - loss: 0.2632 - accuracy: 0.9036 - val_loss: 0.1614 - val_accuracy: 0.9417 - 44s/epoch - 20ms/step
# Epoch 49/50
# 2188/2188 - 44s - loss: 0.2669 - accuracy: 0.9017 - val_loss: 0.1567 - val_accuracy: 0.9449 - 44s/epoch - 20ms/step
# Epoch 50/50
# 2188/2188 - 44s - loss: 0.2603 - accuracy: 0.9040 - val_loss: 0.2131 - val_accuracy: 0.9283 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.2168 - accuracy: 0.9297
# 274/274 [==============================] - 3s 9ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 2.2204 - accuracy: 0.6887
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 126, 32)           5888
#
#  dropout_5 (Dropout)         (None, 126, 32)           0
#
#  lstm_6 (LSTM)               (None, 126, 32)           8320
#
#  dropout_6 (Dropout)         (None, 126, 32)           0
#
#  lstm_7 (LSTM)               (None, 126, 32)           8320
#
#  dropout_7 (Dropout)         (None, 126, 32)           0
#
#  lstm_8 (LSTM)               (None, 126, 32)           8320
#
#  dropout_8 (Dropout)         (None, 126, 32)           0
#
#  lstm_9 (LSTM)               (None, 126, 32)           8320
#
#  flatten_1 (Flatten)         (None, 4032)              0
#
#  dense_2 (Dense)             (None, 512)               2064896
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,109,194
# Trainable params: 2,109,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 50s - loss: 1.5232 - accuracy: 0.4387 - val_loss: 1.1202 - val_accuracy: 0.5896 - 50s/epoch - 23ms/step
# Epoch 2/50
# 2188/2188 - 44s - loss: 1.1422 - accuracy: 0.5804 - val_loss: 0.8942 - val_accuracy: 0.6753 - 44s/epoch - 20ms/step
# Epoch 3/50
# 2188/2188 - 44s - loss: 0.9884 - accuracy: 0.6335 - val_loss: 0.8794 - val_accuracy: 0.6777 - 44s/epoch - 20ms/step
# Epoch 4/50
# 2188/2188 - 44s - loss: 0.8976 - accuracy: 0.6682 - val_loss: 0.6808 - val_accuracy: 0.7482 - 44s/epoch - 20ms/step
# Epoch 5/50
# 2188/2188 - 43s - loss: 0.8255 - accuracy: 0.6921 - val_loss: 0.6202 - val_accuracy: 0.7706 - 43s/epoch - 20ms/step
# Epoch 6/50
# 2188/2188 - 44s - loss: 0.7694 - accuracy: 0.7149 - val_loss: 0.5846 - val_accuracy: 0.7800 - 44s/epoch - 20ms/step
# Epoch 7/50
# 2188/2188 - 44s - loss: 0.7203 - accuracy: 0.7336 - val_loss: 0.5560 - val_accuracy: 0.7936 - 44s/epoch - 20ms/step
# Epoch 8/50
# 2188/2188 - 44s - loss: 0.6748 - accuracy: 0.7512 - val_loss: 0.5598 - val_accuracy: 0.7907 - 44s/epoch - 20ms/step
# Epoch 9/50
# 2188/2188 - 44s - loss: 0.6515 - accuracy: 0.7593 - val_loss: 0.4658 - val_accuracy: 0.8305 - 44s/epoch - 20ms/step
# Epoch 10/50
# 2188/2188 - 44s - loss: 0.6056 - accuracy: 0.7764 - val_loss: 0.4370 - val_accuracy: 0.8370 - 44s/epoch - 20ms/step
# Epoch 11/50
# 2188/2188 - 44s - loss: 0.5859 - accuracy: 0.7818 - val_loss: 0.4211 - val_accuracy: 0.8471 - 44s/epoch - 20ms/step
# Epoch 12/50
# 2188/2188 - 44s - loss: 0.5627 - accuracy: 0.7919 - val_loss: 0.4231 - val_accuracy: 0.8426 - 44s/epoch - 20ms/step
# Epoch 13/50
# 2188/2188 - 44s - loss: 0.5344 - accuracy: 0.8024 - val_loss: 0.3747 - val_accuracy: 0.8633 - 44s/epoch - 20ms/step
# Epoch 14/50
# 2188/2188 - 44s - loss: 0.5183 - accuracy: 0.8079 - val_loss: 0.4161 - val_accuracy: 0.8504 - 44s/epoch - 20ms/step
# Epoch 15/50
# 2188/2188 - 44s - loss: 0.5053 - accuracy: 0.8135 - val_loss: 0.3646 - val_accuracy: 0.8619 - 44s/epoch - 20ms/step
# Epoch 16/50
# 2188/2188 - 44s - loss: 0.4889 - accuracy: 0.8194 - val_loss: 0.3367 - val_accuracy: 0.8752 - 44s/epoch - 20ms/step
# Epoch 17/50
# 2188/2188 - 43s - loss: 0.4627 - accuracy: 0.8279 - val_loss: 0.3064 - val_accuracy: 0.8869 - 43s/epoch - 20ms/step
# Epoch 18/50
# 2188/2188 - 43s - loss: 0.4525 - accuracy: 0.8307 - val_loss: 0.3572 - val_accuracy: 0.8713 - 43s/epoch - 20ms/step
# Epoch 19/50
# 2188/2188 - 44s - loss: 0.4453 - accuracy: 0.8347 - val_loss: 0.2754 - val_accuracy: 0.9031 - 44s/epoch - 20ms/step
# Epoch 20/50
# 2188/2188 - 44s - loss: 0.4171 - accuracy: 0.8447 - val_loss: 0.2921 - val_accuracy: 0.8935 - 44s/epoch - 20ms/step
# Epoch 21/50
# 2188/2188 - 44s - loss: 0.4136 - accuracy: 0.8458 - val_loss: 0.2906 - val_accuracy: 0.8949 - 44s/epoch - 20ms/step
# Epoch 22/50
# 2188/2188 - 44s - loss: 0.4051 - accuracy: 0.8497 - val_loss: 0.2647 - val_accuracy: 0.9047 - 44s/epoch - 20ms/step
# Epoch 23/50
# 2188/2188 - 44s - loss: 0.3951 - accuracy: 0.8540 - val_loss: 0.2750 - val_accuracy: 0.9039 - 44s/epoch - 20ms/step
# Epoch 24/50
# 2188/2188 - 44s - loss: 0.3814 - accuracy: 0.8588 - val_loss: 0.3308 - val_accuracy: 0.8826 - 44s/epoch - 20ms/step
# Epoch 25/50
# 2188/2188 - 44s - loss: 0.3822 - accuracy: 0.8591 - val_loss: 0.2305 - val_accuracy: 0.9193 - 44s/epoch - 20ms/step
# Epoch 26/50
# 2188/2188 - 44s - loss: 0.3656 - accuracy: 0.8655 - val_loss: 0.2558 - val_accuracy: 0.9085 - 44s/epoch - 20ms/step
# Epoch 27/50
# 2188/2188 - 44s - loss: 0.3587 - accuracy: 0.8674 - val_loss: 0.2174 - val_accuracy: 0.9230 - 44s/epoch - 20ms/step
# Epoch 28/50
# 2188/2188 - 44s - loss: 0.3491 - accuracy: 0.8700 - val_loss: 0.2496 - val_accuracy: 0.9152 - 44s/epoch - 20ms/step
# Epoch 29/50
# 2188/2188 - 44s - loss: 0.3408 - accuracy: 0.8735 - val_loss: 0.2139 - val_accuracy: 0.9224 - 44s/epoch - 20ms/step
# Epoch 30/50
# 2188/2188 - 44s - loss: 0.3377 - accuracy: 0.8755 - val_loss: 0.2097 - val_accuracy: 0.9263 - 44s/epoch - 20ms/step
# Epoch 31/50
# 2188/2188 - 44s - loss: 0.3268 - accuracy: 0.8793 - val_loss: 0.1988 - val_accuracy: 0.9337 - 44s/epoch - 20ms/step
# Epoch 32/50
# 2188/2188 - 44s - loss: 0.3191 - accuracy: 0.8823 - val_loss: 0.2337 - val_accuracy: 0.9181 - 44s/epoch - 20ms/step
# Epoch 33/50
# 2188/2188 - 44s - loss: 0.3155 - accuracy: 0.8837 - val_loss: 0.2300 - val_accuracy: 0.9229 - 44s/epoch - 20ms/step
# Epoch 34/50
# 2188/2188 - 44s - loss: 0.3059 - accuracy: 0.8874 - val_loss: 0.2086 - val_accuracy: 0.9302 - 44s/epoch - 20ms/step
# Epoch 35/50
# 2188/2188 - 44s - loss: 0.3088 - accuracy: 0.8869 - val_loss: 0.2296 - val_accuracy: 0.9219 - 44s/epoch - 20ms/step
# Epoch 36/50
# 2188/2188 - 44s - loss: 0.2976 - accuracy: 0.8905 - val_loss: 0.2269 - val_accuracy: 0.9226 - 44s/epoch - 20ms/step
# Epoch 37/50
# 2188/2188 - 44s - loss: 0.2917 - accuracy: 0.8913 - val_loss: 0.2076 - val_accuracy: 0.9294 - 44s/epoch - 20ms/step
# Epoch 38/50
# 2188/2188 - 44s - loss: 0.2884 - accuracy: 0.8936 - val_loss: 0.1831 - val_accuracy: 0.9382 - 44s/epoch - 20ms/step
# Epoch 39/50
# 2188/2188 - 44s - loss: 0.2803 - accuracy: 0.8961 - val_loss: 0.2227 - val_accuracy: 0.9290 - 44s/epoch - 20ms/step
# Epoch 40/50
# 2188/2188 - 44s - loss: 0.2820 - accuracy: 0.8962 - val_loss: 0.2023 - val_accuracy: 0.9345 - 44s/epoch - 20ms/step
# Epoch 41/50
# 2188/2188 - 44s - loss: 0.2802 - accuracy: 0.8972 - val_loss: 0.1893 - val_accuracy: 0.9370 - 44s/epoch - 20ms/step
# Epoch 42/50
# 2188/2188 - 44s - loss: 0.2709 - accuracy: 0.9001 - val_loss: 0.1843 - val_accuracy: 0.9385 - 44s/epoch - 20ms/step
# Epoch 43/50
# 2188/2188 - 44s - loss: 0.2686 - accuracy: 0.9005 - val_loss: 0.1964 - val_accuracy: 0.9374 - 44s/epoch - 20ms/step
# Epoch 44/50
# 2188/2188 - 44s - loss: 0.2654 - accuracy: 0.9014 - val_loss: 0.1755 - val_accuracy: 0.9442 - 44s/epoch - 20ms/step
# Epoch 45/50
# 2188/2188 - 44s - loss: 0.2577 - accuracy: 0.9058 - val_loss: 0.1747 - val_accuracy: 0.9442 - 44s/epoch - 20ms/step
# Epoch 46/50
# 2188/2188 - 44s - loss: 0.2595 - accuracy: 0.9060 - val_loss: 0.2691 - val_accuracy: 0.9048 - 44s/epoch - 20ms/step
# Epoch 47/50
# 2188/2188 - 44s - loss: 0.2515 - accuracy: 0.9082 - val_loss: 0.1837 - val_accuracy: 0.9395 - 44s/epoch - 20ms/step
# Epoch 48/50
# 2188/2188 - 44s - loss: 0.2479 - accuracy: 0.9098 - val_loss: 0.1742 - val_accuracy: 0.9472 - 44s/epoch - 20ms/step
# Epoch 49/50
# 2188/2188 - 44s - loss: 0.2487 - accuracy: 0.9093 - val_loss: 0.1832 - val_accuracy: 0.9454 - 44s/epoch - 20ms/step
# Epoch 50/50
# 2188/2188 - 44s - loss: 0.2433 - accuracy: 0.9100 - val_loss: 0.1986 - val_accuracy: 0.9417 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.2019 - accuracy: 0.9351
# 274/274 [==============================] - 3s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 2.1939 - accuracy: 0.6973
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 126, 32)           5888
#
#  dropout_10 (Dropout)        (None, 126, 32)           0
#
#  lstm_11 (LSTM)              (None, 126, 32)           8320
#
#  dropout_11 (Dropout)        (None, 126, 32)           0
#
#  lstm_12 (LSTM)              (None, 126, 32)           8320
#
#  dropout_12 (Dropout)        (None, 126, 32)           0
#
#  lstm_13 (LSTM)              (None, 126, 32)           8320
#
#  dropout_13 (Dropout)        (None, 126, 32)           0
#
#  lstm_14 (LSTM)              (None, 126, 32)           8320
#
#  flatten_2 (Flatten)         (None, 4032)              0
#
#  dense_4 (Dense)             (None, 512)               2064896
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,109,194
# Trainable params: 2,109,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 50s - loss: 1.5353 - accuracy: 0.4332 - val_loss: 1.1940 - val_accuracy: 0.5566 - 50s/epoch - 23ms/step
# Epoch 2/50
# 2188/2188 - 44s - loss: 1.1770 - accuracy: 0.5663 - val_loss: 1.0688 - val_accuracy: 0.5993 - 44s/epoch - 20ms/step
# Epoch 3/50
# 2188/2188 - 44s - loss: 1.0265 - accuracy: 0.6210 - val_loss: 0.8435 - val_accuracy: 0.6981 - 44s/epoch - 20ms/step
# Epoch 4/50
# 2188/2188 - 44s - loss: 0.9235 - accuracy: 0.6571 - val_loss: 0.7721 - val_accuracy: 0.7179 - 44s/epoch - 20ms/step
# Epoch 5/50
# 2188/2188 - 44s - loss: 0.8535 - accuracy: 0.6842 - val_loss: 0.6988 - val_accuracy: 0.7381 - 44s/epoch - 20ms/step
# Epoch 6/50
# 2188/2188 - 44s - loss: 0.8004 - accuracy: 0.7055 - val_loss: 0.5855 - val_accuracy: 0.7874 - 44s/epoch - 20ms/step
# Epoch 7/50
# 2188/2188 - 44s - loss: 0.7492 - accuracy: 0.7204 - val_loss: 0.6005 - val_accuracy: 0.7791 - 44s/epoch - 20ms/step
# Epoch 8/50
# 2188/2188 - 44s - loss: 0.7131 - accuracy: 0.7366 - val_loss: 0.5493 - val_accuracy: 0.7982 - 44s/epoch - 20ms/step
# Epoch 9/50
# 2188/2188 - 44s - loss: 0.6815 - accuracy: 0.7466 - val_loss: 0.4983 - val_accuracy: 0.8163 - 44s/epoch - 20ms/step
# Epoch 10/50
# 2188/2188 - 44s - loss: 0.6486 - accuracy: 0.7603 - val_loss: 0.4666 - val_accuracy: 0.8305 - 44s/epoch - 20ms/step
# Epoch 11/50
# 2188/2188 - 44s - loss: 0.6228 - accuracy: 0.7702 - val_loss: 0.4692 - val_accuracy: 0.8256 - 44s/epoch - 20ms/step
# Epoch 12/50
# 2188/2188 - 44s - loss: 0.5941 - accuracy: 0.7813 - val_loss: 0.4485 - val_accuracy: 0.8336 - 44s/epoch - 20ms/step
# Epoch 13/50
# 2188/2188 - 44s - loss: 0.5677 - accuracy: 0.7886 - val_loss: 0.4464 - val_accuracy: 0.8402 - 44s/epoch - 20ms/step
# Epoch 14/50
# 2188/2188 - 44s - loss: 0.5566 - accuracy: 0.7967 - val_loss: 0.3842 - val_accuracy: 0.8600 - 44s/epoch - 20ms/step
# Epoch 15/50
# 2188/2188 - 44s - loss: 0.5358 - accuracy: 0.8029 - val_loss: 0.3841 - val_accuracy: 0.8561 - 44s/epoch - 20ms/step
# Epoch 16/50
# 2188/2188 - 44s - loss: 0.5149 - accuracy: 0.8074 - val_loss: 0.3631 - val_accuracy: 0.8653 - 44s/epoch - 20ms/step
# Epoch 17/50
# 2188/2188 - 44s - loss: 0.4985 - accuracy: 0.8158 - val_loss: 0.4515 - val_accuracy: 0.8339 - 44s/epoch - 20ms/step
# Epoch 18/50
# 2188/2188 - 44s - loss: 0.4816 - accuracy: 0.8213 - val_loss: 0.3624 - val_accuracy: 0.8658 - 44s/epoch - 20ms/step
# Epoch 19/50
# 2188/2188 - 44s - loss: 0.4729 - accuracy: 0.8237 - val_loss: 0.3032 - val_accuracy: 0.8905 - 44s/epoch - 20ms/step
# Epoch 20/50
# 2188/2188 - 44s - loss: 0.4541 - accuracy: 0.8304 - val_loss: 0.3021 - val_accuracy: 0.8906 - 44s/epoch - 20ms/step
# Epoch 21/50
# 2188/2188 - 44s - loss: 0.4451 - accuracy: 0.8350 - val_loss: 0.3131 - val_accuracy: 0.8851 - 44s/epoch - 20ms/step
# Epoch 22/50
# 2188/2188 - 44s - loss: 0.4318 - accuracy: 0.8401 - val_loss: 0.3017 - val_accuracy: 0.8898 - 44s/epoch - 20ms/step
# Epoch 23/50
# 2188/2188 - 44s - loss: 0.4207 - accuracy: 0.8442 - val_loss: 0.2783 - val_accuracy: 0.8977 - 44s/epoch - 20ms/step
# Epoch 24/50
# 2188/2188 - 44s - loss: 0.4133 - accuracy: 0.8463 - val_loss: 0.3421 - val_accuracy: 0.8746 - 44s/epoch - 20ms/step
# Epoch 25/50
# 2188/2188 - 44s - loss: 0.4083 - accuracy: 0.8483 - val_loss: 0.2633 - val_accuracy: 0.9040 - 44s/epoch - 20ms/step
# Epoch 26/50
# 2188/2188 - 44s - loss: 0.3965 - accuracy: 0.8534 - val_loss: 0.2516 - val_accuracy: 0.9080 - 44s/epoch - 20ms/step
# Epoch 27/50
# 2188/2188 - 44s - loss: 0.3860 - accuracy: 0.8561 - val_loss: 0.2501 - val_accuracy: 0.9059 - 44s/epoch - 20ms/step
# Epoch 28/50
# 2188/2188 - 44s - loss: 0.3776 - accuracy: 0.8590 - val_loss: 0.2291 - val_accuracy: 0.9177 - 44s/epoch - 20ms/step
# Epoch 29/50
# 2188/2188 - 44s - loss: 0.3724 - accuracy: 0.8620 - val_loss: 0.2527 - val_accuracy: 0.9089 - 44s/epoch - 20ms/step
# Epoch 30/50
# 2188/2188 - 44s - loss: 0.3635 - accuracy: 0.8669 - val_loss: 0.2531 - val_accuracy: 0.9101 - 44s/epoch - 20ms/step
# Epoch 31/50
# 2188/2188 - 44s - loss: 0.3545 - accuracy: 0.8686 - val_loss: 0.2663 - val_accuracy: 0.9017 - 44s/epoch - 20ms/step
# Epoch 32/50
# 2188/2188 - 44s - loss: 0.3494 - accuracy: 0.8710 - val_loss: 0.2610 - val_accuracy: 0.9053 - 44s/epoch - 20ms/step
# Epoch 33/50
# 2188/2188 - 44s - loss: 0.3405 - accuracy: 0.8726 - val_loss: 0.2286 - val_accuracy: 0.9197 - 44s/epoch - 20ms/step
# Epoch 34/50
# 2188/2188 - 44s - loss: 0.3386 - accuracy: 0.8753 - val_loss: 0.2200 - val_accuracy: 0.9202 - 44s/epoch - 20ms/step
# Epoch 35/50
# 2188/2188 - 44s - loss: 0.3283 - accuracy: 0.8784 - val_loss: 0.2202 - val_accuracy: 0.9210 - 44s/epoch - 20ms/step
# Epoch 36/50
# 2188/2188 - 44s - loss: 0.3251 - accuracy: 0.8796 - val_loss: 0.2478 - val_accuracy: 0.9104 - 44s/epoch - 20ms/step
# Epoch 37/50
# 2188/2188 - 44s - loss: 0.3141 - accuracy: 0.8836 - val_loss: 0.2082 - val_accuracy: 0.9238 - 44s/epoch - 20ms/step
# Epoch 38/50
# 2188/2188 - 44s - loss: 0.3111 - accuracy: 0.8852 - val_loss: 0.2012 - val_accuracy: 0.9280 - 44s/epoch - 20ms/step
# Epoch 39/50
# 2188/2188 - 44s - loss: 0.3078 - accuracy: 0.8864 - val_loss: 0.2045 - val_accuracy: 0.9261 - 44s/epoch - 20ms/step
# Epoch 40/50
# 2188/2188 - 44s - loss: 0.3051 - accuracy: 0.8875 - val_loss: 0.1979 - val_accuracy: 0.9305 - 44s/epoch - 20ms/step
# Epoch 41/50
# 2188/2188 - 44s - loss: 0.2941 - accuracy: 0.8925 - val_loss: 0.1999 - val_accuracy: 0.9293 - 44s/epoch - 20ms/step
# Epoch 42/50
# 2188/2188 - 44s - loss: 0.2896 - accuracy: 0.8933 - val_loss: 0.1933 - val_accuracy: 0.9346 - 44s/epoch - 20ms/step
# Epoch 43/50
# 2188/2188 - 44s - loss: 0.2865 - accuracy: 0.8933 - val_loss: 0.2077 - val_accuracy: 0.9261 - 44s/epoch - 20ms/step
# Epoch 44/50
# 2188/2188 - 44s - loss: 0.2836 - accuracy: 0.8962 - val_loss: 0.1850 - val_accuracy: 0.9379 - 44s/epoch - 20ms/step
# Epoch 45/50
# 2188/2188 - 44s - loss: 0.2778 - accuracy: 0.8979 - val_loss: 0.1814 - val_accuracy: 0.9363 - 44s/epoch - 20ms/step
# Epoch 46/50
# 2188/2188 - 44s - loss: 0.2800 - accuracy: 0.8964 - val_loss: 0.1797 - val_accuracy: 0.9370 - 44s/epoch - 20ms/step
# Epoch 47/50
# 2188/2188 - 44s - loss: 0.2726 - accuracy: 0.9002 - val_loss: 0.2066 - val_accuracy: 0.9286 - 44s/epoch - 20ms/step
# Epoch 48/50
# 2188/2188 - 44s - loss: 0.2707 - accuracy: 0.9009 - val_loss: 0.1713 - val_accuracy: 0.9410 - 44s/epoch - 20ms/step
# Epoch 49/50
# 2188/2188 - 44s - loss: 0.2655 - accuracy: 0.9018 - val_loss: 0.1898 - val_accuracy: 0.9366 - 44s/epoch - 20ms/step
# Epoch 50/50
# 2188/2188 - 44s - loss: 0.2590 - accuracy: 0.9044 - val_loss: 0.2066 - val_accuracy: 0.9282 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.2010 - accuracy: 0.9265
# 274/274 [==============================] - 4s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 2.0860 - accuracy: 0.6760
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 126, 32)           5888
#
#  dropout_15 (Dropout)        (None, 126, 32)           0
#
#  lstm_16 (LSTM)              (None, 126, 32)           8320
#
#  dropout_16 (Dropout)        (None, 126, 32)           0
#
#  lstm_17 (LSTM)              (None, 126, 32)           8320
#
#  dropout_17 (Dropout)        (None, 126, 32)           0
#
#  lstm_18 (LSTM)              (None, 126, 32)           8320
#
#  dropout_18 (Dropout)        (None, 126, 32)           0
#
#  lstm_19 (LSTM)              (None, 126, 32)           8320
#
#  flatten_3 (Flatten)         (None, 4032)              0
#
#  dense_6 (Dense)             (None, 512)               2064896
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,109,194
# Trainable params: 2,109,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 50s - loss: 1.5462 - accuracy: 0.4262 - val_loss: 1.1722 - val_accuracy: 0.5675 - 50s/epoch - 23ms/step
# Epoch 2/50
# 2188/2188 - 44s - loss: 1.1625 - accuracy: 0.5718 - val_loss: 0.9438 - val_accuracy: 0.6434 - 44s/epoch - 20ms/step
# Epoch 3/50
# 2188/2188 - 44s - loss: 1.0095 - accuracy: 0.6255 - val_loss: 0.8532 - val_accuracy: 0.6742 - 44s/epoch - 20ms/step
# Epoch 4/50
# 2188/2188 - 44s - loss: 0.9073 - accuracy: 0.6616 - val_loss: 0.7927 - val_accuracy: 0.7032 - 44s/epoch - 20ms/step
# Epoch 5/50
# 2188/2188 - 44s - loss: 0.8260 - accuracy: 0.6922 - val_loss: 0.6696 - val_accuracy: 0.7451 - 44s/epoch - 20ms/step
# Epoch 6/50
# 2188/2188 - 44s - loss: 0.7612 - accuracy: 0.7176 - val_loss: 0.6104 - val_accuracy: 0.7722 - 44s/epoch - 20ms/step
# Epoch 7/50
# 2188/2188 - 44s - loss: 0.7112 - accuracy: 0.7348 - val_loss: 0.5403 - val_accuracy: 0.7984 - 44s/epoch - 20ms/step
# Epoch 8/50
# 2188/2188 - 41s - loss: 0.6799 - accuracy: 0.7477 - val_loss: 0.4926 - val_accuracy: 0.8245 - 41s/epoch - 19ms/step
# Epoch 9/50
# 2188/2188 - 41s - loss: 0.6454 - accuracy: 0.7596 - val_loss: 0.4945 - val_accuracy: 0.8145 - 41s/epoch - 19ms/step
# Epoch 10/50
# 2188/2188 - 44s - loss: 0.6132 - accuracy: 0.7731 - val_loss: 0.4374 - val_accuracy: 0.8374 - 44s/epoch - 20ms/step
# Epoch 11/50
# 2188/2188 - 44s - loss: 0.5875 - accuracy: 0.7804 - val_loss: 0.4106 - val_accuracy: 0.8505 - 44s/epoch - 20ms/step
# Epoch 12/50
# 2188/2188 - 44s - loss: 0.5617 - accuracy: 0.7911 - val_loss: 0.3960 - val_accuracy: 0.8581 - 44s/epoch - 20ms/step
# Epoch 13/50
# 2188/2188 - 44s - loss: 0.5370 - accuracy: 0.8009 - val_loss: 0.4098 - val_accuracy: 0.8518 - 44s/epoch - 20ms/step
# Epoch 14/50
# 2188/2188 - 44s - loss: 0.5254 - accuracy: 0.8061 - val_loss: 0.3505 - val_accuracy: 0.8738 - 44s/epoch - 20ms/step
# Epoch 15/50
# 2188/2188 - 44s - loss: 0.5089 - accuracy: 0.8126 - val_loss: 0.3608 - val_accuracy: 0.8680 - 44s/epoch - 20ms/step
# Epoch 16/50
# 2188/2188 - 44s - loss: 0.4908 - accuracy: 0.8184 - val_loss: 0.3128 - val_accuracy: 0.8863 - 44s/epoch - 20ms/step
# Epoch 17/50
# 2188/2188 - 44s - loss: 0.4695 - accuracy: 0.8257 - val_loss: 0.3080 - val_accuracy: 0.8882 - 44s/epoch - 20ms/step
# Epoch 18/50
# 2188/2188 - 44s - loss: 0.4508 - accuracy: 0.8313 - val_loss: 0.3209 - val_accuracy: 0.8785 - 44s/epoch - 20ms/step
# Epoch 19/50
# 2188/2188 - 44s - loss: 0.4444 - accuracy: 0.8341 - val_loss: 0.3300 - val_accuracy: 0.8817 - 44s/epoch - 20ms/step
# Epoch 20/50
# 2188/2188 - 44s - loss: 0.4341 - accuracy: 0.8375 - val_loss: 0.2982 - val_accuracy: 0.8923 - 44s/epoch - 20ms/step
# Epoch 21/50
# 2188/2188 - 44s - loss: 0.4198 - accuracy: 0.8443 - val_loss: 0.3271 - val_accuracy: 0.8841 - 44s/epoch - 20ms/step
# Epoch 22/50
# 2188/2188 - 44s - loss: 0.4076 - accuracy: 0.8486 - val_loss: 0.2837 - val_accuracy: 0.8987 - 44s/epoch - 20ms/step
# Epoch 23/50
# 2188/2188 - 44s - loss: 0.4004 - accuracy: 0.8519 - val_loss: 0.3043 - val_accuracy: 0.8936 - 44s/epoch - 20ms/step
# Epoch 24/50
# 2188/2188 - 44s - loss: 0.3982 - accuracy: 0.8519 - val_loss: 0.2881 - val_accuracy: 0.8958 - 44s/epoch - 20ms/step
# Epoch 25/50
# 2188/2188 - 44s - loss: 0.3830 - accuracy: 0.8568 - val_loss: 0.2485 - val_accuracy: 0.9113 - 44s/epoch - 20ms/step
# Epoch 26/50
# 2188/2188 - 44s - loss: 0.3702 - accuracy: 0.8630 - val_loss: 0.2517 - val_accuracy: 0.9109 - 44s/epoch - 20ms/step
# Epoch 27/50
# 2188/2188 - 44s - loss: 0.3673 - accuracy: 0.8660 - val_loss: 0.2470 - val_accuracy: 0.9121 - 44s/epoch - 20ms/step
# Epoch 28/50
# 2188/2188 - 44s - loss: 0.3564 - accuracy: 0.8664 - val_loss: 0.2148 - val_accuracy: 0.9277 - 44s/epoch - 20ms/step
# Epoch 29/50
# 2188/2188 - 44s - loss: 0.3471 - accuracy: 0.8715 - val_loss: 0.2451 - val_accuracy: 0.9157 - 44s/epoch - 20ms/step
# Epoch 30/50
# 2188/2188 - 44s - loss: 0.3457 - accuracy: 0.8722 - val_loss: 0.2248 - val_accuracy: 0.9210 - 44s/epoch - 20ms/step
# Epoch 31/50
# 2188/2188 - 44s - loss: 0.3325 - accuracy: 0.8768 - val_loss: 0.2402 - val_accuracy: 0.9160 - 44s/epoch - 20ms/step
# Epoch 32/50
# 2188/2188 - 44s - loss: 0.3321 - accuracy: 0.8771 - val_loss: 0.2229 - val_accuracy: 0.9256 - 44s/epoch - 20ms/step
# Epoch 33/50
# 2188/2188 - 44s - loss: 0.3274 - accuracy: 0.8794 - val_loss: 0.1909 - val_accuracy: 0.9357 - 44s/epoch - 20ms/step
# Epoch 34/50
# 2188/2188 - 44s - loss: 0.3152 - accuracy: 0.8838 - val_loss: 0.2309 - val_accuracy: 0.9187 - 44s/epoch - 20ms/step
# Epoch 35/50
# 2188/2188 - 44s - loss: 0.3135 - accuracy: 0.8833 - val_loss: 0.2017 - val_accuracy: 0.9314 - 44s/epoch - 20ms/step
# Epoch 36/50
# 2188/2188 - 44s - loss: 0.3099 - accuracy: 0.8850 - val_loss: 0.2173 - val_accuracy: 0.9256 - 44s/epoch - 20ms/step
# Epoch 37/50
# 2188/2188 - 44s - loss: 0.3023 - accuracy: 0.8871 - val_loss: 0.2109 - val_accuracy: 0.9262 - 44s/epoch - 20ms/step
# Epoch 38/50
# 2188/2188 - 44s - loss: 0.2965 - accuracy: 0.8921 - val_loss: 0.1813 - val_accuracy: 0.9363 - 44s/epoch - 20ms/step
# Epoch 39/50
# 2188/2188 - 44s - loss: 0.2926 - accuracy: 0.8904 - val_loss: 0.1994 - val_accuracy: 0.9312 - 44s/epoch - 20ms/step
# Epoch 40/50
# 2188/2188 - 44s - loss: 0.2873 - accuracy: 0.8928 - val_loss: 0.2467 - val_accuracy: 0.9198 - 44s/epoch - 20ms/step
# Epoch 41/50
# 2188/2188 - 44s - loss: 0.2803 - accuracy: 0.8952 - val_loss: 0.2028 - val_accuracy: 0.9304 - 44s/epoch - 20ms/step
# Epoch 42/50
# 2188/2188 - 44s - loss: 0.2790 - accuracy: 0.8960 - val_loss: 0.1738 - val_accuracy: 0.9424 - 44s/epoch - 20ms/step
# Epoch 43/50
# 2188/2188 - 44s - loss: 0.2760 - accuracy: 0.8982 - val_loss: 0.1826 - val_accuracy: 0.9386 - 44s/epoch - 20ms/step
# Epoch 44/50
# 2188/2188 - 44s - loss: 0.2722 - accuracy: 0.9002 - val_loss: 0.1592 - val_accuracy: 0.9477 - 44s/epoch - 20ms/step
# Epoch 45/50
# 2188/2188 - 44s - loss: 0.2674 - accuracy: 0.9034 - val_loss: 0.1816 - val_accuracy: 0.9352 - 44s/epoch - 20ms/step
# Epoch 46/50
# 2188/2188 - 44s - loss: 0.2628 - accuracy: 0.9031 - val_loss: 0.1701 - val_accuracy: 0.9429 - 44s/epoch - 20ms/step
# Epoch 47/50
# 2188/2188 - 44s - loss: 0.2604 - accuracy: 0.9042 - val_loss: 0.1761 - val_accuracy: 0.9409 - 44s/epoch - 20ms/step
# Epoch 48/50
# 2188/2188 - 44s - loss: 0.2562 - accuracy: 0.9064 - val_loss: 0.1949 - val_accuracy: 0.9341 - 44s/epoch - 20ms/step
# Epoch 49/50
# 2188/2188 - 44s - loss: 0.2528 - accuracy: 0.9062 - val_loss: 0.1784 - val_accuracy: 0.9424 - 44s/epoch - 20ms/step
# Epoch 50/50
# 2188/2188 - 44s - loss: 0.2493 - accuracy: 0.9074 - val_loss: 0.1792 - val_accuracy: 0.9410 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.1867 - accuracy: 0.9365
# 274/274 [==============================] - 3s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 2.0189 - accuracy: 0.7036
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 8ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 126, 32)           5888
#
#  dropout_20 (Dropout)        (None, 126, 32)           0
#
#  lstm_21 (LSTM)              (None, 126, 32)           8320
#
#  dropout_21 (Dropout)        (None, 126, 32)           0
#
#  lstm_22 (LSTM)              (None, 126, 32)           8320
#
#  dropout_22 (Dropout)        (None, 126, 32)           0
#
#  lstm_23 (LSTM)              (None, 126, 32)           8320
#
#  dropout_23 (Dropout)        (None, 126, 32)           0
#
#  lstm_24 (LSTM)              (None, 126, 32)           8320
#
#  flatten_4 (Flatten)         (None, 4032)              0
#
#  dense_8 (Dense)             (None, 512)               2064896
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2,109,194
# Trainable params: 2,109,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2188/2188 - 50s - loss: 1.5261 - accuracy: 0.4372 - val_loss: 1.1260 - val_accuracy: 0.5907 - 50s/epoch - 23ms/step
# Epoch 2/50
# 2188/2188 - 44s - loss: 1.1385 - accuracy: 0.5803 - val_loss: 1.0142 - val_accuracy: 0.6161 - 44s/epoch - 20ms/step
# Epoch 3/50
# 2188/2188 - 44s - loss: 0.9857 - accuracy: 0.6356 - val_loss: 0.7628 - val_accuracy: 0.7167 - 44s/epoch - 20ms/step
# Epoch 4/50
# 2188/2188 - 44s - loss: 0.8857 - accuracy: 0.6726 - val_loss: 0.6845 - val_accuracy: 0.7505 - 44s/epoch - 20ms/step
# Epoch 5/50
# 2188/2188 - 44s - loss: 0.8164 - accuracy: 0.6966 - val_loss: 0.7307 - val_accuracy: 0.7286 - 44s/epoch - 20ms/step
# Epoch 6/50
# 2188/2188 - 44s - loss: 0.7572 - accuracy: 0.7214 - val_loss: 0.6028 - val_accuracy: 0.7685 - 44s/epoch - 20ms/step
# Epoch 7/50
# 2188/2188 - 44s - loss: 0.7072 - accuracy: 0.7385 - val_loss: 0.5765 - val_accuracy: 0.7889 - 44s/epoch - 20ms/step
# Epoch 8/50
# 2188/2188 - 44s - loss: 0.6694 - accuracy: 0.7537 - val_loss: 0.5086 - val_accuracy: 0.8031 - 44s/epoch - 20ms/step
# Epoch 9/50
# 2188/2188 - 44s - loss: 0.6399 - accuracy: 0.7636 - val_loss: 0.4818 - val_accuracy: 0.8197 - 44s/epoch - 20ms/step
# Epoch 10/50
# 2188/2188 - 44s - loss: 0.6000 - accuracy: 0.7776 - val_loss: 0.4150 - val_accuracy: 0.8502 - 44s/epoch - 20ms/step
# Epoch 11/50
# 2188/2188 - 44s - loss: 0.5751 - accuracy: 0.7886 - val_loss: 0.4086 - val_accuracy: 0.8491 - 44s/epoch - 20ms/step
# Epoch 12/50
# 2188/2188 - 44s - loss: 0.5531 - accuracy: 0.7963 - val_loss: 0.3824 - val_accuracy: 0.8592 - 44s/epoch - 20ms/step
# Epoch 13/50
# 2188/2188 - 44s - loss: 0.5313 - accuracy: 0.8041 - val_loss: 0.3570 - val_accuracy: 0.8664 - 44s/epoch - 20ms/step
# Epoch 14/50
# 2188/2188 - 44s - loss: 0.5069 - accuracy: 0.8122 - val_loss: 0.3557 - val_accuracy: 0.8714 - 44s/epoch - 20ms/step
# Epoch 15/50
# 2188/2188 - 44s - loss: 0.4913 - accuracy: 0.8183 - val_loss: 0.3339 - val_accuracy: 0.8769 - 44s/epoch - 20ms/step
# Epoch 16/50
# 2188/2188 - 44s - loss: 0.4746 - accuracy: 0.8246 - val_loss: 0.3510 - val_accuracy: 0.8682 - 44s/epoch - 20ms/step
# Epoch 17/50
# 2188/2188 - 44s - loss: 0.4645 - accuracy: 0.8283 - val_loss: 0.3273 - val_accuracy: 0.8773 - 44s/epoch - 20ms/step
# Epoch 18/50
# 2188/2188 - 44s - loss: 0.4435 - accuracy: 0.8350 - val_loss: 0.2881 - val_accuracy: 0.8949 - 44s/epoch - 20ms/step
# Epoch 19/50
# 2188/2188 - 44s - loss: 0.4389 - accuracy: 0.8390 - val_loss: 0.2732 - val_accuracy: 0.9002 - 44s/epoch - 20ms/step
# Epoch 20/50
# 2188/2188 - 44s - loss: 0.4279 - accuracy: 0.8420 - val_loss: 0.3240 - val_accuracy: 0.8813 - 44s/epoch - 20ms/step
# Epoch 21/50
# 2188/2188 - 44s - loss: 0.4067 - accuracy: 0.8487 - val_loss: 0.2690 - val_accuracy: 0.9010 - 44s/epoch - 20ms/step
# Epoch 22/50
# 2188/2188 - 44s - loss: 0.4031 - accuracy: 0.8507 - val_loss: 0.3169 - val_accuracy: 0.8815 - 44s/epoch - 20ms/step
# Epoch 23/50
# 2188/2188 - 44s - loss: 0.3899 - accuracy: 0.8557 - val_loss: 0.2503 - val_accuracy: 0.9099 - 44s/epoch - 20ms/step
# Epoch 24/50
# 2188/2188 - 44s - loss: 0.3837 - accuracy: 0.8582 - val_loss: 0.2386 - val_accuracy: 0.9129 - 44s/epoch - 20ms/step
# Epoch 25/50
# 2188/2188 - 44s - loss: 0.3689 - accuracy: 0.8634 - val_loss: 0.2259 - val_accuracy: 0.9146 - 44s/epoch - 20ms/step
# Epoch 26/50
# 2188/2188 - 44s - loss: 0.3597 - accuracy: 0.8666 - val_loss: 0.2484 - val_accuracy: 0.9111 - 44s/epoch - 20ms/step
# Epoch 27/50
# 2188/2188 - 44s - loss: 0.3624 - accuracy: 0.8663 - val_loss: 0.2262 - val_accuracy: 0.9195 - 44s/epoch - 20ms/step
# Epoch 28/50
# 2188/2188 - 44s - loss: 0.3548 - accuracy: 0.8676 - val_loss: 0.2278 - val_accuracy: 0.9200 - 44s/epoch - 20ms/step
# Epoch 29/50
# 2188/2188 - 44s - loss: 0.3420 - accuracy: 0.8720 - val_loss: 0.2234 - val_accuracy: 0.9186 - 44s/epoch - 20ms/step
# Epoch 30/50
# 2188/2188 - 44s - loss: 0.3348 - accuracy: 0.8769 - val_loss: 0.2022 - val_accuracy: 0.9278 - 44s/epoch - 20ms/step
# Epoch 31/50
# 2188/2188 - 44s - loss: 0.3329 - accuracy: 0.8766 - val_loss: 0.2276 - val_accuracy: 0.9181 - 44s/epoch - 20ms/step
# Epoch 32/50
# 2188/2188 - 44s - loss: 0.3231 - accuracy: 0.8818 - val_loss: 0.2081 - val_accuracy: 0.9267 - 44s/epoch - 20ms/step
# Epoch 33/50
# 2188/2188 - 44s - loss: 0.3179 - accuracy: 0.8827 - val_loss: 0.2091 - val_accuracy: 0.9247 - 44s/epoch - 20ms/step
# Epoch 34/50
# 2188/2188 - 44s - loss: 0.3152 - accuracy: 0.8837 - val_loss: 0.1797 - val_accuracy: 0.9349 - 44s/epoch - 20ms/step
# Epoch 35/50
# 2188/2188 - 44s - loss: 0.3088 - accuracy: 0.8850 - val_loss: 0.2051 - val_accuracy: 0.9265 - 44s/epoch - 20ms/step
# Epoch 36/50
# 2188/2188 - 44s - loss: 0.2968 - accuracy: 0.8901 - val_loss: 0.1987 - val_accuracy: 0.9288 - 44s/epoch - 20ms/step
# Epoch 37/50
# 2188/2188 - 44s - loss: 0.2963 - accuracy: 0.8895 - val_loss: 0.2025 - val_accuracy: 0.9283 - 44s/epoch - 20ms/step
# Epoch 38/50
# 2188/2188 - 44s - loss: 0.2859 - accuracy: 0.8935 - val_loss: 0.1919 - val_accuracy: 0.9335 - 44s/epoch - 20ms/step
# Epoch 39/50
# 2188/2188 - 44s - loss: 0.2871 - accuracy: 0.8934 - val_loss: 0.1876 - val_accuracy: 0.9346 - 44s/epoch - 20ms/step
# Epoch 40/50
# 2188/2188 - 44s - loss: 0.2815 - accuracy: 0.8969 - val_loss: 0.1833 - val_accuracy: 0.9344 - 44s/epoch - 20ms/step
# Epoch 41/50
# 2188/2188 - 44s - loss: 0.2737 - accuracy: 0.8983 - val_loss: 0.1762 - val_accuracy: 0.9366 - 44s/epoch - 20ms/step
# Epoch 42/50
# 2188/2188 - 44s - loss: 0.2751 - accuracy: 0.8987 - val_loss: 0.1792 - val_accuracy: 0.9391 - 44s/epoch - 20ms/step
# Epoch 43/50
# 2188/2188 - 44s - loss: 0.2729 - accuracy: 0.8997 - val_loss: 0.1767 - val_accuracy: 0.9382 - 44s/epoch - 20ms/step
# Epoch 44/50
# 2188/2188 - 44s - loss: 0.2682 - accuracy: 0.9028 - val_loss: 0.1667 - val_accuracy: 0.9427 - 44s/epoch - 20ms/step
# Epoch 45/50
# 2188/2188 - 44s - loss: 0.2621 - accuracy: 0.9043 - val_loss: 0.1811 - val_accuracy: 0.9355 - 44s/epoch - 20ms/step
# Epoch 46/50
# 2188/2188 - 44s - loss: 0.2580 - accuracy: 0.9057 - val_loss: 0.1817 - val_accuracy: 0.9390 - 44s/epoch - 20ms/step
# Epoch 47/50
# 2188/2188 - 44s - loss: 0.2549 - accuracy: 0.9061 - val_loss: 0.2175 - val_accuracy: 0.9256 - 44s/epoch - 20ms/step
# Epoch 48/50
# 2188/2188 - 44s - loss: 0.2481 - accuracy: 0.9087 - val_loss: 0.1495 - val_accuracy: 0.9478 - 44s/epoch - 20ms/step
# Epoch 49/50
# 2188/2188 - 44s - loss: 0.2464 - accuracy: 0.9078 - val_loss: 0.1876 - val_accuracy: 0.9322 - 44s/epoch - 20ms/step
# Epoch 50/50
# 2188/2188 - 44s - loss: 0.2447 - accuracy: 0.9100 - val_loss: 0.1981 - val_accuracy: 0.9342 - 44s/epoch - 20ms/step
# 274/274 [==============================] - 2s 9ms/step - loss: 0.1992 - accuracy: 0.9331
# 274/274 [==============================] - 3s 8ms/step
# 128/128 [==============================] - 1s 9ms/step - loss: 2.1708 - accuracy: 0.7014
# 128/128 [==============================] - 1s 9ms/step
# 274/274 [==============================] - 2s 8ms/step
