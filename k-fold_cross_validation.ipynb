# %%
import numpy as np
import pandas as pd
import librosa
import os
import glob
import re
import seaborn as sn
import matplotlib.pyplot as plt
import scipy
import time
import collections
import keras
import random
from keras.utils import np_utils
from keras.layers import MaxPooling1D, Conv1D, Conv2D, MaxPooling2D, GlobalAveragePooling2D, LSTM, ELU, Bidirectional, Attention
from keras.layers import Dense, Dropout, Activation, Flatten, CuDNNLSTM
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import tensorflow as tf
import pickle
from keras.utils.vis_utils import plot_model
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix
import keras_tuner
from keras import backend as K
import shutil
import os
import tensorflow_addons as tfa
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense
from sklearn import metrics
# Out:
# 2023-05-14 02:14:29.841686: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-14 02:14:30.601306: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/stenmarken/miniconda3/envs/tensorflow/lib/:/home/stenmarken/miniconda3/envs/tensorflow/lib/
# 2023-05-14 02:14:30.601374: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ros/noetic/lib:/home/stenmarken/miniconda3/envs/tensorflow/lib/:/home/stenmarken/miniconda3/envs/tensorflow/lib/
# 2023-05-14 02:14:30.601380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Global variables

# %%
global_model_type = 'cnn'
global_folder_name = 'cnn_base_model_new_dr_lr'
file_suffix = 'weyo1'
global_batch_size = 32
global_epochs = 50
global_learning_rate = 0.001
own_file_path = os.getcwd() 
global_hyperparameter_folder_name = 'lstm_new_lr_12_05'  #lstm_filter_size_dropout1' #'cnn_filter_size_dropout'
optimized_model = False # Om satt till True körs den hyperparameter tune:ade modellen. Annars base_model

# %%
def instrument_code(filename):
    """
    Function that takes in a filename and returns instrument based on naming convention
    """
    # Synth lead borttagen. id = 9
    class_names=['bass', 'brass', 'flute', 'guitar', 
             'keyboard', 'mallet', 'organ', 'reed', 
             'string', 'vocal']
    
    for name in class_names:
        if name in filename:
            return class_names.index(name)
    else:
        return None

# %% [markdown]
# ## Get data

# %%
def get_data_from_file(file):
    with open(file, "rb") as f:
        X_train_full  = pickle.load(f)

    X_train = []
    y_train = []

    for (key, value) in X_train_full:
        X_train.append(value)
        y_train.append(instrument_code(key))

    X_train_numpy = np.array(X_train)
    y_train_numpy = np.array(y_train)
    return (X_train_numpy, y_train_numpy)

# %%
def get_old_test_data(file):
    with open(file, 'rb') as f:
        old_X_test_full = pickle.load(f)

    old_X_test = []
    old_y_test = []

    for(key, value) in old_X_test_full.items():
        #temporal_value = np.mean(value, axis = 1)
        old_X_test.append(value)
        old_y_test.append(instrument_code(key))
        
    old_y_test_numpy = np.asarray(old_y_test)
    old_X_test_numpy = np.asarray(old_X_test)
    return (old_X_test_numpy, old_y_test_numpy)

# %% [markdown]
# ### Calculate metrics

# %%
def calc_metrics(y_true, y_pred):
    print(metrics.classification_report(y_true, y_pred, digits=3))

# %%
def hyperparameter_cnn_model(hp):
    """
    Function that builds a CNN model with optimized hyperparameters including filter size and dropout rate
    """

    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same', input_shape=(126, 13, 1)))
    model.add(Conv2D(32, kernel_size=(3, 3), 
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))

    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_1', values = [32, 64, 128]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Conv2D(filters = hp.Choice('conv_2_filters_2', values = [32, 64, 128, 256]), kernel_size=(3, 3),
                    activation='relu', padding='same'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def hyperparameter_lstm_model(hp):
    """
    Function that builds a LSTM model with optimized hyperparameters including filter size and dropout rate
    """
    
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_1', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    model.add(LSTM(units = hp.Choice('lstm_layer_units_2', values = [32, 64, 128]), return_sequences=True))
    model.add(Dropout(hp.Float('dropout_lstm', min_value=0.1, max_value=0.5, step=0.1)))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer=Adam(learning_rate=global_learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_cnn_model():    
    input_shape = (126, 13, 1)
    cnn_dropout_rate = 0.5
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(cnn_dropout_rate))

    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(cnn_dropout_rate))

    model.add(Conv2D(128,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_cnn_model():
    input_shape = (126, 13, 1)
    dropout_1 = 0.2 
    conv_2_filters_1 = 128
    conv_2_filters_2 = 128

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(conv_2_filters_1, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout_1))

    model.add(Conv2D(conv_2_filters_2,(3, 3), padding='same', activation='relu'))
    model.add(Dropout(dropout_1))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_lstm_model():
    model = Sequential()
    #model.add(Bidirectional(CuDNNLSTM(128, return_sequences=True), input_shape=(126, 128)))
    #model.add(CuDNNLSTM(4, input_shape=(126, 128), return_sequences=True))
    #model.add(Dropout(0.5))
    lstm_dropout_rate = 0.25
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    model.add(Dropout(lstm_dropout_rate))
    model.add(LSTM(32, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def build_optimized_lstm_model():
    dropout_lstm = 0.3
    lstm_layer_units_1 = 32
    lstm_layer_units_2 = 128
    model = Sequential()
    model.add(LSTM(32, input_shape=(126, 13), return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_1, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    model.add(Dropout(dropout_lstm))
    model.add(LSTM(lstm_layer_units_2, return_sequences=True))
    #model.add(LSTM(16, return_sequences=True))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def plot_acc_loss(history, acc_file_path, loss_file_path):
    # Taget från https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    # summarize history for accuracy
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(acc_file_path)
    plt.show()

    # summarize history for loss
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig(loss_file_path)
    plt.show()

# %%
    
def plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path):    
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    result = confusion_matrix(y_test, y_prediction , normalize='pred')

    df_cm = pd.DataFrame(result, index = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]],
                    columns = [i for i in ["bass", "brass", "flute", "guitar", "keyboard", "mallet", "organ", "reed", "string", "vocal"]])

    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig(confusion_matrix_file_path)
    plt.show()

# %%
def run_cnn(fold_index):

    old_test_file = 'CustomDataFull/testdata2000.pkl'

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/cnn_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

    if optimized_model:
        model = build_optimized_cnn_model()
    else:
        model = build_cnn_model()
        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)

    print("\n\ny_test : ", y_test)
    print("\n\ny_prediction : ", y_prediction)

    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)

    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores:\n' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata:\n' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %%
def run_lstm(fold_index):
    old_test_file = 'CustomDataFull/testdata2000.pkl'
    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    old_X_test, old_y_test = get_old_test_data(old_test_file)

    fold_path = 'results/lstm_results/' + global_folder_name + '/' + str(fold_index) + file_suffix + '/'
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)


    if optimized_model:
        model = build_optimized_lstm_model()
    else:
        model = build_lstm_model()

        
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy'])
    #model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=global_learning_rate), metrics=['accuracy', 
    #              tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=10, average='macro',
    #              threshold=0.5)])
    
    model.summary()
    history = model.fit(x=X_train, y=y_train, validation_data=(X_valid, y_valid), batch_size=global_batch_size, epochs=global_epochs, shuffle=True, verbose=2)
    model.save(fold_path + str(fold_index) + 'model_' + file_suffix + '.h5')

    history_name = fold_path + str(fold_index) + 'history_' + file_suffix + '.history'

    with open(history_name, 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

    scores = model.evaluate(X_test, y_test, verbose=1)
    y_prediction = model.predict(X_test)
    y_prediction = np.argmax(y_prediction, axis = 1)
    f1_scores = metrics.classification_report(y_test, y_prediction, digits=3)

    original_scores = model.evaluate(old_X_test, old_y_test, verbose=1)
    original_y_prediction = model.predict(old_X_test)
    original_y_prediction = np.argmax(original_y_prediction, axis = 1)
    original_f1_scores = metrics.classification_report(old_y_test, original_y_prediction, digits=3)
    
    score_file = fold_path + str(fold_index) + 'score_' + file_suffix + '.txt'
    with open(score_file, 'w') as f:
        f.write('fold: ' + str(fold_index) + '\n')
        f.write('scores: ' + str(scores) + '\n')
        f.write('scores with original testdata: ' + str(original_scores) + '\n')
        f.write('f1_scores: ' + str(f1_scores) + '\n')
        f.write('f1_scores with original testdata: ' + str(original_f1_scores) + '\n')

    loss_file_path = fold_path + str(fold_index) + 'loss_' + file_suffix + '.png'
    acc_file_path = fold_path + str(fold_index) + 'acc_' + file_suffix + '.png'
    plot_acc_loss(history.history, acc_file_path, loss_file_path)

    confusion_matrix_file_path = fold_path + str(fold_index) + 'confusion_matrix_' + file_suffix + '.png'
    plt_confusion_matrix(model, X_test, y_test, confusion_matrix_file_path)

# %% [markdown]
# ### Hyperparameter tuning

# %%
def tune_cnn():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_cnn_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
        f.write(str(tuner.results_summary()) + '\n')

    tuner.results_summary()

    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'cnn-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %%
def tune_lstm():
    """
    OBS! Efter en körning så printas summaryn över resultaten gällande de olika hyperparametrarna. Spara dom!
    """
    tuner = keras_tuner.RandomSearch(hyperparameter_lstm_model, overwrite=True, objective='val_accuracy', max_trials=5, executions_per_trial=2, directory='hyperparameters', project_name=global_hyperparameter_folder_name)
    tuner.search_space_summary()
    fold_index = 0 # Godtyckligt val!!!

    train_file = 'folds/' + str(fold_index) + 'train_' + file_suffix
    test_file = 'folds/' + str(fold_index) + 'test_' + file_suffix
    valid_file = 'folds/' + str(fold_index) + 'valid_' + file_suffix

    X_train, y_train = get_data_from_file(train_file)
    X_test, y_test = get_data_from_file(test_file)
    X_valid, y_valid = get_data_from_file(valid_file)
    tuner.search(X_train, y_train, epochs=global_epochs, batch_size=global_batch_size, validation_data=(X_valid, y_valid), shuffle=True, verbose=2, callbacks=[tf.keras.callbacks.TensorBoard(log_dir='hyperparameters/' + global_hyperparameter_folder_name)])
    
    print(tuner.get_best_hyperparameters()[0].values)

    hyperparameter_log_name = 'hyperparameters/' + global_hyperparameter_folder_name + '/log.txt'

    with open(hyperparameter_log_name, 'w') as f:
        f.write('best hyperparameters: ' + str(tuner.get_best_hyperparameters()[0].values) + '\n')
    
    tuner.results_summary()
    
    copy_file = 'hyperparameters/' + global_hyperparameter_folder_name + '/' + 'lstm-hyperparameter_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

# %% [markdown]
# ### Run 5-fold cross validation

# %%
def run_cnn_5_fold_cross_validation():
    path = 'results/cnn_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)

    copy_file = 'results/cnn_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_cnn(i)

# %%
def run_lstm_5_fold_cross_validation():
    path = 'results/lstm_results/' + global_folder_name
    if not os.path.exists(path):
        os.makedirs(path)
    
    copy_file = 'results/lstm_results/' + global_folder_name + '/' + 'copied_model.ipynb'
    own_file_name = own_file_path + '/k-fold_cross_validation.ipynb'
    shutil.copyfile(own_file_name, copy_file)

    for i in range(0, 5):
        run_lstm(i)

# %%
if (global_model_type == 'cnn'):
    print('Start running cnn')
    run_cnn_5_fold_cross_validation()
elif (global_model_type == 'lstm'):
    print('Start running lstm')
    run_lstm_5_fold_cross_validation()
elif (global_model_type == 'tune_cnn'):
    print('Start tuning cnn')
    tune_cnn()
elif (global_model_type == 'tune_lstm'):
    print('Start tuning lstm')
    tune_lstm()
# Out:
# Start running cnn
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 13, 32)       320
#
#  conv2d_1 (Conv2D)           (None, 126, 13, 32)       9248
#
#  max_pooling2d (MaxPooling2D  (None, 63, 6, 32)        0
#  )
#
#  dropout (Dropout)           (None, 63, 6, 32)         0
#
#  conv2d_2 (Conv2D)           (None, 63, 6, 64)         18496
#
#  conv2d_3 (Conv2D)           (None, 63, 6, 64)         36928
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 3, 64)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 31, 3, 64)         0
#
#  conv2d_4 (Conv2D)           (None, 31, 3, 128)        73856
#
#  dropout_2 (Dropout)         (None, 31, 3, 128)        0
#
#  flatten (Flatten)           (None, 11904)             0
#
#  dense (Dense)               (None, 512)               6095360
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,239,338
# Trainable params: 6,239,338
# Non-trainable params: 0
# _________________________________________________________________
# 2023-05-14 02:15:02.095859: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.100171: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.100405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.100762: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-14 02:15:02.101170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.101346: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.101508: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.515158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.515428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.515680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-14 02:15:02.515848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4244 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:26:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-05-14 02:15:03.731713: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-05-14 02:15:04.187935: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8201
# 2023-05-14 02:15:05.129074: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f9ff5ba3210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-14 02:15:05.129098: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 SUPER, Compute Capability 7.5
# 2023-05-14 02:15:05.132439: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-14 02:15:05.758923: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2188/2188 - 20s - loss: 1.6153 - accuracy: 0.4008 - val_loss: 1.3416 - val_accuracy: 0.5081 - 20s/epoch - 9ms/step
# Epoch 2/50
# 2188/2188 - 15s - loss: 1.1715 - accuracy: 0.5652 - val_loss: 1.1282 - val_accuracy: 0.5896 - 15s/epoch - 7ms/step
# Epoch 3/50
# 2188/2188 - 15s - loss: 1.0217 - accuracy: 0.6251 - val_loss: 1.1673 - val_accuracy: 0.5569 - 15s/epoch - 7ms/step
# Epoch 4/50
# 2188/2188 - 15s - loss: 0.9258 - accuracy: 0.6571 - val_loss: 1.1160 - val_accuracy: 0.5733 - 15s/epoch - 7ms/step
# Epoch 5/50
# 2188/2188 - 15s - loss: 0.8439 - accuracy: 0.6877 - val_loss: 0.9910 - val_accuracy: 0.6278 - 15s/epoch - 7ms/step
# Epoch 6/50
# 2188/2188 - 15s - loss: 0.7980 - accuracy: 0.7052 - val_loss: 0.9695 - val_accuracy: 0.6454 - 15s/epoch - 7ms/step
# Epoch 7/50
# 2188/2188 - 15s - loss: 0.7562 - accuracy: 0.7224 - val_loss: 0.9453 - val_accuracy: 0.6511 - 15s/epoch - 7ms/step
# Epoch 8/50
# 2188/2188 - 15s - loss: 0.7264 - accuracy: 0.7322 - val_loss: 1.0118 - val_accuracy: 0.6143 - 15s/epoch - 7ms/step
# Epoch 9/50
# 2188/2188 - 15s - loss: 0.6923 - accuracy: 0.7461 - val_loss: 0.9062 - val_accuracy: 0.6682 - 15s/epoch - 7ms/step
# Epoch 10/50
# 2188/2188 - 15s - loss: 0.6748 - accuracy: 0.7546 - val_loss: 0.9568 - val_accuracy: 0.6483 - 15s/epoch - 7ms/step
# Epoch 11/50
# 2188/2188 - 15s - loss: 0.6488 - accuracy: 0.7623 - val_loss: 0.8794 - val_accuracy: 0.6688 - 15s/epoch - 7ms/step
# Epoch 12/50
# 2188/2188 - 15s - loss: 0.6419 - accuracy: 0.7652 - val_loss: 0.9013 - val_accuracy: 0.6578 - 15s/epoch - 7ms/step
# Epoch 13/50
# 2188/2188 - 15s - loss: 0.6253 - accuracy: 0.7716 - val_loss: 0.8551 - val_accuracy: 0.6789 - 15s/epoch - 7ms/step
# Epoch 14/50
# 2188/2188 - 15s - loss: 0.6073 - accuracy: 0.7788 - val_loss: 0.7473 - val_accuracy: 0.7288 - 15s/epoch - 7ms/step
# Epoch 15/50
# 2188/2188 - 15s - loss: 0.5957 - accuracy: 0.7804 - val_loss: 0.7430 - val_accuracy: 0.7248 - 15s/epoch - 7ms/step
# Epoch 16/50
# 2188/2188 - 15s - loss: 0.5792 - accuracy: 0.7880 - val_loss: 0.8951 - val_accuracy: 0.6790 - 15s/epoch - 7ms/step
# Epoch 17/50
# 2188/2188 - 15s - loss: 0.5728 - accuracy: 0.7898 - val_loss: 0.8111 - val_accuracy: 0.7039 - 15s/epoch - 7ms/step
# Epoch 18/50
# 2188/2188 - 15s - loss: 0.5698 - accuracy: 0.7929 - val_loss: 0.8804 - val_accuracy: 0.6835 - 15s/epoch - 7ms/step
# Epoch 19/50
# 2188/2188 - 15s - loss: 0.5587 - accuracy: 0.7957 - val_loss: 0.8704 - val_accuracy: 0.6847 - 15s/epoch - 7ms/step
# Epoch 20/50
# 2188/2188 - 15s - loss: 0.5536 - accuracy: 0.7977 - val_loss: 0.8739 - val_accuracy: 0.6709 - 15s/epoch - 7ms/step
# Epoch 21/50
# 2188/2188 - 15s - loss: 0.5469 - accuracy: 0.8004 - val_loss: 0.7717 - val_accuracy: 0.7087 - 15s/epoch - 7ms/step
# Epoch 22/50
# 2188/2188 - 15s - loss: 0.5375 - accuracy: 0.8013 - val_loss: 0.8460 - val_accuracy: 0.6882 - 15s/epoch - 7ms/step
# Epoch 23/50
# 2188/2188 - 15s - loss: 0.5287 - accuracy: 0.8073 - val_loss: 0.7933 - val_accuracy: 0.7045 - 15s/epoch - 7ms/step
# Epoch 24/50
# 2188/2188 - 15s - loss: 0.5258 - accuracy: 0.8078 - val_loss: 0.8084 - val_accuracy: 0.7024 - 15s/epoch - 7ms/step
# Epoch 25/50
# 2188/2188 - 15s - loss: 0.5181 - accuracy: 0.8117 - val_loss: 0.8137 - val_accuracy: 0.6961 - 15s/epoch - 7ms/step
# Epoch 26/50
# 2188/2188 - 15s - loss: 0.5193 - accuracy: 0.8103 - val_loss: 0.6823 - val_accuracy: 0.7485 - 15s/epoch - 7ms/step
# Epoch 27/50
# 2188/2188 - 15s - loss: 0.5081 - accuracy: 0.8141 - val_loss: 0.7572 - val_accuracy: 0.7130 - 15s/epoch - 7ms/step
# Epoch 28/50
# 2188/2188 - 15s - loss: 0.5069 - accuracy: 0.8161 - val_loss: 0.7979 - val_accuracy: 0.7025 - 15s/epoch - 7ms/step
# Epoch 29/50
# 2188/2188 - 15s - loss: 0.5049 - accuracy: 0.8160 - val_loss: 1.0186 - val_accuracy: 0.6193 - 15s/epoch - 7ms/step
# Epoch 30/50
# 2188/2188 - 15s - loss: 0.4972 - accuracy: 0.8205 - val_loss: 0.7026 - val_accuracy: 0.7398 - 15s/epoch - 7ms/step
# Epoch 31/50
# 2188/2188 - 15s - loss: 0.4884 - accuracy: 0.8224 - val_loss: 0.7357 - val_accuracy: 0.7219 - 15s/epoch - 7ms/step
# Epoch 32/50
# 2188/2188 - 15s - loss: 0.4936 - accuracy: 0.8218 - val_loss: 0.7693 - val_accuracy: 0.7176 - 15s/epoch - 7ms/step
# Epoch 33/50
# 2188/2188 - 15s - loss: 0.4838 - accuracy: 0.8256 - val_loss: 0.9616 - val_accuracy: 0.6536 - 15s/epoch - 7ms/step
# Epoch 34/50
# 2188/2188 - 15s - loss: 0.4787 - accuracy: 0.8265 - val_loss: 0.7496 - val_accuracy: 0.7194 - 15s/epoch - 7ms/step
# Epoch 35/50
# 2188/2188 - 15s - loss: 0.4798 - accuracy: 0.8269 - val_loss: 0.7855 - val_accuracy: 0.7062 - 15s/epoch - 7ms/step
# Epoch 36/50
# 2188/2188 - 15s - loss: 0.4743 - accuracy: 0.8283 - val_loss: 0.8878 - val_accuracy: 0.6766 - 15s/epoch - 7ms/step
# Epoch 37/50
# 2188/2188 - 15s - loss: 0.4724 - accuracy: 0.8278 - val_loss: 0.7901 - val_accuracy: 0.7002 - 15s/epoch - 7ms/step
# Epoch 38/50
# 2188/2188 - 15s - loss: 0.4679 - accuracy: 0.8309 - val_loss: 0.9110 - val_accuracy: 0.6662 - 15s/epoch - 7ms/step
# Epoch 39/50
# 2188/2188 - 15s - loss: 0.4704 - accuracy: 0.8326 - val_loss: 0.8153 - val_accuracy: 0.6873 - 15s/epoch - 7ms/step
# Epoch 40/50
# 2188/2188 - 15s - loss: 0.4615 - accuracy: 0.8331 - val_loss: 0.8517 - val_accuracy: 0.6849 - 15s/epoch - 7ms/step
# Epoch 41/50
# 2188/2188 - 15s - loss: 0.4639 - accuracy: 0.8343 - val_loss: 0.8232 - val_accuracy: 0.6974 - 15s/epoch - 7ms/step
# Epoch 42/50
# 2188/2188 - 15s - loss: 0.4702 - accuracy: 0.8301 - val_loss: 0.9585 - val_accuracy: 0.6527 - 15s/epoch - 7ms/step
# Epoch 43/50
# 2188/2188 - 15s - loss: 0.4632 - accuracy: 0.8346 - val_loss: 1.0128 - val_accuracy: 0.6542 - 15s/epoch - 7ms/step
# Epoch 44/50
# 2188/2188 - 15s - loss: 0.4569 - accuracy: 0.8346 - val_loss: 0.9766 - val_accuracy: 0.6539 - 15s/epoch - 7ms/step
# Epoch 45/50
# 2188/2188 - 15s - loss: 0.4551 - accuracy: 0.8359 - val_loss: 0.7944 - val_accuracy: 0.7081 - 15s/epoch - 7ms/step
# Epoch 46/50
# 2188/2188 - 15s - loss: 0.4572 - accuracy: 0.8367 - val_loss: 0.8962 - val_accuracy: 0.6710 - 15s/epoch - 7ms/step
# Epoch 47/50
# 2188/2188 - 15s - loss: 0.4530 - accuracy: 0.8372 - val_loss: 0.9475 - val_accuracy: 0.6659 - 15s/epoch - 7ms/step
# Epoch 48/50
# 2188/2188 - 15s - loss: 0.4440 - accuracy: 0.8414 - val_loss: 0.9239 - val_accuracy: 0.6702 - 15s/epoch - 7ms/step
# Epoch 49/50
# 2188/2188 - 15s - loss: 0.4503 - accuracy: 0.8377 - val_loss: 1.1724 - val_accuracy: 0.5957 - 15s/epoch - 7ms/step
# Epoch 50/50
# 2188/2188 - 15s - loss: 0.4461 - accuracy: 0.8407 - val_loss: 0.8255 - val_accuracy: 0.6952 - 15s/epoch - 7ms/step
# 274/274 [==============================] - 1s 2ms/step - loss: 0.8101 - accuracy: 0.7019
# 274/274 [==============================] - 1s 2ms/step
#
#
# y_test :  [0 0 0 ... 9 9 9]
#
#
# y_prediction :  [4 0 0 ... 9 9 9]
# 128/128 [==============================] - 0s 2ms/step - loss: 1.5645 - accuracy: 0.5701
# 128/128 [==============================] - 0s 2ms/step
# 274/274 [==============================] - 0s 2ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 126, 13, 32)       320
#
#  conv2d_6 (Conv2D)           (None, 126, 13, 32)       9248
#
#  max_pooling2d_2 (MaxPooling  (None, 63, 6, 32)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 63, 6, 32)         0
#
#  conv2d_7 (Conv2D)           (None, 63, 6, 64)         18496
#
#  conv2d_8 (Conv2D)           (None, 63, 6, 64)         36928
#
#  max_pooling2d_3 (MaxPooling  (None, 31, 3, 64)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 31, 3, 64)         0
#
#  conv2d_9 (Conv2D)           (None, 31, 3, 128)        73856
#
#  dropout_6 (Dropout)         (None, 31, 3, 128)        0
#
#  flatten_1 (Flatten)         (None, 11904)             0
#
#  dense_2 (Dense)             (None, 512)               6095360
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,239,338
# Trainable params: 6,239,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-14 02:28:09.880685: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2188/2188 - 16s - loss: 1.5856 - accuracy: 0.4130 - val_loss: 1.5322 - val_accuracy: 0.4475 - 16s/epoch - 7ms/step
# Epoch 2/50
# 2188/2188 - 15s - loss: 1.2067 - accuracy: 0.5536 - val_loss: 1.2587 - val_accuracy: 0.5471 - 15s/epoch - 7ms/step
# Epoch 3/50
# 2188/2188 - 15s - loss: 1.0706 - accuracy: 0.6001 - val_loss: 1.1820 - val_accuracy: 0.5691 - 15s/epoch - 7ms/step
# Epoch 4/50
# 2188/2188 - 15s - loss: 0.9770 - accuracy: 0.6317 - val_loss: 1.1217 - val_accuracy: 0.5675 - 15s/epoch - 7ms/step
# Epoch 5/50
# 2188/2188 - 15s - loss: 0.9187 - accuracy: 0.6556 - val_loss: 1.2673 - val_accuracy: 0.5249 - 15s/epoch - 7ms/step
# Epoch 6/50
# 2188/2188 - 15s - loss: 0.8619 - accuracy: 0.6777 - val_loss: 1.2614 - val_accuracy: 0.5087 - 15s/epoch - 7ms/step
# Epoch 7/50
# 2188/2188 - 15s - loss: 0.8216 - accuracy: 0.6930 - val_loss: 1.1127 - val_accuracy: 0.5622 - 15s/epoch - 7ms/step
# Epoch 8/50
# 2188/2188 - 15s - loss: 0.7777 - accuracy: 0.7099 - val_loss: 1.0889 - val_accuracy: 0.5881 - 15s/epoch - 7ms/step
# Epoch 9/50
# 2188/2188 - 15s - loss: 0.7480 - accuracy: 0.7217 - val_loss: 1.0440 - val_accuracy: 0.6122 - 15s/epoch - 7ms/step
# Epoch 10/50
# 2188/2188 - 15s - loss: 0.7178 - accuracy: 0.7319 - val_loss: 1.0685 - val_accuracy: 0.5983 - 15s/epoch - 7ms/step
# Epoch 11/50
# 2188/2188 - 15s - loss: 0.6934 - accuracy: 0.7427 - val_loss: 0.9016 - val_accuracy: 0.6634 - 15s/epoch - 7ms/step
# Epoch 12/50
# 2188/2188 - 15s - loss: 0.6731 - accuracy: 0.7512 - val_loss: 0.8676 - val_accuracy: 0.6631 - 15s/epoch - 7ms/step
# Epoch 13/50
# 2188/2188 - 15s - loss: 0.6594 - accuracy: 0.7559 - val_loss: 0.8113 - val_accuracy: 0.6909 - 15s/epoch - 7ms/step
# Epoch 14/50
# 2188/2188 - 15s - loss: 0.6450 - accuracy: 0.7611 - val_loss: 0.9735 - val_accuracy: 0.6304 - 15s/epoch - 7ms/step
# Epoch 15/50
# 2188/2188 - 15s - loss: 0.6267 - accuracy: 0.7685 - val_loss: 0.7189 - val_accuracy: 0.7329 - 15s/epoch - 7ms/step
# Epoch 16/50
# 2188/2188 - 15s - loss: 0.6107 - accuracy: 0.7721 - val_loss: 0.8392 - val_accuracy: 0.6737 - 15s/epoch - 7ms/step
# Epoch 17/50
# 2188/2188 - 15s - loss: 0.6090 - accuracy: 0.7762 - val_loss: 1.0075 - val_accuracy: 0.6113 - 15s/epoch - 7ms/step
# Epoch 18/50
# 2188/2188 - 15s - loss: 0.5984 - accuracy: 0.7793 - val_loss: 0.8382 - val_accuracy: 0.6815 - 15s/epoch - 7ms/step
# Epoch 19/50
# 2188/2188 - 15s - loss: 0.5869 - accuracy: 0.7838 - val_loss: 1.0900 - val_accuracy: 0.5978 - 15s/epoch - 7ms/step
# Epoch 20/50
# 2188/2188 - 15s - loss: 0.5755 - accuracy: 0.7905 - val_loss: 0.8983 - val_accuracy: 0.6655 - 15s/epoch - 7ms/step
# Epoch 21/50
# 2188/2188 - 15s - loss: 0.5673 - accuracy: 0.7917 - val_loss: 0.7458 - val_accuracy: 0.7178 - 15s/epoch - 7ms/step
# Epoch 22/50
# 2188/2188 - 15s - loss: 0.5590 - accuracy: 0.7936 - val_loss: 0.7512 - val_accuracy: 0.7167 - 15s/epoch - 7ms/step
# Epoch 23/50
# 2188/2188 - 15s - loss: 0.5532 - accuracy: 0.7985 - val_loss: 0.7473 - val_accuracy: 0.7205 - 15s/epoch - 7ms/step
# Epoch 24/50
# 2188/2188 - 15s - loss: 0.5460 - accuracy: 0.7989 - val_loss: 0.7788 - val_accuracy: 0.7047 - 15s/epoch - 7ms/step
# Epoch 25/50
# 2188/2188 - 15s - loss: 0.5410 - accuracy: 0.8019 - val_loss: 0.7129 - val_accuracy: 0.7341 - 15s/epoch - 7ms/step
# Epoch 26/50
# 2188/2188 - 15s - loss: 0.5329 - accuracy: 0.8058 - val_loss: 0.7603 - val_accuracy: 0.7154 - 15s/epoch - 7ms/step
# Epoch 27/50
# 2188/2188 - 15s - loss: 0.5246 - accuracy: 0.8083 - val_loss: 0.6936 - val_accuracy: 0.7338 - 15s/epoch - 7ms/step
# Epoch 28/50
# 2188/2188 - 15s - loss: 0.5206 - accuracy: 0.8099 - val_loss: 0.7211 - val_accuracy: 0.7369 - 15s/epoch - 7ms/step
# Epoch 29/50
# 2188/2188 - 15s - loss: 0.5204 - accuracy: 0.8107 - val_loss: 0.8142 - val_accuracy: 0.6994 - 15s/epoch - 7ms/step
# Epoch 30/50
# 2188/2188 - 15s - loss: 0.5127 - accuracy: 0.8141 - val_loss: 0.6702 - val_accuracy: 0.7475 - 15s/epoch - 7ms/step
# Epoch 31/50
# 2188/2188 - 15s - loss: 0.5092 - accuracy: 0.8128 - val_loss: 0.6995 - val_accuracy: 0.7387 - 15s/epoch - 7ms/step
# Epoch 32/50
# 2188/2188 - 15s - loss: 0.4993 - accuracy: 0.8187 - val_loss: 0.9671 - val_accuracy: 0.6634 - 15s/epoch - 7ms/step
# Epoch 33/50
# 2188/2188 - 15s - loss: 0.4947 - accuracy: 0.8197 - val_loss: 0.7027 - val_accuracy: 0.7403 - 15s/epoch - 7ms/step
# Epoch 34/50
# 2188/2188 - 15s - loss: 0.4932 - accuracy: 0.8207 - val_loss: 0.7336 - val_accuracy: 0.7274 - 15s/epoch - 7ms/step
# Epoch 35/50
# 2188/2188 - 15s - loss: 0.4872 - accuracy: 0.8242 - val_loss: 0.7580 - val_accuracy: 0.7187 - 15s/epoch - 7ms/step
# Epoch 36/50
# 2188/2188 - 15s - loss: 0.4840 - accuracy: 0.8228 - val_loss: 0.6156 - val_accuracy: 0.7814 - 15s/epoch - 7ms/step
# Epoch 37/50
# 2188/2188 - 15s - loss: 0.4815 - accuracy: 0.8251 - val_loss: 0.9361 - val_accuracy: 0.6877 - 15s/epoch - 7ms/step
# Epoch 38/50
# 2188/2188 - 15s - loss: 0.4780 - accuracy: 0.8271 - val_loss: 0.7157 - val_accuracy: 0.7375 - 15s/epoch - 7ms/step
# Epoch 39/50
# 2188/2188 - 15s - loss: 0.4739 - accuracy: 0.8282 - val_loss: 0.7182 - val_accuracy: 0.7343 - 15s/epoch - 7ms/step
# Epoch 40/50
# 2188/2188 - 15s - loss: 0.4700 - accuracy: 0.8303 - val_loss: 0.7616 - val_accuracy: 0.7218 - 15s/epoch - 7ms/step
# Epoch 41/50
# 2188/2188 - 15s - loss: 0.4684 - accuracy: 0.8311 - val_loss: 0.6336 - val_accuracy: 0.7707 - 15s/epoch - 7ms/step
# Epoch 42/50
# 2188/2188 - 15s - loss: 0.4640 - accuracy: 0.8314 - val_loss: 0.6532 - val_accuracy: 0.7622 - 15s/epoch - 7ms/step
# Epoch 43/50
# 2188/2188 - 15s - loss: 0.4652 - accuracy: 0.8329 - val_loss: 0.5800 - val_accuracy: 0.7967 - 15s/epoch - 7ms/step
# Epoch 44/50
# 2188/2188 - 15s - loss: 0.4634 - accuracy: 0.8340 - val_loss: 0.6882 - val_accuracy: 0.7509 - 15s/epoch - 7ms/step
# Epoch 45/50
# 2188/2188 - 15s - loss: 0.4528 - accuracy: 0.8362 - val_loss: 0.6075 - val_accuracy: 0.7749 - 15s/epoch - 7ms/step
# Epoch 46/50
# 2188/2188 - 15s - loss: 0.4531 - accuracy: 0.8370 - val_loss: 0.7299 - val_accuracy: 0.7288 - 15s/epoch - 7ms/step
# Epoch 47/50
# 2188/2188 - 15s - loss: 0.4511 - accuracy: 0.8387 - val_loss: 0.4928 - val_accuracy: 0.8242 - 15s/epoch - 7ms/step
# Epoch 48/50
# 2188/2188 - 15s - loss: 0.4442 - accuracy: 0.8398 - val_loss: 0.5543 - val_accuracy: 0.8001 - 15s/epoch - 7ms/step
# Epoch 49/50
# 2188/2188 - 15s - loss: 0.4374 - accuracy: 0.8432 - val_loss: 0.7792 - val_accuracy: 0.7154 - 15s/epoch - 7ms/step
# Epoch 50/50
# 2188/2188 - 15s - loss: 0.4517 - accuracy: 0.8396 - val_loss: 0.6803 - val_accuracy: 0.7550 - 15s/epoch - 7ms/step
# 274/274 [==============================] - 1s 2ms/step - loss: 0.7003 - accuracy: 0.7488
# 274/274 [==============================] - 1s 2ms/step
#
#
# y_test :  [0 0 0 ... 9 9 9]
#
#
# y_prediction :  [0 0 0 ... 9 9 9]
# 128/128 [==============================] - 0s 2ms/step - loss: 1.7437 - accuracy: 0.5593
# 128/128 [==============================] - 0s 2ms/step
# 274/274 [==============================] - 0s 2ms/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 126, 13, 32)       320
#
#  conv2d_11 (Conv2D)          (None, 126, 13, 32)       9248
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 6, 32)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 63, 6, 32)         0
#
#  conv2d_12 (Conv2D)          (None, 63, 6, 64)         18496
#
#  conv2d_13 (Conv2D)          (None, 63, 6, 64)         36928
#
#  max_pooling2d_5 (MaxPooling  (None, 31, 3, 64)        0
#  2D)
#
#  dropout_9 (Dropout)         (None, 31, 3, 64)         0
#
#  conv2d_14 (Conv2D)          (None, 31, 3, 128)        73856
#
#  dropout_10 (Dropout)        (None, 31, 3, 128)        0
#
#  flatten_2 (Flatten)         (None, 11904)             0
#
#  dense_4 (Dense)             (None, 512)               6095360
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,239,338
# Trainable params: 6,239,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-14 02:41:09.247260: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2188/2188 - 17s - loss: 1.7112 - accuracy: 0.3638 - val_loss: 1.6178 - val_accuracy: 0.4336 - 17s/epoch - 8ms/step
# Epoch 2/50
# 2188/2188 - 15s - loss: 1.3761 - accuracy: 0.4885 - val_loss: 1.5989 - val_accuracy: 0.4530 - 15s/epoch - 7ms/step
# Epoch 3/50
# 2188/2188 - 15s - loss: 1.2088 - accuracy: 0.5488 - val_loss: 1.4733 - val_accuracy: 0.4641 - 15s/epoch - 7ms/step
# Epoch 4/50
# 2188/2188 - 15s - loss: 1.0957 - accuracy: 0.5900 - val_loss: 1.4035 - val_accuracy: 0.5085 - 15s/epoch - 7ms/step
# Epoch 5/50
# 2188/2188 - 15s - loss: 1.0149 - accuracy: 0.6181 - val_loss: 1.3039 - val_accuracy: 0.5317 - 15s/epoch - 7ms/step
# Epoch 6/50
# 2188/2188 - 15s - loss: 0.9565 - accuracy: 0.6418 - val_loss: 1.2282 - val_accuracy: 0.5607 - 15s/epoch - 7ms/step
# Epoch 7/50
# 2188/2188 - 15s - loss: 0.9095 - accuracy: 0.6613 - val_loss: 1.3979 - val_accuracy: 0.4926 - 15s/epoch - 7ms/step
# Epoch 8/50
# 2188/2188 - 15s - loss: 0.8764 - accuracy: 0.6716 - val_loss: 1.3459 - val_accuracy: 0.5043 - 15s/epoch - 7ms/step
# Epoch 9/50
# 2188/2188 - 15s - loss: 0.8449 - accuracy: 0.6805 - val_loss: 1.2315 - val_accuracy: 0.5639 - 15s/epoch - 7ms/step
# Epoch 10/50
# 2188/2188 - 15s - loss: 0.8158 - accuracy: 0.6943 - val_loss: 1.0618 - val_accuracy: 0.6073 - 15s/epoch - 7ms/step
# Epoch 11/50
# 2188/2188 - 15s - loss: 0.8012 - accuracy: 0.7001 - val_loss: 1.4342 - val_accuracy: 0.4982 - 15s/epoch - 7ms/step
# Epoch 12/50
# 2188/2188 - 15s - loss: 0.7852 - accuracy: 0.7056 - val_loss: 1.2164 - val_accuracy: 0.5535 - 15s/epoch - 7ms/step
# Epoch 13/50
# 2188/2188 - 15s - loss: 0.7683 - accuracy: 0.7123 - val_loss: 1.3140 - val_accuracy: 0.5416 - 15s/epoch - 7ms/step
# Epoch 14/50
# 2188/2188 - 15s - loss: 0.7493 - accuracy: 0.7209 - val_loss: 1.1459 - val_accuracy: 0.5739 - 15s/epoch - 7ms/step
# Epoch 15/50
# 2188/2188 - 15s - loss: 0.7338 - accuracy: 0.7264 - val_loss: 1.2228 - val_accuracy: 0.5553 - 15s/epoch - 7ms/step
# Epoch 16/50
# 2188/2188 - 15s - loss: 0.7284 - accuracy: 0.7281 - val_loss: 1.3740 - val_accuracy: 0.5030 - 15s/epoch - 7ms/step
# Epoch 17/50
# 2188/2188 - 15s - loss: 0.7146 - accuracy: 0.7333 - val_loss: 1.3084 - val_accuracy: 0.5304 - 15s/epoch - 7ms/step
# Epoch 18/50
# 2188/2188 - 15s - loss: 0.7016 - accuracy: 0.7369 - val_loss: 1.4915 - val_accuracy: 0.4966 - 15s/epoch - 7ms/step
# Epoch 19/50
# 2188/2188 - 15s - loss: 0.6963 - accuracy: 0.7398 - val_loss: 1.2270 - val_accuracy: 0.5771 - 15s/epoch - 7ms/step
# Epoch 20/50
# 2188/2188 - 15s - loss: 0.6860 - accuracy: 0.7435 - val_loss: 1.2525 - val_accuracy: 0.5744 - 15s/epoch - 7ms/step
# Epoch 21/50
# 2188/2188 - 15s - loss: 0.6791 - accuracy: 0.7496 - val_loss: 1.6863 - val_accuracy: 0.4859 - 15s/epoch - 7ms/step
# Epoch 22/50
# 2188/2188 - 15s - loss: 0.6673 - accuracy: 0.7517 - val_loss: 1.3686 - val_accuracy: 0.5393 - 15s/epoch - 7ms/step
# Epoch 23/50
# 2188/2188 - 15s - loss: 0.6553 - accuracy: 0.7564 - val_loss: 1.4997 - val_accuracy: 0.5189 - 15s/epoch - 7ms/step
# Epoch 24/50
# 2188/2188 - 15s - loss: 0.6533 - accuracy: 0.7563 - val_loss: 1.4639 - val_accuracy: 0.5293 - 15s/epoch - 7ms/step
# Epoch 25/50
# 2188/2188 - 15s - loss: 0.6446 - accuracy: 0.7614 - val_loss: 1.7395 - val_accuracy: 0.5137 - 15s/epoch - 7ms/step
# Epoch 26/50
# 2188/2188 - 15s - loss: 0.6405 - accuracy: 0.7627 - val_loss: 1.8251 - val_accuracy: 0.4712 - 15s/epoch - 7ms/step
# Epoch 27/50
# 2188/2188 - 15s - loss: 0.6264 - accuracy: 0.7665 - val_loss: 1.2078 - val_accuracy: 0.5775 - 15s/epoch - 7ms/step
# Epoch 28/50
# 2188/2188 - 15s - loss: 0.6304 - accuracy: 0.7687 - val_loss: 1.1091 - val_accuracy: 0.5842 - 15s/epoch - 7ms/step
# Epoch 29/50
# 2188/2188 - 15s - loss: 0.6207 - accuracy: 0.7689 - val_loss: 1.3087 - val_accuracy: 0.5223 - 15s/epoch - 7ms/step
# Epoch 30/50
# 2188/2188 - 15s - loss: 0.6156 - accuracy: 0.7735 - val_loss: 1.1137 - val_accuracy: 0.6203 - 15s/epoch - 7ms/step
# Epoch 31/50
# 2188/2188 - 15s - loss: 0.6099 - accuracy: 0.7738 - val_loss: 1.0478 - val_accuracy: 0.6127 - 15s/epoch - 7ms/step
# Epoch 32/50
# 2188/2188 - 15s - loss: 0.5996 - accuracy: 0.7786 - val_loss: 1.4919 - val_accuracy: 0.5467 - 15s/epoch - 7ms/step
# Epoch 33/50
# 2188/2188 - 15s - loss: 0.6008 - accuracy: 0.7776 - val_loss: 1.1875 - val_accuracy: 0.5760 - 15s/epoch - 7ms/step
# Epoch 34/50
# 2188/2188 - 15s - loss: 0.5965 - accuracy: 0.7793 - val_loss: 1.8118 - val_accuracy: 0.5133 - 15s/epoch - 7ms/step
# Epoch 35/50
# 2188/2188 - 15s - loss: 0.5902 - accuracy: 0.7826 - val_loss: 1.1578 - val_accuracy: 0.5762 - 15s/epoch - 7ms/step
# Epoch 36/50
# 2188/2188 - 15s - loss: 0.5895 - accuracy: 0.7824 - val_loss: 1.4357 - val_accuracy: 0.5106 - 15s/epoch - 7ms/step
# Epoch 37/50
# 2188/2188 - 15s - loss: 0.5850 - accuracy: 0.7827 - val_loss: 1.8140 - val_accuracy: 0.4502 - 15s/epoch - 7ms/step
# Epoch 38/50
# 2188/2188 - 15s - loss: 0.5790 - accuracy: 0.7856 - val_loss: 1.3049 - val_accuracy: 0.5819 - 15s/epoch - 7ms/step
# Epoch 39/50
# 2188/2188 - 15s - loss: 0.5727 - accuracy: 0.7891 - val_loss: 2.0041 - val_accuracy: 0.4946 - 15s/epoch - 7ms/step
# Epoch 40/50
# 2188/2188 - 15s - loss: 0.5713 - accuracy: 0.7881 - val_loss: 1.0096 - val_accuracy: 0.6224 - 15s/epoch - 7ms/step
# Epoch 41/50
# 2188/2188 - 15s - loss: 0.5720 - accuracy: 0.7897 - val_loss: 1.3134 - val_accuracy: 0.5649 - 15s/epoch - 7ms/step
# Epoch 42/50
# 2188/2188 - 15s - loss: 0.5684 - accuracy: 0.7931 - val_loss: 1.8893 - val_accuracy: 0.5047 - 15s/epoch - 7ms/step
# Epoch 43/50
# 2188/2188 - 15s - loss: 0.5625 - accuracy: 0.7927 - val_loss: 1.5019 - val_accuracy: 0.5421 - 15s/epoch - 7ms/step
# Epoch 44/50
# 2188/2188 - 15s - loss: 0.5542 - accuracy: 0.7972 - val_loss: 1.6334 - val_accuracy: 0.5270 - 15s/epoch - 7ms/step
# Epoch 45/50
# 2188/2188 - 15s - loss: 0.5572 - accuracy: 0.7949 - val_loss: 1.4093 - val_accuracy: 0.5601 - 15s/epoch - 7ms/step
# Epoch 46/50
# 2188/2188 - 15s - loss: 0.5600 - accuracy: 0.7934 - val_loss: 1.6697 - val_accuracy: 0.5248 - 15s/epoch - 7ms/step
# Epoch 47/50
# 2188/2188 - 15s - loss: 0.5537 - accuracy: 0.7973 - val_loss: 1.7114 - val_accuracy: 0.5121 - 15s/epoch - 7ms/step
# Epoch 48/50
# 2188/2188 - 15s - loss: 0.5486 - accuracy: 0.7995 - val_loss: 1.3372 - val_accuracy: 0.5486 - 15s/epoch - 7ms/step
# Epoch 49/50
# 2188/2188 - 15s - loss: 0.5390 - accuracy: 0.8023 - val_loss: 1.7334 - val_accuracy: 0.5049 - 15s/epoch - 7ms/step
# Epoch 50/50
# 2188/2188 - 15s - loss: 0.5426 - accuracy: 0.8006 - val_loss: 1.5722 - val_accuracy: 0.5280 - 15s/epoch - 7ms/step
# 274/274 [==============================] - 1s 2ms/step - loss: 1.5794 - accuracy: 0.5222
# 274/274 [==============================] - 1s 2ms/step
#
#
# y_test :  [0 0 0 ... 9 9 9]
#
#
# y_prediction :  [0 3 4 ... 9 9 9]
# 128/128 [==============================] - 0s 2ms/step - loss: 2.5259 - accuracy: 0.4702
# 128/128 [==============================] - 0s 2ms/step
# 274/274 [==============================] - 0s 2ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 126, 13, 32)       320
#
#  conv2d_16 (Conv2D)          (None, 126, 13, 32)       9248
#
#  max_pooling2d_6 (MaxPooling  (None, 63, 6, 32)        0
#  2D)
#
#  dropout_12 (Dropout)        (None, 63, 6, 32)         0
#
#  conv2d_17 (Conv2D)          (None, 63, 6, 64)         18496
#
#  conv2d_18 (Conv2D)          (None, 63, 6, 64)         36928
#
#  max_pooling2d_7 (MaxPooling  (None, 31, 3, 64)        0
#  2D)
#
#  dropout_13 (Dropout)        (None, 31, 3, 64)         0
#
#  conv2d_19 (Conv2D)          (None, 31, 3, 128)        73856
#
#  dropout_14 (Dropout)        (None, 31, 3, 128)        0
#
#  flatten_3 (Flatten)         (None, 11904)             0
#
#  dense_6 (Dense)             (None, 512)               6095360
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,239,338
# Trainable params: 6,239,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-14 02:54:13.653992: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_3/dropout_12/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2188/2188 - 16s - loss: 2.3031 - accuracy: 0.0959 - val_loss: 2.3026 - val_accuracy: 0.1000 - 16s/epoch - 8ms/step
# Epoch 2/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 3/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 4/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 5/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 6/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 7/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0977 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 8/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 9/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 10/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0975 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 11/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0991 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 12/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 13/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 14/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0986 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 15/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 16/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 17/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 18/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 19/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 20/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 21/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.0992 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 22/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 23/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 24/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 25/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 26/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0980 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 27/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.1011 - val_loss: 2.3028 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 28/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 29/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0966 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 30/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 31/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 32/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0967 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 33/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0977 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 34/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 35/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0996 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 36/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0984 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 37/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0976 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 38/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0979 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 39/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 40/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 41/50
# 2188/2188 - 15s - loss: 2.3027 - accuracy: 0.0980 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 42/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 43/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0992 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 44/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0982 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 45/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0976 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 46/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 47/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 48/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0977 - val_loss: 2.3027 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 49/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.0983 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# Epoch 50/50
# 2188/2188 - 15s - loss: 2.3028 - accuracy: 0.1002 - val_loss: 2.3026 - val_accuracy: 0.1000 - 15s/epoch - 7ms/step
# 274/274 [==============================] - 1s 2ms/step - loss: 2.3026 - accuracy: 0.1000
# 274/274 [==============================] - 1s 2ms/step
#
#
# y_test :  [0 0 0 ... 9 9 9]
#
#
# y_prediction :  [0 0 0 ... 0 0 0]
#  47/128 [==========>...................] - ETA: 0s - loss: 2.3015 - accuracy: 0.2081
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 128/128 [==============================] - 0s 2ms/step - loss: 2.3018 - accuracy: 0.2058
# 128/128 [==============================] - 0s 2ms/step
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/stenmarken/miniconda3/envs/tensorflow/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 274/274 [==============================] - 0s 2ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 126, 13, 32)       320
#
#  conv2d_21 (Conv2D)          (None, 126, 13, 32)       9248
#
#  max_pooling2d_8 (MaxPooling  (None, 63, 6, 32)        0
#  2D)
#
#  dropout_16 (Dropout)        (None, 63, 6, 32)         0
#
#  conv2d_22 (Conv2D)          (None, 63, 6, 64)         18496
#
#  conv2d_23 (Conv2D)          (None, 63, 6, 64)         36928
#
#  max_pooling2d_9 (MaxPooling  (None, 31, 3, 64)        0
#  2D)
#
#  dropout_17 (Dropout)        (None, 31, 3, 64)         0
#
#  conv2d_24 (Conv2D)          (None, 31, 3, 128)        73856
#
#  dropout_18 (Dropout)        (None, 31, 3, 128)        0
#
#  flatten_4 (Flatten)         (None, 11904)             0
#
#  dense_8 (Dense)             (None, 512)               6095360
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,239,338
# Trainable params: 6,239,338
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-14 03:07:14.400691: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_4/dropout_16/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2188/2188 - 17s - loss: 1.6701 - accuracy: 0.3828 - val_loss: 1.4181 - val_accuracy: 0.4618 - 17s/epoch - 8ms/step
# Epoch 2/50
# 2188/2188 - 15s - loss: 1.2677 - accuracy: 0.5299 - val_loss: 1.3481 - val_accuracy: 0.5088 - 15s/epoch - 7ms/step
# Epoch 3/50
# 2188/2188 - 15s - loss: 1.1104 - accuracy: 0.5883 - val_loss: 1.3749 - val_accuracy: 0.4970 - 15s/epoch - 7ms/step
# Epoch 4/50
# 2188/2188 - 15s - loss: 1.0239 - accuracy: 0.6168 - val_loss: 1.3055 - val_accuracy: 0.5315 - 15s/epoch - 7ms/step
# Epoch 5/50
# 2188/2188 - 15s - loss: 0.9577 - accuracy: 0.6406 - val_loss: 1.4528 - val_accuracy: 0.4955 - 15s/epoch - 7ms/step
# Epoch 6/50
# 2188/2188 - 15s - loss: 0.9015 - accuracy: 0.6609 - val_loss: 1.6208 - val_accuracy: 0.4514 - 15s/epoch - 7ms/step
# Epoch 7/50
# 2188/2188 - 15s - loss: 0.8667 - accuracy: 0.6756 - val_loss: 1.3373 - val_accuracy: 0.5442 - 15s/epoch - 7ms/step
# Epoch 8/50
# 2188/2188 - 15s - loss: 0.8350 - accuracy: 0.6856 - val_loss: 1.8469 - val_accuracy: 0.4432 - 15s/epoch - 7ms/step
# Epoch 9/50
# 2188/2188 - 15s - loss: 0.8026 - accuracy: 0.6985 - val_loss: 1.3246 - val_accuracy: 0.5331 - 15s/epoch - 7ms/step
# Epoch 10/50
# 2188/2188 - 15s - loss: 0.7844 - accuracy: 0.7062 - val_loss: 1.6362 - val_accuracy: 0.4523 - 15s/epoch - 7ms/step
# Epoch 11/50
# 2188/2188 - 15s - loss: 0.7647 - accuracy: 0.7124 - val_loss: 1.2991 - val_accuracy: 0.5659 - 15s/epoch - 7ms/step
# Epoch 12/50
# 2188/2188 - 15s - loss: 0.7471 - accuracy: 0.7203 - val_loss: 1.3640 - val_accuracy: 0.5525 - 15s/epoch - 7ms/step
# Epoch 13/50
# 2188/2188 - 15s - loss: 0.7278 - accuracy: 0.7298 - val_loss: 1.2336 - val_accuracy: 0.5857 - 15s/epoch - 7ms/step
# Epoch 14/50
# 2188/2188 - 15s - loss: 0.7142 - accuracy: 0.7325 - val_loss: 1.4778 - val_accuracy: 0.5411 - 15s/epoch - 7ms/step
# Epoch 15/50
# 2188/2188 - 15s - loss: 0.6975 - accuracy: 0.7394 - val_loss: 1.2193 - val_accuracy: 0.5904 - 15s/epoch - 7ms/step
# Epoch 16/50
# 2188/2188 - 15s - loss: 0.6870 - accuracy: 0.7445 - val_loss: 1.2535 - val_accuracy: 0.5896 - 15s/epoch - 7ms/step
# Epoch 17/50
# 2188/2188 - 15s - loss: 0.6749 - accuracy: 0.7462 - val_loss: 1.4304 - val_accuracy: 0.5448 - 15s/epoch - 7ms/step
# Epoch 18/50
# 2188/2188 - 15s - loss: 0.6711 - accuracy: 0.7508 - val_loss: 1.6762 - val_accuracy: 0.4678 - 15s/epoch - 7ms/step
# Epoch 19/50
# 2188/2188 - 15s - loss: 0.6608 - accuracy: 0.7527 - val_loss: 1.3263 - val_accuracy: 0.5560 - 15s/epoch - 7ms/step
# Epoch 20/50
# 2188/2188 - 15s - loss: 0.6472 - accuracy: 0.7590 - val_loss: 1.3367 - val_accuracy: 0.5751 - 15s/epoch - 7ms/step
# Epoch 21/50
# 2188/2188 - 15s - loss: 0.6415 - accuracy: 0.7616 - val_loss: 1.2815 - val_accuracy: 0.5659 - 15s/epoch - 7ms/step
# Epoch 22/50
# 2188/2188 - 15s - loss: 0.6365 - accuracy: 0.7624 - val_loss: 1.1592 - val_accuracy: 0.6058 - 15s/epoch - 7ms/step
# Epoch 23/50
# 2188/2188 - 15s - loss: 0.6217 - accuracy: 0.7667 - val_loss: 1.2204 - val_accuracy: 0.5893 - 15s/epoch - 7ms/step
# Epoch 24/50
# 2188/2188 - 15s - loss: 0.6225 - accuracy: 0.7695 - val_loss: 1.2251 - val_accuracy: 0.5843 - 15s/epoch - 7ms/step
# Epoch 25/50
# 2188/2188 - 15s - loss: 0.6127 - accuracy: 0.7706 - val_loss: 1.3425 - val_accuracy: 0.5726 - 15s/epoch - 7ms/step
# Epoch 26/50
# 2188/2188 - 15s - loss: 0.6106 - accuracy: 0.7717 - val_loss: 1.6974 - val_accuracy: 0.5027 - 15s/epoch - 7ms/step
# Epoch 27/50
# 2188/2188 - 15s - loss: 0.6025 - accuracy: 0.7768 - val_loss: 1.2041 - val_accuracy: 0.6009 - 15s/epoch - 7ms/step
# Epoch 28/50
# 2188/2188 - 15s - loss: 0.5980 - accuracy: 0.7789 - val_loss: 0.9707 - val_accuracy: 0.6599 - 15s/epoch - 7ms/step
# Epoch 29/50
# 2188/2188 - 15s - loss: 0.5921 - accuracy: 0.7813 - val_loss: 1.3576 - val_accuracy: 0.5736 - 15s/epoch - 7ms/step
# Epoch 30/50
# 2188/2188 - 15s - loss: 0.5864 - accuracy: 0.7803 - val_loss: 1.2305 - val_accuracy: 0.6089 - 15s/epoch - 7ms/step
# Epoch 31/50
# 2188/2188 - 15s - loss: 0.5869 - accuracy: 0.7819 - val_loss: 1.1474 - val_accuracy: 0.6426 - 15s/epoch - 7ms/step
# Epoch 32/50
# 2188/2188 - 15s - loss: 0.5811 - accuracy: 0.7850 - val_loss: 1.0755 - val_accuracy: 0.6325 - 15s/epoch - 7ms/step
# Epoch 33/50
# 2188/2188 - 15s - loss: 0.5754 - accuracy: 0.7874 - val_loss: 1.0976 - val_accuracy: 0.6378 - 15s/epoch - 7ms/step
# Epoch 34/50
# 2188/2188 - 15s - loss: 0.5663 - accuracy: 0.7911 - val_loss: 1.2883 - val_accuracy: 0.5816 - 15s/epoch - 7ms/step
# Epoch 35/50
# 2188/2188 - 15s - loss: 0.5666 - accuracy: 0.7921 - val_loss: 1.0441 - val_accuracy: 0.6359 - 15s/epoch - 7ms/step
# Epoch 36/50
# 2188/2188 - 15s - loss: 0.5617 - accuracy: 0.7912 - val_loss: 1.4334 - val_accuracy: 0.5397 - 15s/epoch - 7ms/step
# Epoch 37/50
# 2188/2188 - 15s - loss: 0.5632 - accuracy: 0.7926 - val_loss: 1.3377 - val_accuracy: 0.5762 - 15s/epoch - 7ms/step
# Epoch 38/50
# 2188/2188 - 15s - loss: 0.5593 - accuracy: 0.7939 - val_loss: 1.0713 - val_accuracy: 0.6314 - 15s/epoch - 7ms/step
# Epoch 39/50
# 2188/2188 - 15s - loss: 0.5481 - accuracy: 0.7978 - val_loss: 1.1814 - val_accuracy: 0.6007 - 15s/epoch - 7ms/step
# Epoch 40/50
# 2188/2188 - 15s - loss: 0.5541 - accuracy: 0.7957 - val_loss: 1.5025 - val_accuracy: 0.5345 - 15s/epoch - 7ms/step
# Epoch 41/50
# 2188/2188 - 15s - loss: 0.5462 - accuracy: 0.7995 - val_loss: 1.0690 - val_accuracy: 0.6384 - 15s/epoch - 7ms/step
# Epoch 42/50
# 2188/2188 - 15s - loss: 0.5422 - accuracy: 0.7978 - val_loss: 1.2332 - val_accuracy: 0.6000 - 15s/epoch - 7ms/step
# Epoch 43/50
# 2188/2188 - 15s - loss: 0.5409 - accuracy: 0.8006 - val_loss: 1.2179 - val_accuracy: 0.6178 - 15s/epoch - 7ms/step
# Epoch 44/50
# 2188/2188 - 15s - loss: 0.5353 - accuracy: 0.8043 - val_loss: 1.2540 - val_accuracy: 0.5790 - 15s/epoch - 7ms/step
# Epoch 45/50
# 2188/2188 - 15s - loss: 0.5417 - accuracy: 0.8009 - val_loss: 1.0052 - val_accuracy: 0.6659 - 15s/epoch - 7ms/step
# Epoch 46/50
# 2188/2188 - 15s - loss: 0.5279 - accuracy: 0.8051 - val_loss: 1.0032 - val_accuracy: 0.6440 - 15s/epoch - 7ms/step
# Epoch 47/50
# 2188/2188 - 15s - loss: 0.5226 - accuracy: 0.8085 - val_loss: 1.2111 - val_accuracy: 0.5978 - 15s/epoch - 7ms/step
# Epoch 48/50
# 2188/2188 - 15s - loss: 0.5227 - accuracy: 0.8074 - val_loss: 1.1655 - val_accuracy: 0.6274 - 15s/epoch - 7ms/step
# Epoch 49/50
# 2188/2188 - 15s - loss: 0.5326 - accuracy: 0.8060 - val_loss: 1.0108 - val_accuracy: 0.6598 - 15s/epoch - 7ms/step
# Epoch 50/50
# 2188/2188 - 15s - loss: 0.5171 - accuracy: 0.8103 - val_loss: 0.9128 - val_accuracy: 0.6830 - 15s/epoch - 7ms/step
# 274/274 [==============================] - 1s 2ms/step - loss: 0.9191 - accuracy: 0.6808
# 274/274 [==============================] - 1s 2ms/step
#
#
# y_test :  [0 0 0 ... 9 9 9]
#
#
# y_prediction :  [0 4 9 ... 2 9 9]
# 128/128 [==============================] - 0s 2ms/step - loss: 1.5391 - accuracy: 0.5000
# 128/128 [==============================] - 0s 2ms/step
# 274/274 [==============================] - 0s 2ms/step
